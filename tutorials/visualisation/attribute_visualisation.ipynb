# %%
# %load_ext autoreload
# %autoreload 2

# %%
from estnltk.tests import new_text

# %%
from estnltk.visualisation.attribute_visualiser.attribute_visualisation import DisplayAttributes
from estnltk.visualisation.span_visualiser.fancy_span_visualisation import DisplaySpans

display = DisplayAttributes()
another = DisplayAttributes()

# %%
from estnltk.visualisation.core.span_decomposition import decompose_to_elementary_spans
decompose_to_elementary_spans(new_text(5).layer_1,new_text(5).text)
# Out:
# ([['Sada', [0]],
#   [' ', []],
#   ['kaks', [1, 2]],
#   ['kümme', [2, 3]],
#   ['nd', [2]],
#   [' ', []],
#   ['kolm', [4]],
#   ['. ', []],
#   ['Neli', [5]],
#   [' ', []],
#   ['tuhat', [6]],
#   [' ', []],
#   ['viis', [7, 8]],
#   ['sada', [8, 9]],
#   [' ', []],
#   ['kuus', [10, 11]],
#   ['kümme', [11, 12]],
#   ['nd', [11]],
#   [' ', []],
#   ['seitse', [13]],
#   [' ', []],
#   ['koma', [14]],
#   [' ', []],
#   ['kaheksa', [15]],
#   ['. ', []],
#   ['Üheksa', [16, 17]],
#   ['kümme', [17, 18]],
#   ['nd', [17]],
#   [' tuhat.', []]],
#  [AmbiguousSpan('Sada', [{'attr': 'L1-0', 'attr_1': 'SADA'}]),
#   AmbiguousSpan('kaks', [{'attr': 'L1-1', 'attr_1': 'KAKS'}]),
#   AmbiguousSpan('kakskümmend', [{'attr': 'L1-2', 'attr_1': 'KAKS'}, {'attr': 'L1-2', 'attr_1': 'KÜMME'}, {'attr': 'L1-2', 'attr_1': 'KAKSKÜMMEND'}]),
#   AmbiguousSpan('kümme', [{'attr': 'L1-3', 'attr_1': 'KÜMME'}]),
#   AmbiguousSpan('kolm', [{'attr': 'L1-4', 'attr_1': 'KOLM'}]),
# ...

# %%
new_text(5).layer_1
# Out:
# Layer(name='layer_1', attributes=('attr', 'attr_1'), spans=SL[AmbiguousSpan('Sada', [{'attr': 'L1-0', 'attr_1': 'SADA'}]),
# AmbiguousSpan('kaks', [{'attr': 'L1-1', 'attr_1': 'KAKS'}]),
# AmbiguousSpan('kakskümmend', [{'attr': 'L1-2', 'attr_1': 'KAKS'}, {'attr': 'L1-2', 'attr_1': 'KÜMME'}, {'attr': 'L1-2', 'attr_1': 'KAKSKÜMMEND'}]),
# AmbiguousSpan('kümme', [{'attr': 'L1-3', 'attr_1': 'KÜMME'}]),
# AmbiguousSpan('kolm', [{'attr': 'L1-4', 'attr_1': 'KOLM'}]),
# AmbiguousSpan('Neli', [{'attr': 'L1-5', 'attr_1': 'NELI'}]),
# AmbiguousSpan('tuhat', [{'attr': 'L1-6', 'attr_1': 'TUHAT'}]),
# AmbiguousSpan('viis', [{'attr': 'L1-7', 'attr_1': 'VIIS'}]),
# AmbiguousSpan('viissada', [{'attr': 'L1-8', 'attr_1': 'SADA'}, {'attr': 'L1-8', 'attr_1': 'VIIS'}, {'attr': 'L1-8', 'attr_1': 'VIISSADA'}]),
# AmbiguousSpan('sada', [{'attr': 'L1-9', 'attr_1': 'SADA'}]),
# AmbiguousSpan('kuus', [{'attr': 'L1-10', 'attr_1': 'KUUS'}]),
# ...

# %%
display(new_text(5).layer_1)
# näita annotatsioone paralleelselt tulpades, kasutaja saab tulba valida nooltega liikudes
# vasakult paremale saaks liikuda spanide peal, iga spani juures valida kas sobib või mitte
# Out:
# <style>
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
#
# .attribute-names-table {
#     padding: 6px;
# }
#
# .attribute-column {
#     padding: 6px;
# }
#
# .attribute-names-table tbody tr:nth-child(even) {
#     background-color: white;
# }
#
# .attribute-names-table tbody tr:nth-child(odd) {
#     background-color: white;
# }
#
# .attribute-names-table tbody tr:hover {
#     background-color: white;
# }
#
# .chosen-span {
#     border: 2px solid red;
# }
#
# .highlighted {
#     border: 2px solid red;
# }
#
# .alt-tables {
#     position: absolute;
#     width: fit-content;
# ...

# %%
display.accepted_array

# %%
display.chosen_annotations
