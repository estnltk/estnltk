# %% [markdown]
# # Examples how span visualisuation can be used in the NLP pipeline
#
# Span visualisation is the simplest visualisation form for layers. In brief, it allows you to specify how individual spans and their overlaps rendered, e.g. which colors are used. This can be useful:
#
# * for visualisation of spans/annotations in general;
# * for visualisation of certain types of words or word classes;
# * for detecting unexpected overlaps among spans;
# * for checking that complex taggers do what they are intended to do.

# %% [markdown]
# ## I. Visualisation of spans via `Layer.display()`
#
# You can easily visualize a layer's spans by calling the `Layer.display()` method, which renders the text with the relevant sections highlighted.
#
# Example:

# %%
from estnltk import Text

t = Text('''Silver, kus on sinu julged teod? 
            Merepõhja noorus maha jäi koos laevaga.''').tag_layer('morph_analysis')

# %%
# Highlight 'words' layer:
t['words'].display()
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:yellow; ">Silver</span><span style=background:yellow; ">,</span> <span style=background:yellow; ">kus</span> <span style=background:yellow; ">on</span> <span style=background:yellow; ">sinu</span> <span style=background:yellow; ">julged</span> <span style=background:yellow; ">teod</span><span style=background:yellow; ">?</span> <br>            <span style=background:yellow; ">Merepõhja</span> <span style=background:yellow; ">noorus</span> <span style=background:yellow; ">maha</span> <span style=background:yellow; ">jäi</span> <span style=background:yellow; ">koos</span> <span style=background:yellow; ">laevaga</span><span style=background:yellow; ">.</span>

# %%
# Highlight 'sentences' layer:
t['sentences'].display()
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:yellow; ">Silver, kus on sinu julged teod?</span> <br>            <span style=background:yellow; ">Merepõhja noorus maha jäi koos laevaga.</span>

# %% [markdown]
# **Changing the display style**. It is possible to pass a `mapping_dict` parameter to the `display()` method, which contains a dictionary that describes the display style.
# In this dictionary, CSS elements (e.g., `"background"`, `"font-weight"`, or `"font-family"`) are mapped to a function, e.g.:
#
#     mapping_dict = {"background":  lambda x: ...
#                     "font-weight": lambda x: ...
#                     "font-family": lambda x: ... }
#
# This function receives a single argument (a list containing the text content and its corresponding `Annotation` objects) and decides, based on the value of this argument, what the value of the CSS element should be.
#
# In the simplest case, we can use `lambda` functions that return a fixed value for every span, for instance:

# %%
# Define a new CSS style:
mapping_dict = {"background":  (lambda x: 'lime'),     # background color: lime
                "font-weight": (lambda x: 'bold'),     # font weight: bold
                "font-family": (lambda x: 'Courier')}  # font type: Courier

# Apply new style for displaying words
t['words'].display( mapping_dict = mapping_dict )
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:lime;font-weight:bold;font-family:Courier; ">Silver</span><span style=background:lime;font-weight:bold;font-family:Courier; ">,</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">kus</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">on</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">sinu</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">julged</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">teod</span><span style=background:lime;font-weight:bold;font-family:Courier; ">?</span> <br>            <span style=background:lime;font-weight:bold;font-family:Courier; ">Merepõhja</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">noorus</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">maha</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">jäi</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">koos</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">laevaga</span><span style=background:lime;font-weight:bold;font-family:Courier; ">.</span>

# %% [markdown]
# **Conditional changing of the display style**. The functions within the `mapping_dict` dictionary receive a list as an argument. The first element of this list is the text content currently being styled (a string), and the second element is a list of the corresponding `Annotation` objects.
# How many elements are in the list of `Annotation` objects depends on whether the annotation is ambigious or not; in the case of an unambigious layer, this list will always contain one element.
# Using this knowledge, we can define a more complex `mapping_dict` where the values of the style elements depend on the content of the `Annotation` objects. For instance, we can apply coloring distinguishing words and punctuation symbols:

# %%
# Define a new CSS style:
mapping_dict = {"background":  lambda x: 'pink' if x[1][0]['partofspeech'] == 'Z' else 'lime',  # use pink color for punctuation (Z) and lime for words
                "font-weight": (lambda x: 'bold'),     # font weight: bold
                "font-family": (lambda x: 'Courier')}  # font type: Courier

# Apply new style for displaying morph_analysis
t['morph_analysis'].display( mapping_dict = mapping_dict )
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:lime;font-weight:bold;font-family:Courier; ">Silver</span><span style=background:pink;font-weight:bold;font-family:Courier; ">,</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">kus</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">on</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">sinu</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">julged</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">teod</span><span style=background:pink;font-weight:bold;font-family:Courier; ">?</span> <br>            <span style=background:lime;font-weight:bold;font-family:Courier; ">Merepõhja</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">noorus</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">maha</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">jäi</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">koos</span> <span style=background:lime;font-weight:bold;font-family:Courier; ">laevaga</span><span style=background:pink;font-weight:bold;font-family:Courier; ">.</span>

# %% [markdown]
# If you want to add more complex visualization conditions, you can define a special decorator function and use it within `mapping_dict`.
#
# For example:

# %%
def my_background_decorator( span_list ):
     # use pink color for punctuation (Z),
     # yellow for proper names (H) and, 
     # lime for all other words
     if span_list[1][0]['partofspeech'] == 'Z':
         return 'pink'
     elif span_list[1][0]['partofspeech'] == 'H':
         return 'yellow'
     else:
         return 'lime'

mapping_dict = {"background":  my_background_decorator }

# Apply new style for displaying morph_analysis
t['morph_analysis'].display( mapping_dict = mapping_dict )
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:yellow; ">Silver</span><span style=background:pink; ">,</span> <span style=background:lime; ">kus</span> <span style=background:lime; ">on</span> <span style=background:lime; ">sinu</span> <span style=background:lime; ">julged</span> <span style=background:lime; ">teod</span><span style=background:pink; ">?</span> <br>            <span style=background:lime; ">Merepõhja</span> <span style=background:lime; ">noorus</span> <span style=background:lime; ">maha</span> <span style=background:lime; ">jäi</span> <span style=background:lime; ">koos</span> <span style=background:lime; ">laevaga</span><span style=background:pink; ">.</span>

# %% [markdown]
# ---
#
# ## II. Pre-defined visualisation modules
#
# EstNLTK also has some pre-defined modules providing specific visualization logic, such as highlighting ambigious annotations, part-of-speech tags, or types of compound tokens.
# We'll introduce these modules below.

# %% [markdown]
# ### II.a. Visualisation of span overlaps and spans with ambigious annotations
#
# Many steps in the NLP pipleline can lead to ambiguous results. Sometimes this can lead to unexpected results.
# For example, most analysers in the NLP pipeline assume that tokenisation is unique and there are no overlapping spans. You might also want to inspect what words have several valid morfological annotations to see when disambiguation fails during morphological analysis.

# %% [markdown]
# The following span visualiser allows you to control the background color of overlaps and ambigious annotations.
# You can specify different color for each number of annotations so that words with extremely many annotations would be easy to spot.

# %%
from estnltk.visualisation.standard_visualisers import DisplayAmbiguousSpans

# %%
# Examine docs
print( DisplayAmbiguousSpans.__doc__ )
# Out:
#     Displays overlaps between spans and spans with multiple annotations
#
#     Default background color scheme is following:
#     * normal spans are transparent
#     * overlapping spans are red
#     * ambiguous spans are orange
#
#     The opacity level indicates the number of overlaps and annotations
#
#     Color scheme is controlled by two dictionary-like class attributes
#     * span_coloring[int]
#     * annotation_coloring[int]
#
#     Assigning corresponding elements redefines the coloring for a particular
#     number of annotations or spans, e.g. span_coloring[2] = 'blue'.
#
#     Assigning corresponding attributes redefines the entire color scheme.
#     The assigned object must support indexing with any int.

# %% [markdown]
# #### Example: Showing words with ambigious morphological analysis
#
# Lets first call the span visualiser with default color scheme.

# %%
display_ambigous = DisplayAmbiguousSpans()
display_ambigous(t.morph_analysis)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:#FFA50000;>Silver</span><span style=background:#FFA50000;>,</span> <span style=background:#FFA50000;>kus</span> <span style=background:#FFA500;>on</span> <span style=background:#FFA50000;>sinu</span> <span style=background:#FFA50000;>julged</span> <span style=background:#FFA500;>teod</span><span style=background:#FFA50000;>?</span> <br>            <span style=background:#FFA50000;>Merepõhja</span> <span style=background:#FFA50000;>noorus</span> <span style=background:#FFA50000;>maha</span> <span style=background:#FFA50000;>jäi</span> <span style=background:#FFA50000;>koos</span> <span style=background:#FFA50000;>laevaga</span><span style=background:#FFA50000;>.</span>

# %% [markdown]
# Lets check whether the word 'on' has two different annotations by setting the corresponding annotation color to red and the color of three annotations to blue.

# %%
display_ambigous.annotation_coloring[2] = 'red'
display_ambigous.annotation_coloring[3] = 'blue'
display_ambigous(t.morph_analysis)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:#FFA50000;>Silver</span><span style=background:#FFA50000;>,</span> <span style=background:#FFA50000;>kus</span> <span style=background:red;>on</span> <span style=background:#FFA50000;>sinu</span> <span style=background:#FFA50000;>julged</span> <span style=background:red;>teod</span><span style=background:#FFA50000;>?</span> <br>            <span style=background:#FFA50000;>Merepõhja</span> <span style=background:#FFA50000;>noorus</span> <span style=background:#FFA50000;>maha</span> <span style=background:#FFA50000;>jäi</span> <span style=background:#FFA50000;>koos</span> <span style=background:#FFA50000;>laevaga</span><span style=background:#FFA50000;>.</span>

# %% [markdown]
# Now lets go back to the default coloring scheme.

# %%
display_ambigous.restore_defaults()
display_ambigous(t.morph_analysis)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:#FFA50000;>Silver</span><span style=background:#FFA50000;>,</span> <span style=background:#FFA50000;>kus</span> <span style=background:#FFA500;>on</span> <span style=background:#FFA50000;>sinu</span> <span style=background:#FFA50000;>julged</span> <span style=background:#FFA500;>teod</span><span style=background:#FFA50000;>?</span> <br>            <span style=background:#FFA50000;>Merepõhja</span> <span style=background:#FFA50000;>noorus</span> <span style=background:#FFA50000;>maha</span> <span style=background:#FFA50000;>jäi</span> <span style=background:#FFA50000;>koos</span> <span style=background:#FFA50000;>laevaga</span><span style=background:#FFA50000;>.</span>

# %% [markdown]
# ### II.b. Visualisation of words' part-of-speech
#
# Sometimes it can be useful to control the outcome of a morphological analysis visually. In the following, we show how one can visualise most important part-of-speech tags in `morph_analysis` layer.
# Analogous approach can be used for other attributes of the `morph_analysis` layer.

# %% [markdown]
# You can specify different color for each part-of-speech tag and a special color for words that have multiple part-of-speech tags. You can also choose the color for the rare case where tokenization is not unique and tokens overlap. This could occur only if you did some non-standard modifications to the NLP pipeline.

# %%
from estnltk.visualisation.standard_visualisers import DisplayPostagsSpans

# %%
print( DisplayPostagsSpans.__doc__ )
# Out:
#     Visualises different part-of-speech tags in a text.
#
#     Provides default background colourschme for Vabamorf and GT tagsets.
#     Color scheme is controlled by two dictionary-like class attributes
#     * pos_coloring[str]
#     * span_coloring[int]
#
#     The first coloring controls how spans with different POS-tags are
#     colored. Default coloring can be changed by assigning appropriate
#     entries, e.g. pos_coloring['V'] = 'black'.
#
#     The second controls how span overlaps are colored. The tokenization
#     into the words can be ambiguous. By default, overlaps are colored
#     by two shades of red. This can be changed by assigning appropriate
#     entries, e.g. span_coloring[2] = 'blue'.
#
#     To redefine the entire color scheme, the entire colouring attribute
#     must be redefined. The assigned object must support indexing with
#     any string for pos_coloring and any int for span_coloring.
#
#     As POS-tagging may be ambiguous, coloring is done in two phases:
#     1. list of POS-tags is aggregated into a new string label
#     2. POS-tag coloring is used to determine the background color
#
#     The default aggregator marks all ambigious labellings with '*'.
#     It is possible to customise this by redefining ambiguity_resolver.

# %% [markdown]
# #### Example: Default coloring and how to change it

# %%
display_postags = DisplayPostagsSpans()
display_postags(t.morph_analysis)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:orange;>Silver</span><span style=background:#ffffff00;>,</span> <span style=background:#ffffff00;>kus</span> <span style=background:lime;>on</span> <span style=background:#ffffff00;>sinu</span> <span style=background:yellow;>julged</span> <span style=background:orange;>teod</span><span style=background:#ffffff00;>?</span> <br>            <span style=background:orange;>Merepõhja</span> <span style=background:orange;>noorus</span> <span style=background:#ffffff00;>maha</span> <span style=background:lime;>jäi</span> <span style=background:#ffffff00;>koos</span> <span style=background:orange;>laevaga</span><span style=background:#ffffff00;>.</span>

# %%
# Examine default pos coloring:
display_postags.pos_coloring.items()
# Out:
# dict_items([('S', 'orange'), ('H', 'orange'), ('A', 'yellow'), ('U', 'yellow'), ('C', 'yellow'), ('N', 'yellow'), ('O', 'yellow'), ('V', 'lime'), ('*', 'gray')])

# %% [markdown]
# Let's change the color of the verbs (V) to red and nouns (S) to green.

# %%
display_postags.pos_coloring['V'] = 'red'
display_postags.pos_coloring['S'] = 'green'
display_postags(t)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:orange;>Silver</span><span style=background:#ffffff00;>,</span> <span style=background:#ffffff00;>kus</span> <span style=background:red;>on</span> <span style=background:#ffffff00;>sinu</span> <span style=background:yellow;>julged</span> <span style=background:green;>teod</span><span style=background:#ffffff00;>?</span> <br>            <span style=background:green;>Merepõhja</span> <span style=background:green;>noorus</span> <span style=background:#ffffff00;>maha</span> <span style=background:red;>jäi</span> <span style=background:#ffffff00;>koos</span> <span style=background:green;>laevaga</span><span style=background:#ffffff00;>.</span>

# %% [markdown]
# This does not look good. Let's restore original coloring.

# %%
display_postags.restore_defaults()
display_postags(t)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:orange;>Silver</span><span style=background:#ffffff00;>,</span> <span style=background:#ffffff00;>kus</span> <span style=background:lime;>on</span> <span style=background:#ffffff00;>sinu</span> <span style=background:yellow;>julged</span> <span style=background:orange;>teod</span><span style=background:#ffffff00;>?</span> <br>            <span style=background:orange;>Merepõhja</span> <span style=background:orange;>noorus</span> <span style=background:#ffffff00;>maha</span> <span style=background:lime;>jäi</span> <span style=background:#ffffff00;>koos</span> <span style=background:orange;>laevaga</span><span style=background:#ffffff00;>.</span>

# %% [markdown]
# Let's redefine the way the span visualiser handles ambiguities.

# %%
def amb_resolver(span):
    
    pos_tags = list(span['partofspeech'])
    if len(pos_tags) == 1:
        return next(iter(pos_tags));
    return '*'

display_postags.ambiguity_resolver = amb_resolver
display_postags(t)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:orange;>Silver</span><span style=background:#ffffff00;>,</span> <span style=background:#ffffff00;>kus</span> <span style=background:gray;>on</span> <span style=background:#ffffff00;>sinu</span> <span style=background:yellow;>julged</span> <span style=background:gray;>teod</span><span style=background:#ffffff00;>?</span> <br>            <span style=background:orange;>Merepõhja</span> <span style=background:orange;>noorus</span> <span style=background:#ffffff00;>maha</span> <span style=background:lime;>jäi</span> <span style=background:#ffffff00;>koos</span> <span style=background:orange;>laevaga</span><span style=background:#ffffff00;>.</span>

# %% [markdown]
# Note that you can still go back to the default ambiguity resolved specified during the initialisation.

# %%
display_postags.restore_defaults()
display_postags(t)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:orange;>Silver</span><span style=background:#ffffff00;>,</span> <span style=background:#ffffff00;>kus</span> <span style=background:lime;>on</span> <span style=background:#ffffff00;>sinu</span> <span style=background:yellow;>julged</span> <span style=background:orange;>teod</span><span style=background:#ffffff00;>?</span> <br>            <span style=background:orange;>Merepõhja</span> <span style=background:orange;>noorus</span> <span style=background:#ffffff00;>maha</span> <span style=background:lime;>jäi</span> <span style=background:#ffffff00;>koos</span> <span style=background:orange;>laevaga</span><span style=background:#ffffff00;>.</span>

# %% [markdown]
# ### II.c. Visualization of compound tokens
#
# The NLP pipeline starts with a tokenization phase. This phase has sub-steps:
#
# * first, text is split into smallest meaningful tokens
# * then, some of these are combined back into larger units (e.g. dates and proper names)
#
# The following span visualiser highlights identified compound tokens and their subtype.

# %%
from estnltk.visualisation.standard_visualisers import DisplayCompoundTokens

# %%
print( DisplayCompoundTokens.__doc__ )
# Out:
#     Visualizes subtypes of compound tokens in a text
#
#     Default background color scheme is following:
#     * type_coloring[str]
#     * span_coloring[int]
#
#     The first coloring controls how spans with different compound tokens
#     are colored. Default coloring can be changed by assigning appropriate
#     entries, e.g. type_coloring['numeric'] = 'black'.
#
#     The second controls how span overlaps are colored. Tokenization
#     into words can be ambiguous. By default, overlaps are colored
#     in two shades of red. This can be changed by assigning appropriate
#     entries, e.g. span_coloring[2] = 'blue'.
#
#     To redefine the entire color scheme, the entire colouring attribute
#     must be redefined. The assigned object must support indexing with
#     any string for type_coloring and any int for span_coloring.
#
#     As a compound can have multiple type labels, colouring is done in two phases:
#     1. list of type tags is aggregated into a new string label
#     2. type tag coloring is used to determine the background color
#
#     The default aggregator removes 'sign' attribute and marks all ambigious
#     labellings with '*'. It is possible to customize this by redefining
#     ambiguity_resolver.

# %% [markdown]
# #### Example: Default coloring and how to change it
# For this example, we need more specific text that contains compound tokens

# %%
raw_text  = 'Mis aias sa-das 3me sorti s-saia?\n'
raw_text += '02.02.2010 22:55 Mati : saad sa mulle 100,50 asemel 10 000 laenata?\n'
raw_text += 'Mati : +100% kindel, et toon tagasi!!\n'
raw_text += 'Tänase seisuga tuleb ikka suur lohe vaiksema tuule (6-12 m/s) jaoks ja teine väiksem tormikaks (12-20 m/s) võtta…\n'
raw_text += '<u>Kirjavahemärgid, hingamiskohad</u>.\n'
raw_text += 'Saada need e-postiaadressile big@boss.com või tule sisesta lehelt www.iamboss.com\n'
raw_text += 'Maja on fantastiline :)) ja mõte on hea :-)\n'
raw_text += '(arhitektid M. Port, M. Meelak, O. Zhemtshugov, R.-L. Kivi)\n'
raw_text += 'Nt. hädas oli juba Vana-Hiina suurim ajaloolane Sima Qian (II—I saj. e. m. a.).\n'
raw_text += "10 000-st LinkedIn 'i kontaktist mitte üks ei hoolinud meie SKT -st, aga meie workshop ' e väisasid küll.\n"
text = Text(raw_text).tag_layer('compound_tokens')
display_compounds = DisplayCompoundTokens()
display_compounds(text.compound_tokens)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style>Mis aias <span style=background:#306754;>sa-das</span> 3me sorti <span style=background:#306754;>s-saia</span>?<br><span style=background:#9DC209;>02.02.2010</span> <span style=background:#ffffff00;>22:55</span> Mati : saad sa mulle <span style=background:#9DC209;>100,50</span> asemel <span style=background:#9DC209;>10 000</span> laenata?<br>Mati : <span style=background:#9DC209;>+100%</span> kindel, et toon tagasi!!<br>Tänase seisuga tuleb ikka suur lohe vaiksema tuule (6-12 <span style=background:#759A00;>m/s</span>) jaoks ja teine väiksem tormikaks (12-20 <span style=background:#759A00;>m/s</span>) võtta…<br><span style=background:#5E5A80;>&lt;u&gt;</span>Kirjavahemärgid, hingamiskohad<span style=background:#5E5A80;>&lt;/u&gt;</span>.<br>Saada need <span style=background:#306754;>e-postiaadressile</span> <span style=background:#908CB2;>big@boss.com</span> või tule sisesta lehelt <span style=background:#908CB2;>www.iamboss.com</span><br>Maja on fantastiline <span style=background:#FFDB58;>:))</span> ja mõte on hea <span style=background:#FFDB58;>:-)</span><br>(arhitektid <span style=background:#6CA390;>M. Port</span>, <span style=background:#6CA390;>M. Meelak</span>, <span style=background:#6CA390;>O. Zhemtshugov</span>, <span style=background:#6CA390;>R.-L. Kivi</span>)<br><span style=background:#BCE954;>Nt.</span> hädas oli juba <span style=background:#306754;>Vana-Hiina</span> suurim ajaloolane Sima Qian (II—I <span style=background:#BCE954;>saj.</span> <span style=background:#BCE954;>e. m. a.</span>).<br><span style=background:#FFA62F;>10 000-st</span> <span style=background:#6CA390;>LinkedIn &#x27;i</span> kontaktist mitte üks ei hoolinud meie <span style=background:#6CA390;>SKT -st</span>, aga meie <span style=background:#6CA390;>workshop &#x27; e</span> väisasid küll.<br>

# %% [markdown]
# Lets change the colour of dates (numeric_date) to red and emoticons (emoticon) to blue.

# %%
display_compounds.type_coloring['numeric_date'] = 'red' 
display_compounds.type_coloring['emoticon'] = 'aqua'
display_compounds(text)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style>Mis aias <span style=background:#306754;>sa-das</span> 3me sorti <span style=background:#306754;>s-saia</span>?<br><span style=background:red;>02.02.2010</span> <span style=background:#ffffff00;>22:55</span> Mati : saad sa mulle <span style=background:#9DC209;>100,50</span> asemel <span style=background:#9DC209;>10 000</span> laenata?<br>Mati : <span style=background:#9DC209;>+100%</span> kindel, et toon tagasi!!<br>Tänase seisuga tuleb ikka suur lohe vaiksema tuule (6-12 <span style=background:#759A00;>m/s</span>) jaoks ja teine väiksem tormikaks (12-20 <span style=background:#759A00;>m/s</span>) võtta…<br><span style=background:#5E5A80;>&lt;u&gt;</span>Kirjavahemärgid, hingamiskohad<span style=background:#5E5A80;>&lt;/u&gt;</span>.<br>Saada need <span style=background:#306754;>e-postiaadressile</span> <span style=background:#908CB2;>big@boss.com</span> või tule sisesta lehelt <span style=background:#908CB2;>www.iamboss.com</span><br>Maja on fantastiline <span style=background:aqua;>:))</span> ja mõte on hea <span style=background:aqua;>:-)</span><br>(arhitektid <span style=background:#6CA390;>M. Port</span>, <span style=background:#6CA390;>M. Meelak</span>, <span style=background:#6CA390;>O. Zhemtshugov</span>, <span style=background:#6CA390;>R.-L. Kivi</span>)<br><span style=background:#BCE954;>Nt.</span> hädas oli juba <span style=background:#306754;>Vana-Hiina</span> suurim ajaloolane Sima Qian (II—I <span style=background:#BCE954;>saj.</span> <span style=background:#BCE954;>e. m. a.</span>).<br><span style=background:#FFA62F;>10 000-st</span> <span style=background:#6CA390;>LinkedIn &#x27;i</span> kontaktist mitte üks ei hoolinud meie <span style=background:#6CA390;>SKT -st</span>, aga meie <span style=background:#6CA390;>workshop &#x27; e</span> väisasid küll.<br>

# %% [markdown]
# Default subtype resolver discards sign subtype. Lets highlight locations where these are present.

# %%
def subtype_resolver(span):
    if 'sign' in set(span.type):
        return 'sign'
    else:
        return '*'  
display_compounds.ambiguity_resolver = subtype_resolver
display_compounds.type_coloring['sign'] = 'red'
display_compounds.type_coloring['*'] = 'white'
display_compounds(text)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style>Mis aias <span style=background:white;>sa-das</span> 3me sorti <span style=background:white;>s-saia</span>?<br><span style=background:white;>02.02.2010</span> <span style=background:white;>22:55</span> Mati : saad sa mulle <span style=background:white;>100,50</span> asemel <span style=background:white;>10 000</span> laenata?<br>Mati : <span style=background:red;>+100%</span> kindel, et toon tagasi!!<br>Tänase seisuga tuleb ikka suur lohe vaiksema tuule (6-12 <span style=background:white;>m/s</span>) jaoks ja teine väiksem tormikaks (12-20 <span style=background:white;>m/s</span>) võtta…<br><span style=background:white;>&lt;u&gt;</span>Kirjavahemärgid, hingamiskohad<span style=background:white;>&lt;/u&gt;</span>.<br>Saada need <span style=background:white;>e-postiaadressile</span> <span style=background:white;>big@boss.com</span> või tule sisesta lehelt <span style=background:white;>www.iamboss.com</span><br>Maja on fantastiline <span style=background:white;>:))</span> ja mõte on hea <span style=background:white;>:-)</span><br>(arhitektid <span style=background:white;>M. Port</span>, <span style=background:white;>M. Meelak</span>, <span style=background:white;>O. Zhemtshugov</span>, <span style=background:white;>R.-L. Kivi</span>)<br><span style=background:white;>Nt.</span> hädas oli juba <span style=background:white;>Vana-Hiina</span> suurim ajaloolane Sima Qian (II—I <span style=background:white;>saj.</span> <span style=background:white;>e. m. a.</span>).<br><span style=background:white;>10 000-st</span> <span style=background:white;>LinkedIn &#x27;i</span> kontaktist mitte üks ei hoolinud meie <span style=background:white;>SKT -st</span>, aga meie <span style=background:white;>workshop &#x27; e</span> väisasid küll.<br>

# %% [markdown]
# Again, you can restore the default state.

# %%
display_compounds.restore_defaults()
display_compounds(text)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style>Mis aias <span style=background:#306754;>sa-das</span> 3me sorti <span style=background:#306754;>s-saia</span>?<br><span style=background:#9DC209;>02.02.2010</span> <span style=background:#ffffff00;>22:55</span> Mati : saad sa mulle <span style=background:#9DC209;>100,50</span> asemel <span style=background:#9DC209;>10 000</span> laenata?<br>Mati : <span style=background:#9DC209;>+100%</span> kindel, et toon tagasi!!<br>Tänase seisuga tuleb ikka suur lohe vaiksema tuule (6-12 <span style=background:#759A00;>m/s</span>) jaoks ja teine väiksem tormikaks (12-20 <span style=background:#759A00;>m/s</span>) võtta…<br><span style=background:#5E5A80;>&lt;u&gt;</span>Kirjavahemärgid, hingamiskohad<span style=background:#5E5A80;>&lt;/u&gt;</span>.<br>Saada need <span style=background:#306754;>e-postiaadressile</span> <span style=background:#908CB2;>big@boss.com</span> või tule sisesta lehelt <span style=background:#908CB2;>www.iamboss.com</span><br>Maja on fantastiline <span style=background:#FFDB58;>:))</span> ja mõte on hea <span style=background:#FFDB58;>:-)</span><br>(arhitektid <span style=background:#6CA390;>M. Port</span>, <span style=background:#6CA390;>M. Meelak</span>, <span style=background:#6CA390;>O. Zhemtshugov</span>, <span style=background:#6CA390;>R.-L. Kivi</span>)<br><span style=background:#BCE954;>Nt.</span> hädas oli juba <span style=background:#306754;>Vana-Hiina</span> suurim ajaloolane Sima Qian (II—I <span style=background:#BCE954;>saj.</span> <span style=background:#BCE954;>e. m. a.</span>).<br><span style=background:#FFA62F;>10 000-st</span> <span style=background:#6CA390;>LinkedIn &#x27;i</span> kontaktist mitte üks ei hoolinud meie <span style=background:#6CA390;>SKT -st</span>, aga meie <span style=background:#6CA390;>workshop &#x27; e</span> väisasid küll.<br>

# %% [markdown]
# ### II.d. Visualization of cases
#
# Cases are one of the most important output attribute of morphological analysis. These are used as inputs for many higher level taggers. Thus, it might be convenient to visualize this outcome. This might reveal error patterns or incorrect assumptions made by the higher level taggers.

# %%
from estnltk.visualisation.standard_visualisers import DisplayNounCases

# %%
print( DisplayNounCases.__doc__ )
# Out:
#     Visualizes case information in a text
#
#     Default background color scheme is following:
#     * case_coloring[str]
#     * span_coloring[int]
#
#     The first coloring controls how spans with different cases are colored.
#     Default coloring can be changed by assigning appropriate entries, e.g.
#     case_coloring['kom'] = 'black'.
#
#     The second controls how span overlaps are colored. The tokenization
#     into the words can be ambiguous. By default, overlaps are colored
#     in two shades of red. This can be changed by assigning appropriate
#     entries, e.g. span_coloring[2] = 'blue'.
#
#     To redefine the entire color scheme, the entire colouring attribute
#     must be redefined. The assigned object must support indexing with
#     any string for type_coloring and any int for span_coloring.
#
#     As a word can have multiple analyses, coloring is done in two phases:
#     1. list of case tags is aggregated into a new string label
#     2. case tag coloring is used to determine the background color
#
#     The default aggregator removes number information from the case label
#     and marks all ambigious labellings with '*'. It is possible to customise
#     this by redefining ambiguity_resolver.

# %% [markdown]
# #### Example: Default coloring and how ro change it

# %%
display_cases = DisplayNounCases() 
display_cases(t)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:orange;>Silver</span><span style=background:#ffffff00;>,</span> <span style=background:#ffffff00;>kus</span> <span style=background:#ffffff00;>on</span> <span style=background:yellow;>sinu</span> <span style=background:#ffffff00;>julged</span> <span style=background:orange;>teod</span><span style=background:#ffffff00;>?</span> <br>            <span style=background:yellow;>Merepõhja</span> <span style=background:orange;>noorus</span> <span style=background:#ffffff00;>maha</span> <span style=background:#ffffff00;>jäi</span> <span style=background:#ffffff00;>koos</span> <span style=background:#ffffff00;>laevaga</span><span style=background:#ffffff00;>.</span>

# %% [markdown]
# Lets color only plural and singular aspect of the case. This requires change in the ambiguity resolver and coloring itself.

# %%
import re

def case_number_detector(span):
    cases = {re.match('^(?P<number>sg|pl) ', an.form).group('number') for an in span.annotations 
             if an.partofspeech in {'S', 'H', 'P'} and re.match('^(?P<number>sg|pl) ', an.form)}
        
    if len(cases) == 0:
        return '_'
        
    if len(cases) == 1:
        return next(iter(cases));
        
    return '*'

display_cases.ambiguity_resolver = case_number_detector
display_cases.case_coloring['sg'] = 'aqua'
display_cases.case_coloring['pl'] = 'red'
display_cases(t)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:aqua;>Silver</span><span style=background:#ffffff00;>,</span> <span style=background:#ffffff00;>kus</span> <span style=background:#ffffff00;>on</span> <span style=background:aqua;>sinu</span> <span style=background:#ffffff00;>julged</span> <span style=background:red;>teod</span><span style=background:#ffffff00;>?</span> <br>            <span style=background:aqua;>Merepõhja</span> <span style=background:aqua;>noorus</span> <span style=background:#ffffff00;>maha</span> <span style=background:#ffffff00;>jäi</span> <span style=background:#ffffff00;>koos</span> <span style=background:aqua;>laevaga</span><span style=background:#ffffff00;>.</span>

# %% [markdown]
# Let's now restore default behaviour.

# %%
display_cases.restore_defaults()
display_cases(t)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:orange;>Silver</span><span style=background:#ffffff00;>,</span> <span style=background:#ffffff00;>kus</span> <span style=background:#ffffff00;>on</span> <span style=background:yellow;>sinu</span> <span style=background:#ffffff00;>julged</span> <span style=background:orange;>teod</span><span style=background:#ffffff00;>?</span> <br>            <span style=background:yellow;>Merepõhja</span> <span style=background:orange;>noorus</span> <span style=background:#ffffff00;>maha</span> <span style=background:#ffffff00;>jäi</span> <span style=background:#ffffff00;>koos</span> <span style=background:#ffffff00;>laevaga</span><span style=background:#ffffff00;>.</span>

# %% [markdown]
# ### II.e. Visualisation of compound words

# %%
from estnltk.visualisation.standard_visualisers import DisplayCompoundWords

# %%
print( DisplayCompoundWords.__doc__ )
# Out:
#     Visualizes compound words in a text
#
#     Default background color scheme is following:
#     * word_coloring[str]
#     * span_coloring[int]
#
#     The first coloring controls how simple and compound words are colored.
#     Default coloring can be changed by assigning appropriate entries, e.g.
#     case_coloring['simple'] = 'blue'.
#
#     The second controls how span overlaps are colored. Tokenization
#     into words can be ambiguous. By default, overlaps are colored
#     in two shades of red. This can be changed by assigning appropriate
#     entries, e.g. span_coloring[2] = 'blue'.
#
#     To redefine the entire color scheme, the entire colouring attribute
#     must be redefined. The assigned object must support indexing with
#     any string for type_coloring and any int for span_coloring.
#
#     As a word can have multiple analyses, coloring is done in two phases:
#     1. list of root_word tags is aggregated into a new string label
#     2. case tag coloring is used to determine the background color
#
#     The default aggregator marks a word as a compound if it is a compound
#     according to at least one analysis. It is possible to customise
#     this by redefining ambiguity_resolver.

# %%
display_compound_words = DisplayCompoundWords()
display_compound_words(t)
# Out:
# <script>
# var elements = document.getElementsByClassName("overlapping-span")
# for (let i = 0; i < elements.length; i++){
#     elements.item(i).addEventListener("click",function() {show_conflicting_spans(elements.item(i));})}
#
# function show_conflicting_spans(span_element) {
#     let spantable = document.createElement('div')
#     spantable.classList.add('tables')
#
#     // Prepare the contents of the span table
#     data = span_element.getAttribute("span_info")
#     data = data.split(",")
#     var spancontent = '<table>'
#     for (let row of data) {
#         spancontent+='<tr><td>'
#         spancontent+=row
#         spancontent+='</td></tr>'
#     }
#     spancontent += '</table>'
#     spantable.innerHTML = spancontent
#     span_element.parentElement.appendChild(spantable)
#
#     // Increase the size of the cell so the tables would fit
#     spantable.parentElement.style.height = Math.max(Number(spantable.parentElement.style.height.substring(0,spantable.parentElement.style.height.length-2)),span_element.offsetTop+90)+ 'px'
#     // Position the table directly below the corresponding text
#     spantable.style.left = span_element.getBoundingClientRect().left-spantable.parentElement.parentElement.getBoundingClientRect().left + 'px'
#     spantable.style.top = span_element.getBoundingClientRect().top-spantable.parentElement.parentElement.getBoundingClientRect().top+20+ 'px'
#
#     // Remove the table when clicked on again
#     spantable.addEventListener('click', function () {
#         let element = this.parentElement
#         element.removeChild(this)
#     })
# }
# </script><style>
# .span {
#     background-color: yellow;
# }
#
# .overlapping-span {
#     background-color: red;
# }
#
# .spanline {
#     background-color: blue;
#     position: relative;
#     height: 3px;
#     margin-left: 0px;
# }
#
# .tables {
#     position: absolute;
#     width: fit-content;
#     width: -moz-fit-content;
#     border: 1px solid black;
# }
#
# .maintext{0} {
#     position: relative;
# }
#
# .tables tbody tr:nth-child(even) {
#     background-color: lightgray;
# }
#
# .tables tbody tr:nth-child(odd) {
#     background-color: beige;
# }
#
# .tables tbody tr:hover {
#     background-color: ivory;
# }
# </style><span style=background:#ffffff00;>Silver</span><span style=background:#ffffff00;>,</span> <span style=background:#ffffff00;>kus</span> <span style=background:#ffffff00;>on</span> <span style=background:#ffffff00;>sinu</span> <span style=background:#ffffff00;>julged</span> <span style=background:#ffffff00;>teod</span><span style=background:#ffffff00;>?</span> <br>            <span style=background:#ffb6c1;>Merepõhja</span> <span style=background:#ffffff00;>noorus</span> <span style=background:#ffffff00;>maha</span> <span style=background:#ffffff00;>jäi</span> <span style=background:#ffffff00;>koos</span> <span style=background:#ffffff00;>laevaga</span><span style=background:#ffffff00;>.</span>

# %% [markdown]
# ---
