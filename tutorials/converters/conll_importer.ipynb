# %% [markdown]
# # Import conll

# %%
from estnltk.converters.conll_importer import conll_to_text, add_layer_from_conll


text = conll_to_text(file='conll_importer.conll',
                     syntax_layer='conll_syntax_1'  # default: 'conll_syntax'
                     )
text
# Out:
# Text(text='Iga üheksas kroon tuli salapärastelt isikutelt . See oli rohkem kui 10 protsenti kogu Hansapanka paigutatud rahast .')

# %%
text.conll_syntax_1
# Out:
# Layer(name=conll_syntax_1, spans=SL[AS[Annotation(Iga, {'children': None, 'deprel': '@NN>', 'deps': None, 'feats': 'det|sg|nom', 'head': 2, 'id': 1, 'lemma': 'iga', 'misc': None, 'parent_span': None, 'upostag': 'P', 'xpostag': 'P'})],
# AS[Annotation(üheksas, {'children': None, 'deprel': '@AN>', 'deps': None, 'feats': 'ord|sg|nom|l', 'head': 3, 'id': 2, 'lemma': 'üheksas', 'misc': None, 'parent_span': None, 'upostag': 'N', 'xpostag': 'A'})],
# AS[Annotation(kroon, {'children': None, 'deprel': '@SUBJ', 'deps': None, 'feats': 'sg|nom', 'head': 4, 'id': 3, 'lemma': 'kroon', 'misc': None, 'parent_span': None, 'upostag': 'S', 'xpostag': 'S'})],
# AS[Annotation(tuli, {'children': None, 'deprel': 'ROOT', 'deps': None, 'feats': 'indic|impf|ps3|sg', 'head': 0, 'id': 4, 'lemma': 'tule', 'misc': None, 'parent_span': None, 'upostag': 'V', 'xpostag': 'V'})],
# AS[Annotation(salapärastelt, {'children': None, 'deprel': '@AN>', 'deps': None, 'feats': 'pl|abl', 'head': 6, 'id': 5, 'lemma': 'sala_pärane', 'misc': None, 'parent_span': None, 'upostag': 'A', 'xpostag': 'A'})],
# AS[Annotation(isikutelt, {'children': None, 'deprel': '@ADVL', 'deps': None, 'feats': 'pl|abl', 'head': 4, 'id': 6, 'lemma': 'isik', 'misc': None, 'parent_span': None, 'upostag': 'S', 'xpostag': 'S'})],
# AS[Annotation(., {'children': None, 'deprel': '@Punc', 'deps': None, 'feats': 'Fst', 'head': 6, 'id': 7, 'lemma': '.', 'misc': None, 'parent_span': None, 'upostag': 'Z', 'xpostag': 'Z'})],
# AS[Annotation(See, {'children': None, 'deprel': '@SUBJ', 'deps': None, 'feats': 'dem|sg|nom', 'head': 2, 'id': 1, 'lemma': 'see', 'misc': None, 'parent_span': None, 'upostag': 'P', 'xpostag': 'P'})],
# AS[Annotation(oli, {'children': None, 'deprel': 'ROOT', 'deps': None, 'feats': 'indic|impf|ps3|sg', 'head': 0, 'id': 2, 'lemma': 'ole', 'misc': None, 'parent_span': None, 'upostag': 'V', 'xpostag': 'V'})],
# AS[Annotation(rohkem, {'children': None, 'deprel': '@OBJ', 'deps': None, 'feats': None, 'head': 2, 'id': 3, 'lemma': 'rohkem', 'misc': None, 'parent_span': None, 'upostag': 'D', 'xpostag': 'D'})],
# AS[Annotation(kui, {'children': None, 'deprel': '@J', 'deps': None, 'feats': None, 'head': 5, 'id': 4, 'lemma': 'kui', 'misc': None, 'parent_span': None, 'upostag': 'J', 'xpostag': 'Jc'})],
# AS[Annotation(10, {'children': None, 'deprel': '@ADVL', 'deps': None, 'feats': 'card|sg|nom', 'head': 3, 'id': 5, 'lemma': '10', 'misc': None, 'parent_span': None, 'upostag': 'N', 'xpostag': 'N'})],
# AS[Annotation(protsenti, {'children': None, 'deprel': '@<Q', 'deps': None, 'feats': 'sg|part', 'head': 5, 'id': 6, 'lemma': 'protsent', 'misc': None, 'parent_span': None, 'upostag': 'S', 'xpostag': 'S'})],
# AS[Annotation(kogu, {'children': None, 'deprel': '@AN>', 'deps': None, 'feats': None, 'head': 10, 'id': 7, 'lemma': 'kogu', 'misc': None, 'parent_span': None, 'upostag': 'A', 'xpostag': 'A'})],
# AS[Annotation(Hansapanka, {'children': None, 'deprel': '@ADVL', 'deps': None, 'feats': 'sg|adit', 'head': 9, 'id': 8, 'lemma': 'Hansa_pank', 'misc': None, 'parent_span': None, 'upostag': 'S', 'xpostag': 'H'})],
# AS[Annotation(paigutatud, {'children': None, 'deprel': '@AN>', 'deps': None, 'feats': 'partic', 'head': 10, 'id': 9, 'lemma': 'paiguta=tud', 'misc': None, 'parent_span': None, 'upostag': 'A', 'xpostag': 'A'})],
# AS[Annotation(rahast, {'children': None, 'deprel': '@ADVL', 'deps': None, 'feats': 'sg|el', 'head': 5, 'id': 10, 'lemma': 'raha', 'misc': None, 'parent_span': None, 'upostag': 'S', 'xpostag': 'S'})],
# AS[Annotation(., {'children': None, 'deprel': '@Punc', 'deps': None, 'feats': 'Fst', 'head': 10, 'id': 11, 'lemma': '.', 'misc': None, 'parent_span': None, 'upostag': 'Z', 'xpostag': 'Z'})]])

# %%
add_layer_from_conll(file='conll_importer.conll',
                     text=text,
                     syntax_layer='conll_syntax_2'
                     )
# Out:
# Text(text='Iga üheksas kroon tuli salapärastelt isikutelt . See oli rohkem kui 10 protsenti kogu Hansapanka paigutatud rahast .')

# %%
text.conll_syntax_2
# Out:
# Layer(name=conll_syntax_2, spans=SL[AS[Annotation(Iga, {'children': None, 'deprel': '@NN>', 'deps': None, 'feats': 'det|sg|nom', 'head': 2, 'id': 1, 'lemma': 'iga', 'misc': None, 'parent_span': None, 'upostag': 'P', 'xpostag': 'P'})],
# AS[Annotation(üheksas, {'children': None, 'deprel': '@AN>', 'deps': None, 'feats': 'ord|sg|nom|l', 'head': 3, 'id': 2, 'lemma': 'üheksas', 'misc': None, 'parent_span': None, 'upostag': 'N', 'xpostag': 'A'})],
# AS[Annotation(kroon, {'children': None, 'deprel': '@SUBJ', 'deps': None, 'feats': 'sg|nom', 'head': 4, 'id': 3, 'lemma': 'kroon', 'misc': None, 'parent_span': None, 'upostag': 'S', 'xpostag': 'S'})],
# AS[Annotation(tuli, {'children': None, 'deprel': 'ROOT', 'deps': None, 'feats': 'indic|impf|ps3|sg', 'head': 0, 'id': 4, 'lemma': 'tule', 'misc': None, 'parent_span': None, 'upostag': 'V', 'xpostag': 'V'})],
# AS[Annotation(salapärastelt, {'children': None, 'deprel': '@AN>', 'deps': None, 'feats': 'pl|abl', 'head': 6, 'id': 5, 'lemma': 'sala_pärane', 'misc': None, 'parent_span': None, 'upostag': 'A', 'xpostag': 'A'})],
# AS[Annotation(isikutelt, {'children': None, 'deprel': '@ADVL', 'deps': None, 'feats': 'pl|abl', 'head': 4, 'id': 6, 'lemma': 'isik', 'misc': None, 'parent_span': None, 'upostag': 'S', 'xpostag': 'S'})],
# AS[Annotation(., {'children': None, 'deprel': '@Punc', 'deps': None, 'feats': 'Fst', 'head': 6, 'id': 7, 'lemma': '.', 'misc': None, 'parent_span': None, 'upostag': 'Z', 'xpostag': 'Z'})],
# AS[Annotation(See, {'children': None, 'deprel': '@SUBJ', 'deps': None, 'feats': 'dem|sg|nom', 'head': 2, 'id': 1, 'lemma': 'see', 'misc': None, 'parent_span': None, 'upostag': 'P', 'xpostag': 'P'})],
# AS[Annotation(oli, {'children': None, 'deprel': 'ROOT', 'deps': None, 'feats': 'indic|impf|ps3|sg', 'head': 0, 'id': 2, 'lemma': 'ole', 'misc': None, 'parent_span': None, 'upostag': 'V', 'xpostag': 'V'})],
# AS[Annotation(rohkem, {'children': None, 'deprel': '@OBJ', 'deps': None, 'feats': None, 'head': 2, 'id': 3, 'lemma': 'rohkem', 'misc': None, 'parent_span': None, 'upostag': 'D', 'xpostag': 'D'})],
# AS[Annotation(kui, {'children': None, 'deprel': '@J', 'deps': None, 'feats': None, 'head': 5, 'id': 4, 'lemma': 'kui', 'misc': None, 'parent_span': None, 'upostag': 'J', 'xpostag': 'Jc'})],
# AS[Annotation(10, {'children': None, 'deprel': '@ADVL', 'deps': None, 'feats': 'card|sg|nom', 'head': 3, 'id': 5, 'lemma': '10', 'misc': None, 'parent_span': None, 'upostag': 'N', 'xpostag': 'N'})],
# AS[Annotation(protsenti, {'children': None, 'deprel': '@<Q', 'deps': None, 'feats': 'sg|part', 'head': 5, 'id': 6, 'lemma': 'protsent', 'misc': None, 'parent_span': None, 'upostag': 'S', 'xpostag': 'S'})],
# AS[Annotation(kogu, {'children': None, 'deprel': '@AN>', 'deps': None, 'feats': None, 'head': 10, 'id': 7, 'lemma': 'kogu', 'misc': None, 'parent_span': None, 'upostag': 'A', 'xpostag': 'A'})],
# AS[Annotation(Hansapanka, {'children': None, 'deprel': '@ADVL', 'deps': None, 'feats': 'sg|adit', 'head': 9, 'id': 8, 'lemma': 'Hansa_pank', 'misc': None, 'parent_span': None, 'upostag': 'S', 'xpostag': 'H'})],
# AS[Annotation(paigutatud, {'children': None, 'deprel': '@AN>', 'deps': None, 'feats': 'partic', 'head': 10, 'id': 9, 'lemma': 'paiguta=tud', 'misc': None, 'parent_span': None, 'upostag': 'A', 'xpostag': 'A'})],
# AS[Annotation(rahast, {'children': None, 'deprel': '@ADVL', 'deps': None, 'feats': 'sg|el', 'head': 5, 'id': 10, 'lemma': 'raha', 'misc': None, 'parent_span': None, 'upostag': 'S', 'xpostag': 'S'})],
# AS[Annotation(., {'children': None, 'deprel': '@Punc', 'deps': None, 'feats': 'Fst', 'head': 10, 'id': 11, 'lemma': '.', 'misc': None, 'parent_span': None, 'upostag': 'Z', 'xpostag': 'Z'})]])
