# %% [markdown]
# # Import conll

# %%
from estnltk.converters.conll_importer import conll_to_text

text = conll_to_text('conll_importer.conll')
text
# Out:
# Text(text='Iga üheksas kroon tuli salapärastelt isikutelt . Eesti Ekspressi teada on Eesti Pank uurinud Hansapanga tehinguid , mis toimusid kaks aastat tagasi suvel ja mille käigus voolas panka ligi miljardi krooni ulatuses kahtlast raha . See oli rohkem kui 10 protsenti kogu Hansapanka paigutatud rahast .')

# %%
text.syntax
# Out:
# Layer(name=syntax, spans=SL[AS[Annotation(Iga, {'deprel': '@NN>', 'deps': None, 'feats': 'det|sg|nom', 'head': None, 'head_id': 2, 'id': 1, 'lemma': 'iga', 'misc': None, 'upostag': 'P', 'xpostag': 'P'})],
# AS[Annotation(üheksas, {'deprel': '@AN>', 'deps': None, 'feats': 'ord|sg|nom|l', 'head': None, 'head_id': 3, 'id': 2, 'lemma': 'üheksas', 'misc': None, 'upostag': 'N', 'xpostag': 'A'})],
# AS[Annotation(kroon, {'deprel': '@SUBJ', 'deps': None, 'feats': 'sg|nom', 'head': None, 'head_id': 4, 'id': 3, 'lemma': 'kroon', 'misc': None, 'upostag': 'S', 'xpostag': 'S'})],
# AS[Annotation(tuli, {'deprel': 'ROOT', 'deps': None, 'feats': 'indic|impf|ps3|sg', 'head': None, 'head_id': 0, 'id': 4, 'lemma': 'tule', 'misc': None, 'upostag': 'V', 'xpostag': 'V'})],
# AS[Annotation(salapärastelt, {'deprel': '@AN>', 'deps': None, 'feats': 'pl|abl', 'head': None, 'head_id': 6, 'id': 5, 'lemma': 'sala_pärane', 'misc': None, 'upostag': 'A', 'xpostag': 'A'})],
# ...
