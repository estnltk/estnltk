# %% [markdown]
# # Web-taggers
#
# To run a web tagger, you need a running [EstNLTK web-tagger](https://github.com/estnltk/webtagger-service) service. Web services for some tools are also available at the `tartunlp` server.

# %%
from estnltk import Text

# %% [markdown]
# ## Currently available web-taggers

# %% [markdown]
# ## BertEmbeddingsWebTagger
#
# Tags [Bert's embeddings](https://huggingface.co/tartuNLP/EstBERT) using EstNLTK's [BertTagger](https://github.com/estnltk/estnltk/blob/version_1.6/tutorials/taggers/embeddings_tagger.ipynb).

# %%
from estnltk.taggers import BertEmbeddingsWebTagger
bert_embeddings_web_tagger = \
    BertEmbeddingsWebTagger(url='https://api.tartunlp.ai/estnltk/tagger/bert')
bert_embeddings_web_tagger
# Out:
# BertEmbeddingsWebTagger(input_layers=('sentences',), output_layer=bert_embeddings, output_attributes=('token', 'bert_embedding'), url=https://api.tartunlp.ai/estnltk/tagger/bert)

# %%
bert_embeddings_web_tagger.about
# Out:
# 'Tags BERT embeddings using EstNLTK 1.6.7beta webservice.'

# %%
bert_embeddings_web_tagger.status
# Out:
# 'OK'

# %%
bert_embeddings_web_tagger.is_alive
# Out:
# True

# %%
# Create a text and add required layers
text = Text('See on lause.')
text.tag_layer('sentences')
# Out:
# Text(text='See on lause.')

# %%
# Add bert embeddings
bert_embeddings_web_tagger.tag(text)
text.bert_embeddings
# Out:
# Layer(name='bert_embeddings', attributes=('token', 'bert_embedding'), spans=SL[Span('See', [{'token': 'see', 'bert_embedding': [0.25575265288352966, -0.05085913464426994, -0.1655101180076599, 0.23147141933441162, 0.5238826870918274, 0.27179154753685, -0.3147072196006775, -0.36876288056373596, 0.21627399325370789, -0.07609765976667404, -1.3708900213241577, 0.27975037693977356, -1.1392385959625244, 0.3960719704627991, 0.28791162371635437, 0.6277047395706177, 0.8617496490478516, 0.039834775030612946, 0.5807466506958008, -0.6618019342422485, 0.2934400141239166, -0.024531202390789986, 0.311393678188324, -0.48999810218811035, 0.11727263778448105, 0.03186161071062088, -0.029331887140870094, 0.0636613667011261, -0.26731058955192566, 0.36866435408592224, -0.38711464405059814, -0.6686874032020569, -0.5005266070365906, 0.32181400060653687, 0.6489686369895935, -0.6957122683525085, -0.6045283675193787, -0.2692183554172516, 0.17446748912334442, -0.22357331216335297, -0.04265381768345833, 0.24407310783863068, 0.010399345308542252, -0.20399326086044312, 0.2015470564365387, -0.15173684060573578, -0.05529721453785896, -0.2626141905784607, 0.4838610291481018, 0.06742721796035767, -0.2977001368999481, -0.7872076630592346, -0.419034868478775, -0.06608255207538605, -0.7486124634742737, 0.2529585659503937, -0.3021761476993561, 0.7171535491943359, -0.2766784131526947, 0.29585981369018555, -0.036211900413036346, 0.17233584821224213, -0.3123025894165039, 0.18278929591178894, -0.20547816157341003, 0.4066270589828491, 0.3325727880001068, 0.2515612840652466, 0.26012957096099854, 0.5885208249092102, -0.46025025844573975, 0.12894701957702637, -0.18308502435684204, -0.24879632890224457, 0.011194083839654922, -0.5595483779907227, -0.001993502490222454, 0.5095421671867371, 0.6745308637619019, -0.053495634347200394, 0.34418293833732605, 0.2804965674877167, -0.8647330403327942, 0.043874792754650116, 0.16086211800575256, -0.4046522378921509, -0.13133996725
, -0.2643401324748993, 0.20597198605537415, -0.014529579319059849, 0.063259556889534, 0.1166195422410965, 0.12052088975906372, 0.13170810043811798, -0.042762212455272675, -0.0305098257958889, -0.08136523514986038, 0.2931649684906006, -0.39323240518569946, 0.3371182978153229, -0.36697280406951904, -0.2264539897441864, 0.005707785952836275, -0.02111886814236641, 0.007159097585827112, 0.2988021969795227, -0.14358003437519073, 0.03197990730404854, 0.34165969491004944, 0.09145448356866837, 0.07423184812068939, -0.016496749594807625, 0.07410449534654617, -0.2241714894771576, -0.336381733417 ...

# %% [markdown]
# Notes:
#
#    * `BertEmbeddingsWebTagger`'s webservice employs a request size limit: you can process `Text` objects that contain 125 words at maximum. If your text is larger, please use EstNLTK\'s functions `extract_sections` or `split_by` to split the `Text` object into smaller `Text`-s before processing. More information about splitting:             [https://github.com/estnltk/estnltk/blob/version_1.6/tutorials/system/layer_operations.ipynb](https://github.com/estnltk/estnltk/blob/version_1.6/tutorials/system/layer_operations.ipynb)
#
#
#    * `BertTagger` uses a tokenization that diverges from EstNLTK's default tokenization. For details, see the tutorial: https://github.com/estnltk/estnltk/blob/version_1.6/tutorials/taggers/embeddings_tagger.ipynb

# %% [markdown]
# ## StanzaSyntaxWebTagger
#
# Tags dependency syntactic analysis using EstNLTK `StanzaSyntaxTagger`'s webservice.

# %%
from estnltk.taggers import StanzaSyntaxWebTagger
stanza_syntax_web_tagger = \
    StanzaSyntaxWebTagger(url='https://api.tartunlp.ai/estnltk/tagger/stanza_syntax')
stanza_syntax_web_tagger
# Out:
# StanzaSyntaxWebTagger(input_layers=('words', 'sentences', 'morph_extended'), output_layer=stanza_syntax, output_attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc'), url=https://api.tartunlp.ai/estnltk/tagger/stanza_syntax)

# %%
# Create Text and add required input layers
from estnltk import Text
text = Text('Ilus suur karvane kass nurrus rohelisel diivanil.').tag_layer('morph_extended')
# Tag syntax with web_tagger
stanza_syntax_web_tagger.tag( text )
text.stanza_syntax
# Out:
# Layer(name='stanza_syntax', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc'), spans=SL[Span('Ilus', [{'id': 1, 'lemma': 'ilus', 'upostag': 'A', 'xpostag': 'A', 'feats': {'nom': 'nom', 'pos': 'pos', 'sg': 'sg'}, 'head': 4, 'deprel': 'amod', 'deps': '_', 'misc': '_'}]),
# Span('suur', [{'id': 2, 'lemma': 'suur', 'upostag': 'A', 'xpostag': 'A', 'feats': {'nom': 'nom', 'pos': 'pos', 'sg': 'sg'}, 'head': 4, 'deprel': 'amod', 'deps': '_', 'misc': '_'}]),
# Span('karvane', [{'id': 3, 'lemma': 'karvane', 'upostag': 'A', 'xpostag': 'A', 'feats': {'nom': 'nom', 'pos': 'pos', 'sg': 'sg'}, 'head': 4, 'deprel': 'amod', 'deps': '_', 'misc': '_'}]),
# Span('kass', [{'id': 4, 'lemma': 'kass', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'nom': 'nom', 'sg': 'sg'}, 'head': 5, 'deprel': 'nsubj', 'deps': '_', 'misc': '_'}]),
# Span('nurrus', [{'id': 5, 'lemma': 'nurruma', 'upostag': 'V', 'xpostag': 'V', 'feats': {'af': 'af', 'aux': 'aux', 'impf': 'impf', 'indic': 'indic', 'ps': 'ps', 'ps3': 'ps3', 'sg': 'sg'}, 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_'}]),
# Span('rohelisel', [{'id': 6, 'lemma': 'roheline', 'upostag': 'A', 'xpostag': 'A', 'feats': {'ad': 'ad', 'pos': 'pos', 'sg': 'sg'}, 'head': 7, 'deprel': 'amod', 'deps': '_', 'misc': '_'}]),
# Span('diivanil', [{'id': 7, 'lemma': 'diivan', 'upostag': 'S', 'xpostag': 'S', 'feats': {'ad': 'ad', 'com': 'com', 'sg': 'sg'}, 'head': 5, 'deprel': 'obl', 'deps': '_', 'misc': '_'}]),
# Span('.', [{'id': 8, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': {}, 'head': 5, 'deprel': 'punct', 'deps': '_', 'misc': '_'}])])

# %% [markdown]
# ## StanzaSyntaxEnsembleWebTagger
#
# Tags dependency syntactic analysis using EstNLTK `StanzaSyntaxEnsembleWebTagger`'s webservice.

# %%
from estnltk.taggers import StanzaSyntaxEnsembleWebTagger
stanza_syntax_ensemble_web_tagger = \
    StanzaSyntaxEnsembleWebTagger(url='https://api.tartunlp.ai/estnltk/tagger/stanza_syntax_ensemble')
stanza_syntax_ensemble_web_tagger
# Out:
# StanzaSyntaxEnsembleWebTagger(input_layers=('words', 'sentences', 'morph_extended'), output_layer=stanza_ensemble_syntax, output_attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc'), url=https://api.tartunlp.ai/estnltk/tagger/stanza_syntax_ensemble)

# %%
# Create Text and add required input layers
from estnltk import Text
text = Text('Ilus suur karvane kass nurrus rohelisel diivanil.').tag_layer('morph_extended')
# Tag syntax with web_tagger
stanza_syntax_ensemble_web_tagger.tag( text )
text.stanza_ensemble_syntax
# Out:
# Layer(name='stanza_ensemble_syntax', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc'), spans=SL[Span('Ilus', [{'id': 1, 'lemma': 'ilus', 'upostag': 'A', 'xpostag': 'A', 'feats': {'nom': 'nom', 'pos': 'pos', 'sg': 'sg'}, 'head': 4, 'deprel': 'amod', 'deps': '_', 'misc': '_'}]),
# Span('suur', [{'id': 2, 'lemma': 'suur', 'upostag': 'A', 'xpostag': 'A', 'feats': {'nom': 'nom', 'pos': 'pos', 'sg': 'sg'}, 'head': 4, 'deprel': 'amod', 'deps': '_', 'misc': '_'}]),
# Span('karvane', [{'id': 3, 'lemma': 'karvane', 'upostag': 'A', 'xpostag': 'A', 'feats': {'nom': 'nom', 'pos': 'pos', 'sg': 'sg'}, 'head': 4, 'deprel': 'amod', 'deps': '_', 'misc': '_'}]),
# Span('kass', [{'id': 4, 'lemma': 'kass', 'upostag': 'S', 'xpostag': 'S', 'feats': {'com': 'com', 'nom': 'nom', 'sg': 'sg'}, 'head': 5, 'deprel': 'nsubj', 'deps': '_', 'misc': '_'}]),
# Span('nurrus', [{'id': 5, 'lemma': 'nurruma', 'upostag': 'V', 'xpostag': 'V', 'feats': {'af': 'af', 'impf': 'impf', 'indic': 'indic', 'mod': 'mod', 'ps': 'ps', 'ps3': 'ps3', 'sg': 'sg'}, 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_'}]),
# Span('rohelisel', [{'id': 6, 'lemma': 'roheline', 'upostag': 'A', 'xpostag': 'A', 'feats': {'ad': 'ad', 'pos': 'pos', 'sg': 'sg'}, 'head': 7, 'deprel': 'amod', 'deps': '_', 'misc': '_'}]),
# Span('diivanil', [{'id': 7, 'lemma': 'diivan', 'upostag': 'S', 'xpostag': 'S', 'feats': {'ad': 'ad', 'com': 'com', 'sg': 'sg'}, 'head': 5, 'deprel': 'obl', 'deps': '_', 'misc': '_'}]),
# Span('.', [{'id': 8, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': {}, 'head': 5, 'deprel': 'punct', 'deps': '_', 'misc': '_'}])])

# %% [markdown]
# Note:
#
#    * `StanzaSyntaxWebTagger`'s and `StanzaSyntaxEnsembleWebTagger`'s webservices employ a request size limit: you can process `Text` objects that contain 125 words at maximum. If your text is larger, please use EstNLTK\'s functions `extract_sections` or `split_by` to split the `Text` object into smaller `Text`-s before processing. More information about splitting:             [https://github.com/estnltk/estnltk/blob/version_1.6/tutorials/system/layer_operations.ipynb](https://github.com/estnltk/estnltk/blob/version_1.6/tutorials/system/layer_operations.ipynb)

# %% [markdown]
# ## Other web-taggers
#
# Before using the following web taggers, you first need to [create a hosting webservice](https://github.com/estnltk/webtagger-service).

# %% [markdown]
# ## VabamorfWebTagger
#
# See also documentation for `VabamorfTagger`.

# %%
from estnltk.taggers import VabamorfWebTagger
vabamorph_web_tagger = VabamorfWebTagger(url='http://127.0.0.1:5000/1.6.7beta/tag/morph_analysis')
vabamorph_web_tagger
# Out:
# VabamorfWebTagger(input_layers=('words', 'sentences', 'compound_tokens'), output_layer=morph_analysis, output_attributes=('normalized_text', 'lemma', 'root', 'root_tokens', 'ending', 'clitic', 'form', 'partofspeech'), url=http://127.0.0.1:5000/1.6.7beta/tag/morph_analysis)

# %%
vabamorph_web_tagger.about
# Out:
# 'Tags morphological analysis using EstNLTK 1.6.7beta webservice.'

# %%
vabamorph_web_tagger.status
# Out:
# 'OK'

# %%
vabamorph_web_tagger.is_alive
# Out:
# True

# %%
text = Text('See on lause.')
text.tag_layer(['sentences'])

vabamorph_web_tagger.tag(text)

text.pop_layer('tokens')

text
# Out:
# Text(text='See on lause.')

# %% [markdown]
# ## SoftmaxEmbTagSumWebTagger
#
# See also documentation for `SoftmaxEmbTagSumTagger`.

# %%
from estnltk.taggers import SoftmaxEmbTagSumWebTagger

text = Text("See on lause.")
text.tag_layer(['morph_analysis'])
        
softmax_emb_tag_sum_web_tagger = SoftmaxEmbTagSumWebTagger(
    url='http://127.0.0.1:5000/1.6.7beta/tag/morph_softmax_emb_tag_sum',
    output_layer='softmax_emb_tag_sum')
softmax_emb_tag_sum_web_tagger
# Out:
# SoftmaxEmbTagSumWebTagger(input_layers=('morph_analysis', 'sentences', 'words'), output_layer=softmax_emb_tag_sum, output_attributes=('morphtag', 'pos', 'form'), url=http://127.0.0.1:5000/1.6.7beta/tag/morph_softmax_emb_tag_sum)

# %%
softmax_emb_tag_sum_web_tagger.tag(text)
text.softmax_emb_tag_sum
# Out:
# Layer(name='softmax_emb_tag_sum', attributes=('morphtag', 'pos', 'form'), spans=SL[Span('See', [{'morphtag': 'POS=P|NUMBER=sg|CASE=nom', 'pos': 'P', 'form': 'sg n'}]),
# Span('on', [{'morphtag': 'POS=V|VERB_TYPE=main|MOOD=indic|TENSE=pres|PERSON=ps3|NUMBER=sg|VERB_PS=ps|VERB_POLARITY=af', 'pos': 'V', 'form': 'b'}]),
# Span('lause', [{'morphtag': 'POS=S|NOUN_TYPE=com|NUMBER=sg|CASE=nom', 'pos': 'S', 'form': 'sg n'}]),
# Span('.', [{'morphtag': 'POS=Z|PUNCT_TYPE=Fst', 'pos': 'Z', 'form': ''}])])
