# %% [markdown]
# # MergeTagger

# %%
from estnltk.text import Span, Layer, Text
from estnltk.taggers import MergeTagger

# %%
text = Text('Tere, maailm!')

layer = Layer(name='test_1',
              attributes=['attr_1']
             )
span = Span(start=0, end=4)
span.attr_1 = 'TERE'
layer.add_span(span)

span = Span(start=6, end=12)
span.attr_1 = 'MAAILM'
layer.add_span(span)

#span = Span(start=9, end=12)
#span.attr_1 = 'MaaIlm'
#layer.add_span(span)

text['test_1'] = layer
text.test_1
# Out:
# Layer(name=test_1, spans=SL[Span(Tere, {'attr_1': 'TERE'}),
# Span(maailm, {'attr_1': 'MAAILM'})])

# %%
layer = Layer(name='test_2',
              attributes=['attr_2']
              )
span = Span(start=4, end=5)
span.attr_2 = 'comma'
layer.add_span(span)

#span = Span(start=6, end=9)
#span.attr_2 = 'MAA'
#layer.add_span(span)

span = Span(start=12, end=13)
span.attr_2 = 'exclamation'
layer.add_span(span)

text['test_2'] = layer
text.test_2
# Out:
# Layer(name=test_2, spans=SL[Span(,, {'attr_2': 'comma'}),
# Span(!, {'attr_2': 'exclamation'})])

# %%
merge_tagger = MergeTagger(output_layer='merged',
                           input_layers=['test_1', 'test_2'],
                           output_attributes=['attr_1','attr_2'])
merge_tagger
# Out:
# MergeTagger()

# %%
merge_tagger.tag(text)
text
# Out:
# Text(text="Tere, maailm!")

# %%
text.merged
# Out:
# Layer(name=merged, spans=SL[Span(Tere, {'attr_1': 'TERE', 'attr_2': None}),
# Span(,, {'attr_1': None, 'attr_2': 'comma'}),
# Span(maailm, {'attr_1': 'MAAILM', 'attr_2': None}),
# Span(!, {'attr_1': None, 'attr_2': 'exclamation'})])
