# %% [markdown]
# # DiffTagger

# %%
from estnltk.taggers import DiffTagger

diff_tagger = DiffTagger(layer_a='layer_5',
                         layer_b='layer_5_new',
                         output_layer='diff_layer',
                         output_attributes=('input_layer_name', 'attr', 'attr_5'),
                         input_layer_name_attribute='input_layer_name')
diff_tagger
# Out:
# DiffTagger(input_layers=('layer_5', 'layer_5_new'), output_layer=diff_layer, output_attributes=('input_layer_name', 'attr', 'attr_5'), input_layer_name_attribute=input_layer_name)

# %% [markdown]
# Ambiguous envelopoing demo layer.

# %%
from estnltk.tests import new_text
text = new_text(5)
layer_5 = text.layer_5
layer_5
# Out:
# Layer(name=layer_5, spans=SL[AS[Annotation(Sada kaks, {'attr': 'L5-0-0', 'attr_5': 'SADA KAKS'})],
# AS[Annotation(Sada kakskümmend, {'attr': 'L5-1-1', 'attr_5': 'SADA KAKS'}), Annotation(Sada kakskümmend, {'attr': 'L5-1-2', 'attr_5': 'SADA KÜMME'}), Annotation(Sada kakskümmend, {'attr': 'L5-1-3', 'attr_5': 'SADA KAKSKÜMMEND'})],
# AS[Annotation(Sada kakskümmend kolm, {'attr': 'L5-2-4', 'attr_5': 'SADA KAKSKÜMMEND KOLM'})],
# AS[Annotation( Neli tuhat, {'attr': 'L5-3-5', 'attr_5': 'NELI TUHAT'})],
# AS[Annotation(tuhat viis, {'attr': 'L5-4-6', 'attr_5': 'TUHAT VIIS'})],
# AS[Annotation(viis, {'attr': 'L5-5-7', 'attr_5': 'VIIS'})],
# AS[Annotation(viissada kuuskümmend, {'attr': 'L5-6-8', 'attr_5': 'VIISSADA KUUS'}), Annotation(viissada kuuskümmend, {'attr': 'L5-6-9', 'attr_5': 'VIISSADA KÜMME'}), Annotation(viissada kuuskümmend, {'attr': 'L5-6-10', 'attr_5': 'VIISSADA KUUSKÜMMEND'})],
# AS[Annotation(kümmend seitse koma kaheksa, {'attr': 'L5-7-11', 'attr_5': 'KÜMME KOMA KAHEKSA'})],
# AS[Annotation(seitse koma kaheksa, {'attr': 'L5-8-12', 'attr_5': 'SEITSE KOMA KAHEKSA'})]])

# %% [markdown]
# Copy and change demo layer.

# %%
from estnltk.layer_operations import merge_layers

layer_5_new = merge_layers(layers=[layer_5],
                           output_layer='layer_5_new',
                           output_attributes=['attr', 'attr_5'])

layer_5_new[1][0].attr_5 = 'sada kaks'
del layer_5_new.spans[3]
del layer_5_new.spans[5].spans[1]
text['layer_5_new'] = layer_5_new
layer_5_new
# Out:
# Layer(name=layer_5_new, spans=SL[AS[Annotation(Sada kaks, {'attr': 'L5-0-0', 'attr_5': 'SADA KAKS'})],
# AS[Annotation(Sada kakskümmend, {'attr': 'L5-1-1', 'attr_5': 'sada kaks'}), Annotation(Sada kakskümmend, {'attr': 'L5-1-2', 'attr_5': 'SADA KÜMME'}), Annotation(Sada kakskümmend, {'attr': 'L5-1-3', 'attr_5': 'SADA KAKSKÜMMEND'})],
# AS[Annotation(Sada kakskümmend kolm, {'attr': 'L5-2-4', 'attr_5': 'SADA KAKSKÜMMEND KOLM'})],
# AS[Annotation(tuhat viis, {'attr': 'L5-4-6', 'attr_5': 'TUHAT VIIS'})],
# AS[Annotation(viis, {'attr': 'L5-5-7', 'attr_5': 'VIIS'})],
# AS[Annotation(viissada kuuskümmend, {'attr': 'L5-6-8', 'attr_5': 'VIISSADA KUUS'}), Annotation(viissada kuuskümmend, {'attr': 'L5-6-10', 'attr_5': 'VIISSADA KUUSKÜMMEND'})],
# AS[Annotation(kümmend seitse koma kaheksa, {'attr': 'L5-7-11', 'attr_5': 'KÜMME KOMA KAHEKSA'})],
# AS[Annotation(seitse koma kaheksa, {'attr': 'L5-8-12', 'attr_5': 'SEITSE KOMA KAHEKSA'})]])

# %% [markdown]
# Create and show layer of differences.

# %%
diff_tagger(text).diff_layer
# Out:
# Layer(name=diff_layer, spans=SL[AS[Annotation(Sada kakskümmend, {'attr': 'L5-1-1', 'attr_5': 'SADA KAKS', 'input_layer_name': 'layer_5'}), Annotation(Sada kakskümmend, {'attr': 'L5-1-2', 'attr_5': 'SADA KÜMME', 'input_layer_name': 'layer_5'}), Annotation(Sada kakskümmend, {'attr': 'L5-1-3', 'attr_5': 'SADA KAKSKÜMMEND', 'input_layer_name': 'layer_5'}), Annotation(Sada kakskümmend, {'attr': 'L5-1-1', 'attr_5': 'sada kaks', 'input_layer_name': 'layer_5_new'}), Annotation(Sada kakskümmend, {'attr': 'L5-1-2', 'attr_5': 'SADA KÜMME', 'input_layer_name': 'layer_5_new'}), Annotation(Sada kakskümmend, {'attr': 'L5-1-3', 'attr_5': 'SADA KAKSKÜMMEND', 'input_layer_name': 'layer_5_new'})],
# AS[Annotation( Neli tuhat, {'attr': 'L5-3-5', 'attr_5': 'NELI TUHAT', 'input_layer_name': 'layer_5'})],
# AS[Annotation(viissada kuuskümmend, {'attr': 'L5-6-8', 'attr_5': 'VIISSADA KUUS', 'input_layer_name': 'layer_5'}), Annotation(viissada kuuskümmend, {'attr': 'L5-6-9', 'attr_5': 'VIISSADA KÜMME', 'input_layer_name': 'layer_5'}), Annotation(viissada kuuskümmend, {'attr': 'L5-6-10', 'attr_5': 'VIISSADA KUUSKÜMMEND', 'input_layer_name': 'layer_5'}), Annotation(viissada kuuskümmend, {'attr': 'L5-6-8', 'attr_5': 'VIISSADA KUUS', 'input_layer_name': 'layer_5_new'}), Annotation(viissada kuuskümmend, {'attr': 'L5-6-10', 'attr_5': 'VIISSADA KUUSKÜMMEND', 'input_layer_name': 'layer_5_new'})]])
