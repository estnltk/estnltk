# %% [markdown]
# # Export Text object to dict

# %% [markdown]
# ## Structure of the dict representation of the Text object
# ```python
# {
# # raw text
# 'text': ___,
# # records of layers in order of dependences
# 'layers': [
#            {
#             # simple layer
#             'name': ___,
#             'attributes': ['attr_1', ...],
#             'parent': None,
#             'enveloping': None,
#             'ambiguous': False,
#             'spans': [
#                       {'start': ___, 'end': ___, 'attr_1':___, ...},
#                       {'start': ___, 'end': ___, 'attr_1':___, ...},
#                       ...
#                      ]
#            },
#            {
#             # parent, not ambiguous
#             'name': ___,
#             'attributes': ['attr_1', ...],
#             'parent': '___',
#             'enveloping': None,
#             'ambiguous': True,
#             'spans': [
#                       {'_index_': _, 'attr_1':___, ...},
#                       {'_index_': _, 'attr_1':___, ...},
#                       ...
#                      ]
#            },
#            {
#             # parent, ambiguous
#             'name': ___,
#             'attributes': ['attr_1', ...],
#             'parent': '___',
#             'enveloping': None,
#             'ambiguous': True,
#             'spans': [
#                       [{'_index_': _, 'attr_1':___, ...},
#                        {'_index_': _, 'attr_1':___, ...},
#                        ...
#                       ],
#                       ...
#                      ]
#            },
#            {
#             # enveloping, not ambiguous
#             'name': ___,
#             'attributes': ['attr_1', ...],
#             'parent': None,
#             'enveloping': '___',
#             'ambiguous': False,
#             'spans': [
#                       {'_index_': [_, ...], 'attr_1':___, ...},
#                       {'_index_': [_, ...], 'attr_1':___, ...},
#                       ...
#                      ]
#            },
#            {
#             # enveloping, ambiguous
#             'name': ___,
#             'attributes': ['attr_1', ...],
#             'parent': None,
#             'enveloping': '___',
#             'ambiguous': True,
#             'spans': [
#                       [
#                        {'_index_': [_, ...], 'attr_1':___, ...},
#                        {'_index_': [_, ...], 'attr_1':___, ...},
#                        ...
#                       ],
#                       [
#                        {'_index_': [_, ...], 'attr_1':___, ...},
#                        {'_index_': [_, ...], 'attr_1':___, ...},
#                        ...
#                       ],
#                       ...
#                      ]
#            }
#           ]
# }
# ```

# %%
def layer_to_dict(layer, text):
    assert '_index_' not in layer.attributes
    layer_dict = {'name':layer.name,
                  'attributes': layer.attributes,
                  'parent': layer.parent,
                  'enveloping': layer.enveloping,
                  'ambiguous': layer.ambiguous,
                  'spans': []}
    if layer.parent:
        parent_spanlist = text[layer.parent].spans
        records = layer.to_records()
        for span, record in zip(layer, records):
            index = parent_spanlist.index(span)
            if layer.ambiguous:
                for rec in record:
                    rec['_index_'] = index
            else:
                record['_index_'] = index
            layer_dict['spans'].append(record)
    elif layer.enveloping:
        enveloped_spanlist = text[layer.enveloping].spans
        
        records = []
        for spanlist in layer:
            index = [enveloped_spanlist.index(span) for span in spanlist]
            if layer.ambiguous:
                pass
                # TODO:
            else:
                record = {attr:getattr(spanlist, attr) for attr in layer.attributes}
                record['_index_'] = index
                records.append(record)
        layer_dict['spans'] = records
    else:
        layer_dict['spans'] = layer.to_records()
    
    return layer_dict


def export_dict(text):
    text_dict = {'text':text.text, 'layers':[]}
    for layer in text.list_layers():
        text_dict['layers'].append(layer_to_dict(layer, text))
    return text_dict

# %%
from estnltk import Text
text = Text('''Mis aias sa-das 2te sorti s-saia? Teine lause.

Teine lõik.''')
text.tag_layer(['morph_analysis', 'paragraphs'])
export_dict(text)
# Out:
# {'layers': [{'ambiguous': False,
#    'attributes': (),
#    'enveloping': None,
#    'name': 'tokens',
#    'parent': None,
#    'spans': [{'end': 3, 'start': 0},
#     {'end': 8, 'start': 4},
#     {'end': 11, 'start': 9},
#     {'end': 12, 'start': 11},
#     {'end': 15, 'start': 12},
#     {'end': 19, 'start': 16},
#     {'end': 25, 'start': 20},
#     {'end': 27, 'start': 26},
#     {'end': 28, 'start': 27},
#     {'end': 32, 'start': 28},
#     {'end': 33, 'start': 32},
#     {'end': 39, 'start': 34},
#     {'end': 45, 'start': 40},
#     {'end': 46, 'start': 45},
#     {'end': 53, 'start': 48},
#     {'end': 58, 'start': 54},
#     {'end': 59, 'start': 58}]},
#   {'ambiguous': False,
#    'attributes': ['type', 'normalized'],
#    'enveloping': 'tokens',
#    'name': 'compound_tokens',
#    'parent': None,
#    'spans': [{'_index_': [2, 3, 4], 'normalized': None, 'type': 'hyphenation'},
#     {'_index_': [7, 8, 9], 'normalized': None, 'type': 'hyphenation'}]},
#   {'ambiguous': False,
#    'attributes': (),
#    'enveloping': None,
#    'name': 'words',
#    'parent': None,
#    'spans': [{'end': 3, 'start': 0},
#     {'end': 8, 'start': 4},
#     {'end': 15, 'start': 9},
#     {'end': 19, 'start': 16},
#     {'end': 25, 'start': 20},
#     {'end': 32, 'start': 26},
#     {'end': 33, 'start': 32},
#     {'end': 39, 'start': 34},
#     {'end': 45, 'start': 40},
#     {'end': 46, 'start': 45},
#     {'end': 53, 'start': 48},
#     {'end': 58, 'start': 54},
#     {'end': 59, 'start': 58}]},
#   {'ambiguous': False,
#    'attributes': (),
#    'enveloping': 'words',
#    'name': 'sentences',
#    'parent': None,
#    'spans': [{'_index_': [0, 1, 2, 3, 4, 5, 6]},
#     {'_index_': [7, 8, 9]},
#     {'_index_': [10, 11, 12]}]},
#   {'ambiguous': False,
#    'attributes': (),
#    'enveloping': 'sentences',
#    'name': 'paragraphs',
#    'parent': None,
#    'spans': [{'_index_': [0, 1]}, {'_index_': [2]}]},
#   {'ambiguous': True,
#    'attributes': ['lemma',
#     'root',
#     'root_tokens',
#     'ending',
#     'clitic',
#     'form',
#     'partofspeech'],
#    'enveloping': None,
#    'name': 'morph_analysis',
#    'parent': 'words',
#    'spans': [[{'_index_': 0,
#       'clitic': '',
#       'end': 3,
#       'ending': '0',
#       'form': 'pl n',
#       'lemma': 'mis',
#       'partofspeech': 'P',
#       'root': 'mis',
#       'root_tokens': ('mis',),
#       'start': 0},
#      {'_index_': 0,
#       'clitic': '',
#       'end': 3,
#       'ending': '0',
#       'form': 'sg n',
#       'lemma': 'mis',
#       'partofspeech': 'P',
#       'root': 'mis',
#       'root_tokens': ('mis',),
#       'start': 0}],
#     [{'_index_': 1,
#       'clitic': '',
#       'end': 8,
#       'ending': 's',
#       'form': 'sg in',
#       'lemma': 'aed',
#       'partofspeech': 'S',
#       'root': 'aed',
#       'root_tokens': ('aed',),
#       'start': 4}],
#     [{'_index_': 2,
#       'clitic': '',
#       'end': 15,
#       'ending': 's',
#       'form': 's',
#       'lemma': 'sadama',
#       'partofspeech': 'V',
#       'root': 'sada',
#       'root_tokens': ('sada',),
#       'start': 9}],
#     [{'_index_': 3,
#       'clitic': '',
#       'end': 19,
#       'ending': 'te',
#       'form': 'pl g',
#       'lemma': '2.',
#       'partofspeech': 'O',
#       'root': '2.',
#       'root_tokens': ('2.',),
#       'start': 16},
#      {'_index_': 3,
#       'clitic': '',
#       'end': 19,
#       'ending': '0',
#       'form': 'adt',
#       'lemma': '2',
#       'partofspeech': 'N',
#       'root': '2',
#       'root_tokens': ('2',),
#       'start': 16},
#      {'_index_': 3,
#       'clitic': '',
#       'end': 19,
#       'ending': '0',
#       'form': 'sg p',
#       'lemma': '2',
#       'partofspeech': 'N',
#       'root': '2',
#       'root_tokens': ('2',),
#       'start': 16}],
#     [{'_index_': 4,
#       'clitic': '',
#       'end': 25,
#       'ending': '0',
#       'form': 'sg p',
#       'lemma': 'sort',
#       'partofspeech': 'S',
#       'root': 'sort',
#       'root_tokens': ('sort',),
#       'start': 20}],
#     [{'_index_': 5,
#       'clitic': '',
#       'end': 32,
#       'ending': '0',
#       'form': 'sg p',
#       'lemma': 'sai',
#       'partofspeech': 'S',
#       'root': 'sai',
#       'root_tokens': ('sai',),
#       'start': 26}],
#     [{'_index_': 6,
#       'clitic': '',
#       'end': 33,
#       'ending': '',
#       'form': '',
#       'lemma': '?',
#       'partofspeech': 'Z',
#       'root': '?',
#       'root_tokens': ('?',),
#       'start': 32}],
#     [{'_index_': 7,
#       'clitic': '',
#       'end': 39,
#       'ending': '0',
#       'form': 'sg n',
#       'lemma': 'teine',
#       'partofspeech': 'O',
#       'root': 'teine',
#       'root_tokens': ('teine',),
#       'start': 34},
#      {'_index_': 7,
#       'clitic': '',
#       'end': 39,
#       'ending': '0',
#       'form': 'sg n',
#       'lemma': 'teine',
#       'partofspeech': 'P',
#       'root': 'teine',
#       'root_tokens': ('teine',),
#       'start': 34}],
#     [{'_index_': 8,
#       'clitic': '',
#       'end': 45,
#       'ending': '0',
#       'form': 'sg n',
#       'lemma': 'lause',
#       'partofspeech': 'S',
#       'root': 'lause',
#       'root_tokens': ('lause',),
#       'start': 40}],
#     [{'_index_': 9,
#       'clitic': '',
#       'end': 46,
#       'ending': '',
#       'form': '',
#       'lemma': '.',
#       'partofspeech': 'Z',
#       'root': '.',
#       'root_tokens': ('.',),
#       'start': 45}],
#     [{'_index_': 10,
#       'clitic': '',
#       'end': 53,
#       'ending': '0',
#       'form': 'sg n',
#       'lemma': 'teine',
#       'partofspeech': 'O',
#       'root': 'teine',
#       'root_tokens': ('teine',),
#       'start': 48},
#      {'_index_': 10,
#       'clitic': '',
#       'end': 53,
#       'ending': '0',
#       'form': 'sg n',
#       'lemma': 'teine',
#       'partofspeech': 'P',
#       'root': 'teine',
#       'root_tokens': ('teine',),
#       'start': 48}],
#     [{'_index_': 11,
#       'clitic': '',
#       'end': 58,
#       'ending': '0',
#       'form': 'sg n',
#       'lemma': 'lõik',
#       'partofspeech': 'S',
#       'root': 'lõik',
#       'root_tokens': ('lõik',),
#       'start': 54}],
#     [{'_index_': 12,
#       'clitic': '',
#       'end': 59,
#       'ending': '',
#       'form': '',
#       'lemma': '.',
#       'partofspeech': 'Z',
#       'root': '.',
#       'root_tokens': ('.',),
#       'start': 58}]]},
#   {'ambiguous': False,
#    'attributes': ['normal'],
#    'enveloping': None,
#    'name': 'normalized_words',
#    'parent': 'words',
#    'spans': [{'_index_': 2, 'end': 15, 'normal': 'sadas', 'start': 9},
#     {'_index_': 5, 'end': 32, 'normal': 'saia', 'start': 26}]}],
#  'text': 'Mis aias sa-das 2te sorti s-saia? Teine lause.\n\nTeine lõik.'}
