# %% [markdown]
# # Syntax preprocessing taggers, rewriters and exporter
#
# |tagger|rewriters|source attributes|target attributes|values|
# |------|---------|-----------------|-----------------|------|
# ||PunctuatinonTypeRewriter|partofspeech, root|punctuation_type|```None```, 'Fst', 'Com', 'Col', ... |
# ||MorphToSyntaxMorphRewriter|partofspeech, form|partofspeech, form||
# |PronounTypeTagger|PronounTypeRewriter|root, ending, clitic, partofspeech|pronoun_type| ```None```, ('det',), ('pers ps3',), ('pos', 'det', 'refl'), ... |
# ||RemoveDuplicateAnalysesRewriter|root, ending, clitic, partofspeech, form|||
# ||RemoveAdpositionAnalysesRewriter|partofspeech, form|||
# ||LetterCaseRewriter|word_text|cap|```None```, 'cap'|
# |FiniteFormTagger|MorphToSyntaxMorphRewriter, FiniteFormRewriter|partofspeech, form|fin|```None```, ```True```, ```False```|
# |VerbExtensionSuffixTagger|VerbExtensionSuffixRewriter|root|verb_extension_suffix|```None```,'tud','nud','mine','nu','tu','v','tav','mata','ja'|
# |SubcatTagger|MorphToSyntaxMorphRewriter, SubcatRewriter|root, partofspeech, form|subcat|```None```, 'Intr', 'Part', 'gen', ...|
# |MorphExtendedTagger|PunctuatinonTypeRewriter, MorphToSyntaxMorphRewriter, PronounTypeRewriter, RemoveDuplicateAnalysesRewriter, RemoveAdpositionAnalysesRewriter, LetterCaseRewriter, FiniteFormRewriter, VerbExtensionSuffixRewriter, SubcatRewriter|root, ending, clitic, partofspeech, form|partofspeech, form, punctuation_type, pronoun_type, cap, fin, verb_extension_suffix, subcat ||

# %%
from estnltk import Text

# %% [markdown]
# ## PronounTypeTagger

# %%
from estnltk.taggers import PronounTypeTagger

tagger = PronounTypeTagger()
text = Text('Kumb, sina või mina?').tag_layer()
tagger.tag(text)
text['pronoun_type']
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>lemma</th>
#       <th>root</th>
#       <th>root_tokens</th>
#       <th>ending</th>
#       <th>clitic</th>
#       <th>form</th>
#       <th>partofspeech</th>
#       <th>pronoun_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Kumb</td>
#       <td>kumb</td>
#       <td>kumb</td>
#       <td>(kumb,)</td>
#       <td>0</td>
#       <td></td>
#       <td>sg n</td>
#       <td>P</td>
#       <td>[rel]</td>
#     </tr>
#     <tr>
#       <td>,</td>
#       <td>,</td>
#       <td>,</td>
#       <td>(,,)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>Z</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>sina</td>
#       <td>sina</td>
#       <td>sina</td>
#       <td>(sina,)</td>
#       <td>0</td>
#       <td></td>
#       <td>sg n</td>
#       <td>P</td>
#       <td>[ps2]</td>
#     </tr>
#     <tr>
#       <td>või</td>
#       <td>või</td>
#       <td>või</td>
#       <td>(või,)</td>
#       <td>0</td>
#       <td></td>
#       <td></td>
#       <td>J</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>mina</td>
#       <td>mina</td>
#       <td>mina</td>
#       <td>(mina,)</td>
#       <td>0</td>
#       <td></td>
#       <td>sg n</td>
#       <td>S</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>?</td>
#       <td>?</td>
#       <td>?</td>
#       <td>(?,)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>Z</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## FiniteFormTagger

# %%
from estnltk.taggers import FiniteFormTagger

fsToSyntFulesFile = '../estnltk/rewriting/syntax_preprocessing/rules_files/tmorftrtabel.txt'

tagger = FiniteFormTagger(fs_to_synt_rules_file=fsToSyntFulesFile)
text = Text('laulma hüpelnud tantsija').tag_layer()
tagger.tag(text)
text['finite_form']
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>lemma</th>
#       <th>root</th>
#       <th>root_tokens</th>
#       <th>ending</th>
#       <th>clitic</th>
#       <th>form</th>
#       <th>partofspeech</th>
#       <th>fin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>laulma</td>
#       <td>laulma</td>
#       <td>laul</td>
#       <td>(laul,)</td>
#       <td>ma</td>
#       <td></td>
#       <td>mod sup ps ill</td>
#       <td>V</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>laulma</td>
#       <td>laul</td>
#       <td>(laul,)</td>
#       <td>ma</td>
#       <td></td>
#       <td>aux sup ps ill</td>
#       <td>V</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>laulma</td>
#       <td>laul</td>
#       <td>(laul,)</td>
#       <td>ma</td>
#       <td></td>
#       <td>main sup ps ill</td>
#       <td>V</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>hüpelnud</td>
#       <td>hüplema</td>
#       <td>hüple</td>
#       <td>(hüple,)</td>
#       <td>nud</td>
#       <td></td>
#       <td>mod indic impf ps neg</td>
#       <td>V</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüplema</td>
#       <td>hüple</td>
#       <td>(hüple,)</td>
#       <td>nud</td>
#       <td></td>
#       <td>mod partic past ps</td>
#       <td>V</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüplema</td>
#       <td>hüple</td>
#       <td>(hüple,)</td>
#       <td>nud</td>
#       <td></td>
#       <td>aux indic impf ps neg</td>
#       <td>V</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüplema</td>
#       <td>hüple</td>
#       <td>(hüple,)</td>
#       <td>nud</td>
#       <td></td>
#       <td>aux partic past ps</td>
#       <td>V</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüplema</td>
#       <td>hüple</td>
#       <td>(hüple,)</td>
#       <td>nud</td>
#       <td></td>
#       <td>main indic impf ps neg</td>
#       <td>V</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüplema</td>
#       <td>hüple</td>
#       <td>(hüple,)</td>
#       <td>nud</td>
#       <td></td>
#       <td>main partic past ps</td>
#       <td>V</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüpelnud</td>
#       <td>hüpel=nud</td>
#       <td>(hüpelnud,)</td>
#       <td>0</td>
#       <td></td>
#       <td>pos</td>
#       <td>A</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüpelnud</td>
#       <td>hüpel=nud</td>
#       <td>(hüpelnud,)</td>
#       <td>0</td>
#       <td></td>
#       <td>pos sg nom</td>
#       <td>A</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüpelnud</td>
#       <td>hüpel=nud</td>
#       <td>(hüpelnud,)</td>
#       <td>d</td>
#       <td></td>
#       <td>pos pl nom</td>
#       <td>A</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>tantsija</td>
#       <td>tantsija</td>
#       <td>tantsija</td>
#       <td>(tantsija,)</td>
#       <td>0</td>
#       <td></td>
#       <td>com sg nom</td>
#       <td>S</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## VerbExtensionSuffixTagger

# %%
from estnltk.taggers import VerbExtensionSuffixTagger

tagger = VerbExtensionSuffixTagger()
text = Text('Laulev hüpelnud tantsija').tag_layer()
tagger.tag(text)
text['verb_extension_suffix']
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>lemma</th>
#       <th>root</th>
#       <th>root_tokens</th>
#       <th>ending</th>
#       <th>clitic</th>
#       <th>form</th>
#       <th>partofspeech</th>
#       <th>verb_extension_suffix</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Laulev</td>
#       <td>laulev</td>
#       <td>laulev</td>
#       <td>(laulev,)</td>
#       <td>0</td>
#       <td></td>
#       <td>sg n</td>
#       <td>A</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td>hüpelnud</td>
#       <td>hüplema</td>
#       <td>hüple</td>
#       <td>(hüple,)</td>
#       <td>nud</td>
#       <td></td>
#       <td>nud</td>
#       <td>V</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüpelnud</td>
#       <td>hüpel=nud</td>
#       <td>(hüpelnud,)</td>
#       <td>0</td>
#       <td></td>
#       <td></td>
#       <td>A</td>
#       <td>[nud]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüpelnud</td>
#       <td>hüpel=nud</td>
#       <td>(hüpelnud,)</td>
#       <td>0</td>
#       <td></td>
#       <td>sg n</td>
#       <td>A</td>
#       <td>[nud]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>hüpelnud</td>
#       <td>hüpel=nud</td>
#       <td>(hüpelnud,)</td>
#       <td>d</td>
#       <td></td>
#       <td>pl n</td>
#       <td>A</td>
#       <td>[nud]</td>
#     </tr>
#     <tr>
#       <td>tantsija</td>
#       <td>tantsija</td>
#       <td>tantsija</td>
#       <td>(tantsija,)</td>
#       <td>0</td>
#       <td></td>
#       <td>sg n</td>
#       <td>S</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## SubcatTagger

# %%
from estnltk.taggers import SubcatTagger

fsToSyntFulesFile = '../estnltk/rewriting/syntax_preprocessing/rules_files/tmorftrtabel.txt'
subcatFile = '../estnltk/rewriting/syntax_preprocessing/rules_files/abileksikon06utf.lx'

tagger = SubcatTagger(fs_to_synt_rules_file=fsToSyntFulesFile, 
                      subcat_rules_file=subcatFile)
text = Text('Järel juurduma').tag_layer()
tagger.tag(text)
text['subcat']
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>lemma</th>
#       <th>root</th>
#       <th>root_tokens</th>
#       <th>ending</th>
#       <th>clitic</th>
#       <th>form</th>
#       <th>partofspeech</th>
#       <th>subcat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Järel</td>
#       <td>järel</td>
#       <td>järel</td>
#       <td>(järel,)</td>
#       <td>0</td>
#       <td></td>
#       <td>post</td>
#       <td>K</td>
#       <td>[gen]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>järel</td>
#       <td>järel</td>
#       <td>(järel,)</td>
#       <td>0</td>
#       <td></td>
#       <td>pre</td>
#       <td>K</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>juurduma</td>
#       <td>juurduma</td>
#       <td>juurdu</td>
#       <td>(juurdu,)</td>
#       <td>ma</td>
#       <td></td>
#       <td>mod sup ps ill</td>
#       <td>V</td>
#       <td>[Intr]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>juurduma</td>
#       <td>juurdu</td>
#       <td>(juurdu,)</td>
#       <td>ma</td>
#       <td></td>
#       <td>aux sup ps ill</td>
#       <td>V</td>
#       <td>[Intr]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>juurduma</td>
#       <td>juurdu</td>
#       <td>(juurdu,)</td>
#       <td>ma</td>
#       <td></td>
#       <td>main sup ps ill</td>
#       <td>V</td>
#       <td>[Intr]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## MorphExtendedTagger

# %%
from estnltk.taggers import MorphExtendedTagger

fsToSyntFulesFile = '../estnltk/rewriting/syntax_preprocessing/rules_files/tmorftrtabel.txt'
subcat_file = '../estnltk/rewriting/syntax_preprocessing/rules_files/abileksikon06utf.lx'

tagger = MorphExtendedTagger(fs_to_synt_rules_file=fsToSyntFulesFile, 
                             allow_to_remove_all=False, 
                             subcat_rules_file=subcat_file)
text = Text('Ta on rääkinud!').tag_layer()
tagger.tag(text)
text['morph_extended']
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>word_text</th>
#       <th>lemma</th>
#       <th>root</th>
#       <th>ending</th>
#       <th>clitic</th>
#       <th>partofspeech</th>
#       <th>form</th>
#       <th>punctuation_type</th>
#       <th>pronoun_type</th>
#       <th>letter_case</th>
#       <th>fin</th>
#       <th>verb_extension_suffix</th>
#       <th>subcat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Ta</td>
#       <td>Ta</td>
#       <td>tema</td>
#       <td>tema</td>
#       <td>0</td>
#       <td></td>
#       <td>P</td>
#       <td>sg nom</td>
#       <td>None</td>
#       <td>[ps3]</td>
#       <td>cap</td>
#       <td>None</td>
#       <td>[]</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>on</td>
#       <td>on</td>
#       <td>olema</td>
#       <td>ole</td>
#       <td>0</td>
#       <td></td>
#       <td>V</td>
#       <td>mod indic pres ps3 sg ps af</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>True</td>
#       <td>[]</td>
#       <td>[Intr]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>on</td>
#       <td>olema</td>
#       <td>ole</td>
#       <td>0</td>
#       <td></td>
#       <td>V</td>
#       <td>aux indic pres ps3 sg ps af</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>True</td>
#       <td>[]</td>
#       <td>[Intr]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>on</td>
#       <td>olema</td>
#       <td>ole</td>
#       <td>0</td>
#       <td></td>
#       <td>V</td>
#       <td>main indic pres ps3 sg ps af</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>True</td>
#       <td>[]</td>
#       <td>[Intr]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>on</td>
#       <td>olema</td>
#       <td>ole</td>
#       <td>0</td>
#       <td></td>
#       <td>V</td>
#       <td>mod indic pres ps3 pl ps af</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>True</td>
#       <td>[]</td>
#       <td>[Intr]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>on</td>
#       <td>olema</td>
#       <td>ole</td>
#       <td>0</td>
#       <td></td>
#       <td>V</td>
#       <td>aux indic pres ps3 pl ps af</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>True</td>
#       <td>[]</td>
#       <td>[Intr]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>on</td>
#       <td>olema</td>
#       <td>ole</td>
#       <td>0</td>
#       <td></td>
#       <td>V</td>
#       <td>main indic pres ps3 pl ps af</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>True</td>
#       <td>[]</td>
#       <td>[Intr]</td>
#     </tr>
#     <tr>
#       <td>rääkinud</td>
#       <td>rääkinud</td>
#       <td>rääkima</td>
#       <td>rääki</td>
#       <td>nud</td>
#       <td></td>
#       <td>V</td>
#       <td>mod indic impf ps neg</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>True</td>
#       <td>[]</td>
#       <td>[Part-P, El]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>rääkinud</td>
#       <td>rääkima</td>
#       <td>rääki</td>
#       <td>nud</td>
#       <td></td>
#       <td>V</td>
#       <td>mod partic past ps</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>[]</td>
#       <td>[Part-P, El]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>rääkinud</td>
#       <td>rääkima</td>
#       <td>rääki</td>
#       <td>nud</td>
#       <td></td>
#       <td>V</td>
#       <td>aux indic impf ps neg</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>True</td>
#       <td>[]</td>
#       <td>[Part-P, El]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>rääkinud</td>
#       <td>rääkima</td>
#       <td>rääki</td>
#       <td>nud</td>
#       <td></td>
#       <td>V</td>
#       <td>aux partic past ps</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>[]</td>
#       <td>[Part-P, El]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>rääkinud</td>
#       <td>rääkima</td>
#       <td>rääki</td>
#       <td>nud</td>
#       <td></td>
#       <td>V</td>
#       <td>main indic impf ps neg</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>True</td>
#       <td>[]</td>
#       <td>[Part-P, El]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>rääkinud</td>
#       <td>rääkima</td>
#       <td>rääki</td>
#       <td>nud</td>
#       <td></td>
#       <td>V</td>
#       <td>main partic past ps</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>[]</td>
#       <td>[Part-P, El]</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>rääkinud</td>
#       <td>rääkinud</td>
#       <td>rääki=nud</td>
#       <td>0</td>
#       <td></td>
#       <td>A</td>
#       <td>pos</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>[nud]</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>rääkinud</td>
#       <td>rääkinud</td>
#       <td>rääki=nud</td>
#       <td>0</td>
#       <td></td>
#       <td>A</td>
#       <td>pos sg nom</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>[nud]</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>rääkinud</td>
#       <td>rääkinud</td>
#       <td>rääki=nud</td>
#       <td>d</td>
#       <td></td>
#       <td>A</td>
#       <td>pos pl nom</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>[nud]</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>!</td>
#       <td>!</td>
#       <td>!</td>
#       <td>!</td>
#       <td></td>
#       <td></td>
#       <td>Z</td>
#       <td></td>
#       <td>Exc</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>[]</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # CG3 exporter

# %%
from estnltk.converters.CG3_exporter import export_CG3
text = Text('Lähme! Ta on rääkinud.')
text.analyse('syntax_preprocessing')
export_CG3(text)
# Out:
# ['"<s>"',
#  '"<Lähme>"',
#  '    "mine" Lme V mod indic pres ps1 pl ps af cap <FinV>',
#  '    "mine" Lme V aux indic pres ps1 pl ps af cap <FinV>',
#  '    "mine" Lme V main indic pres ps1 pl ps af cap <FinV>',
#  '"<!>"',
#  '    "!" Z Exc',
#  '"</s>"',
#  '"<s>"',
#  '"<Ta>"',
#  '    "tema" L0 P pers ps3 sg nom cap',
#  '"<on>"',
#  '    "ole" L0 V mod indic pres ps3 sg ps af <FinV> <Intr>',
#  '    "ole" L0 V aux indic pres ps3 sg ps af <FinV> <Intr>',
#  '    "ole" L0 V main indic pres ps3 sg ps af <FinV> <Intr>',
#  '    "ole" L0 V mod indic pres ps3 pl ps af <FinV> <Intr>',
#  '    "ole" L0 V aux indic pres ps3 pl ps af <FinV> <Intr>',
#  '    "ole" L0 V main indic pres ps3 pl ps af <FinV> <Intr>',
#  '"<rääkinud>"',
#  '    "rääki" Lnud V mod indic impf ps neg <FinV> <Part-P> <El>',
#  '    "rääki" Lnud V mod partic past ps <Part-P> <El>',
#  '    "rääki" Lnud V aux indic impf ps neg <FinV> <Part-P> <El>',
#  '    "rääki" Lnud V aux partic past ps <Part-P> <El>',
#  '    "rääki" Lnud V main indic impf ps neg <FinV> <Part-P> <El>',
#  '    "rääki" Lnud V main partic past ps <Part-P> <El>',
#  '    "rääki=nud" L0 A pos partic <nud>',
#  '    "rääki=nud" L0 A pos sg nom partic <nud>',
#  '    "rääki=nud" Ld A pos pl nom partic <nud>',
#  '"<.>"',
#  '    "." Z Fst',
#  '"</s>"']
