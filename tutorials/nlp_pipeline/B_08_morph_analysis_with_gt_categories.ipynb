# %% [markdown]
# ## Morphological analysis with GT (giellatekno) categories
#
# By default, EstNLTK uses Vabamorf's morphological analysis categories, which are described [here](https://github.com/Filosoft/vabamorf/blob/master/doc/tagset.html) (in Estonian). Vabamorf's categories can be converted to GT (Giellatekno) categories (described [here](http://www2.keeleveeb.ee/dict/corpus/shared/categories.html)), which provide minor fixes on noun forms, and more fine-grained categories for verb forms.
#
# The whole conversion process is handled by `GTMorphConverter`:

# %%
from estnltk.text import Text
from estnltk.taggers import GTMorphConverter
gt_converter = GTMorphConverter()
gt_converter
# Out:
# GTMorphConverter(input_layers=['words', 'sentences', 'morph_analysis', 'clauses'], output_layer=gt_morph_analysis, output_attributes=('lemma', 'root', 'root_tokens', 'ending', 'clitic', 'form', 'partofspeech'), disambiguate_neg=True, disambiguate_sid_ksid=True, depends_on=['words', 'sentences', 'morph_analysis', 'clauses'], layer_name=gt_morph_analysis, attributes=('lemma', 'root', 'root_tokens', 'ending', 'clitic', 'form', 'partofspeech'))

# %% [markdown]
# After a text has been morphologically analysed and clause tagged, we can use `GTMorphConverter` to convert morphological categories to GT format. As a result of conversion, we will have new layer called `'gt_morph_analysis'`:

# %%
text = Text('Rändur võttis istet.')
text.tag_layer(['morph_analysis', 'clauses'])
gt_converter.tag( text )
text
# Out:
# Text(text='Rändur võttis istet.')

# %%
text['gt_morph_analysis']
# Out:
# Layer(name=gt_morph_analysis, spans=SL[AS[Annotation(Rändur, {'clitic': '', 'ending': '0', 'form': 'Sg Nom', 'lemma': 'rändur', 'partofspeech': 'S', 'root': 'rändur', 'root_tokens': ('rändur',)})],
# AS[Annotation(võttis, {'clitic': '', 'ending': 'is', 'form': 'Pers Prt Ind Sg 3 Aff', 'lemma': 'võtma', 'partofspeech': 'V', 'root': 'võt', 'root_tokens': ('võt',)})],
# AS[Annotation(istet, {'clitic': '', 'ending': 't', 'form': 'Sg Par', 'lemma': 'iste', 'partofspeech': 'S', 'root': 'iste', 'root_tokens': ('iste',)})],
# AS[Annotation(., {'clitic': '', 'ending': '', 'form': '', 'lemma': '.', 'partofspeech': 'Z', 'root': '.', 'root_tokens': ('.',)})]])

# %% [markdown]
# Attributes `'lemma', 'root', 'root_tokens', 'ending', 'clitic', 'partofspeech'` are exactly the same in `'gt_morph_analysis'` and `'morph_analysis'`. Only the categories listed under `'form'` are different.

# %% [markdown]
# #### Disambiguation
#
# The conversion to `'gt_morph_analysis'` can introduce some additional analyses, as some of the Vabamorf's verb categories have more than one corresponding GT category. These ambiguities are also automatically disambiguated by `GTMorphConverterTagger` based on contextual clues.

# %% [markdown]
# The first type of ambiguity that will be resolved is the ambiguity between negative and imperative form of a verb. This process can also be switched off with the flag `disambiguate_neg`:

# %%
from estnltk.taggers import GTMorphConverter
gt_converter = GTMorphConverter(disambiguate_neg=False) # Switch off disambiguation of negative verbs

text = Text('Sa ei peatu ega vaata ringi. Palun peatu!')
text.tag_layer(['morph_analysis', 'clauses'])
gt_converter.tag( text )
text['gt_morph_analysis']
# Out:
# Layer(name=gt_morph_analysis, spans=SL[AS[Annotation(Sa, {'clitic': '', 'ending': '0', 'form': 'Sg Nom', 'lemma': 'sina', 'partofspeech': 'P', 'root': 'sina', 'root_tokens': ('sina',)})],
# AS[Annotation(ei, {'clitic': '', 'ending': '0', 'form': 'Neg', 'lemma': 'ei', 'partofspeech': 'V', 'root': 'ei', 'root_tokens': ('ei',)})],
# AS[Annotation(peatu, {'clitic': '', 'ending': '0', 'form': 'Pers Prs Imprt Sg 2', 'lemma': 'peatuma', 'partofspeech': 'V', 'root': 'peatu', 'root_tokens': ('peatu',)}), Annotation(peatu, {'clitic': '', 'ending': '0', 'form': 'Pers Prs Ind Neg', 'lemma': 'peatuma', 'partofspeech': 'V', 'root': 'peatu', 'root_tokens': ('peatu',)})],
# AS[Annotation(ega, {'clitic': '', 'ending': '0', 'form': '', 'lemma': 'ega', 'partofspeech': 'J', 'root': 'ega', 'root_tokens': ('ega',)})],
# AS[Annotation(vaata, {'clitic': '', 'ending': '0', 'form': 'Pers Prs Imprt Sg 2', 'lemma': 'vaatama', 'partofspeech': 'V', 'root': 'vaata', 'root_tokens': ('vaata',)}), Annotation(vaata, {'clitic': '', 'ending': '0', 'form': 'Pers Prs Ind Neg', 'lemma': 'vaatama', 'partofspeech': 'V', 'root': 'vaata', 'root_tokens': ('vaata',)})],
# AS[Annotation(ringi, {'clitic': '', 'ending': '0', 'form': '', 'lemma': 'ringi', 'partofspeech': 'D', 'root': 'ringi', 'root_tokens': ('ringi',)})],
# AS[Annotation(., {'clitic': '', 'ending': '', 'form': '', 'lemma': '.', 'partofspeech': 'Z', 'root': '.', 'root_tokens': ('.',)})],
# AS[Annotation(Palun, {'clitic': '', 'ending': 'n', 'form': 'Pers Prs Ind Sg 1 Aff', 'lemma': 'paluma', 'partofspeech': 'V', 'root': 'palu', 'root_tokens': ('palu',)})],
# AS[Annotation(peatu, {'clitic': '', 'ending': '0', 'form': 'Pers Prs Imprt Sg 2', 'lemma': 'peatuma', 'partofspeech': 'V', 'root': 'peatu', 'root_tokens': ('peatu',)}), Annotation(peatu, {'clitic': '', 'ending': '0', 'form': 'Pers Prs Ind Neg', 'lemma': 'peatuma', 'partofspeech': 'V', 'root': 'peatu', 'root_tokens': ('peatu',)})],
# AS[Annotation(!, {'clitic': '', 'ending': '', 'form': '', 'lemma': '!', 'partofspeech': 'Z', 'root': '!', 'root_tokens': ('!',)})]])

# %%
from estnltk.taggers import GTMorphConverter
gt_converter = GTMorphConverter(disambiguate_neg=True) # Switch on disambiguation of negative verbs (default)

text = Text('Sa ei peatu ega vaata ringi. Palun peatu!')
text.tag_layer(['morph_analysis', 'clauses'])
gt_converter.tag( text )
text['gt_morph_analysis']
# Out:
# Layer(name=gt_morph_analysis, spans=SL[AS[Annotation(Sa, {'clitic': '', 'ending': '0', 'form': 'Sg Nom', 'lemma': 'sina', 'partofspeech': 'P', 'root': 'sina', 'root_tokens': ('sina',)})],
# AS[Annotation(ei, {'clitic': '', 'ending': '0', 'form': 'Neg', 'lemma': 'ei', 'partofspeech': 'V', 'root': 'ei', 'root_tokens': ('ei',)})],
# AS[Annotation(peatu, {'clitic': '', 'ending': '0', 'form': 'Pers Prs Ind Neg', 'lemma': 'peatuma', 'partofspeech': 'V', 'root': 'peatu', 'root_tokens': ('peatu',)})],
# AS[Annotation(ega, {'clitic': '', 'ending': '0', 'form': '', 'lemma': 'ega', 'partofspeech': 'J', 'root': 'ega', 'root_tokens': ('ega',)})],
# AS[Annotation(vaata, {'clitic': '', 'ending': '0', 'form': 'Pers Prs Ind Neg', 'lemma': 'vaatama', 'partofspeech': 'V', 'root': 'vaata', 'root_tokens': ('vaata',)})],
# AS[Annotation(ringi, {'clitic': '', 'ending': '0', 'form': '', 'lemma': 'ringi', 'partofspeech': 'D', 'root': 'ringi', 'root_tokens': ('ringi',)})],
# AS[Annotation(., {'clitic': '', 'ending': '', 'form': '', 'lemma': '.', 'partofspeech': 'Z', 'root': '.', 'root_tokens': ('.',)})],
# AS[Annotation(Palun, {'clitic': '', 'ending': 'n', 'form': 'Pers Prs Ind Sg 1 Aff', 'lemma': 'paluma', 'partofspeech': 'V', 'root': 'palu', 'root_tokens': ('palu',)})],
# AS[Annotation(peatu, {'clitic': '', 'ending': '0', 'form': 'Pers Prs Imprt Sg 2', 'lemma': 'peatuma', 'partofspeech': 'V', 'root': 'peatu', 'root_tokens': ('peatu',)})],
# AS[Annotation(!, {'clitic': '', 'ending': '', 'form': '', 'lemma': '!', 'partofspeech': 'Z', 'root': '!', 'root_tokens': ('!',)})]])

# %% [markdown]
# The second type of ambiguity that is automatically resolved is the ambiguity between verb forms `'Pers Prt Ind Pl3 Aff'` and `'Pers Prt Ind Sg2 Aff'` ( flag `disambiguate_sid_ksid` ):

# %%
from estnltk.taggers import GTMorphConverter
gt_converter = GTMorphConverter(disambiguate_sid_ksid=True) # Switch on disambiguation of -sid, -ksid, -nuksid verbs (default)

text = Text('Sa läksid ära, aga nemad tulid tagasi.')
text.tag_layer(['morph_analysis', 'clauses'])
gt_converter.tag( text )
text['gt_morph_analysis']
# Out:
# Layer(name=gt_morph_analysis, spans=SL[AS[Annotation(Sa, {'clitic': '', 'ending': '0', 'form': 'Sg Nom', 'lemma': 'sina', 'partofspeech': 'P', 'root': 'sina', 'root_tokens': ('sina',)})],
# AS[Annotation(läksid, {'clitic': '', 'ending': 'sid', 'form': 'Pers Prt Ind Sg 2 Aff', 'lemma': 'minema', 'partofspeech': 'V', 'root': 'mine', 'root_tokens': ('mine',)})],
# AS[Annotation(ära, {'clitic': '', 'ending': '0', 'form': '', 'lemma': 'ära', 'partofspeech': 'D', 'root': 'ära', 'root_tokens': ('ära',)})],
# AS[Annotation(,, {'clitic': '', 'ending': '', 'form': '', 'lemma': ',', 'partofspeech': 'Z', 'root': ',', 'root_tokens': (',',)})],
# AS[Annotation(aga, {'clitic': '', 'ending': '0', 'form': '', 'lemma': 'aga', 'partofspeech': 'J', 'root': 'aga', 'root_tokens': ('aga',)})],
# AS[Annotation(nemad, {'clitic': '', 'ending': 'd', 'form': 'Pl Nom', 'lemma': 'tema', 'partofspeech': 'P', 'root': 'tema', 'root_tokens': ('tema',)})],
# AS[Annotation(tulid, {'clitic': '', 'ending': 'id', 'form': 'Pers Prt Ind Pl 3 Aff', 'lemma': 'tulema', 'partofspeech': 'V', 'root': 'tule', 'root_tokens': ('tule',)})],
# AS[Annotation(tagasi, {'clitic': '', 'ending': '0', 'form': '', 'lemma': 'tagasi', 'partofspeech': 'D', 'root': 'tagasi', 'root_tokens': ('tagasi',)})],
# AS[Annotation(., {'clitic': '', 'ending': '', 'form': '', 'lemma': '.', 'partofspeech': 'Z', 'root': '.', 'root_tokens': ('.',)})]])

# %% [markdown]
# Note: if the flag `disambiguate_sid_ksid` is switched off, then the input layer `"clauses"` is no longer required, as it is only needed for resolving _sid/ksid_ type of ambiguities.
