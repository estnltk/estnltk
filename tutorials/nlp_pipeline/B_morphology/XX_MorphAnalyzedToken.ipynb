# %% [markdown]
# # MorphAnalyzedToken
#
# `MorphAnalyzedToken` class is EstNLTK's _internal component_, which provides limited morphological analysis of an input word. It is mainly used inside `CompoundTokenTagger` for validating and normalizing some specific word tokens.
#
# For morphological analysis, `MorphAnalyzedToken` uses `Vabamorf` with the configuration:
# ```python
# guess=False
# propername=False
# disambiguate=False
# ```
# <div class="alert alert-block alert-warning">
# <h4>[Usage warning]</h4>
# While <code>MorphAnalyzedToken</code> can be used for checking if a word is a standard Estonian word, and it provides some (limited) part of speech analysis for a word, we do not recommend using it extensively in text processing.
# Whenever possible, you should prefer using <code>VabamorfTagger</code> or <code>VabamorfAnalyzer</code> instead, as they provide more accurate and extensive morphological analysis, along with all necessary pre- and postprocessing.
# </div>

# %%
from estnltk.taggers.standard.morph_analysis.proxy import MorphAnalyzedToken

# %% [markdown]
# ## is_word
# Return `True` if the token is an Estonian word, `False` otherwise.

# %%
MorphAnalyzedToken('saabas').is_word
# Out:
# True

# %% [markdown]
# ## is_pronoun
#
# Return `True` if the token is a pronoun, `False` otherwise.

# %%
MorphAnalyzedToken('mina').is_pronoun
# Out:
# True

# %% [markdown]
# ## is_conjunction
# Return `True` if the token is a conjunction, `False` otherwise.

# %%
MorphAnalyzedToken('ega').is_conjunction
# Out:
# True

# %% [markdown]
# ## normal
# Return `MorphAnalyzedToken` without hyphenation and stammer.

# %%
MorphAnalyzedToken('s-s-saa-bas').normal
# Out:
# MorphAnalyzedToken('saabas')

# %% [markdown]
# ## Example

# %%
import pandas

tokens = [
          '-q-q-qqwer-ty-',
          'ja',
          '-v-v-v-ve-ve-vere-taoline-',
          'vere-taoline',
          'maa-alune',
          '-maa-a-lu--ne-',
          '-m-a-a-a-l-u-n-e-',
          'maaalune',
          '-lil-le-pott-',
          'lillepott',
          'lille-pott',
          'ma-tegevusnimi',
          'ma-sina',
          'masina',
          '-ise-enda-',
          'iseenda',
          'kes-keda',
          'sulle-mulle',
          'sulle-mina',
          'sulle-tead-mina',
          'selle-ja-sellega',
          'selle-ja-sellele',
          'ei-tea-kellele',
          'sinule-ja-minule',
          'ja-ma',
          'ja-mingi-muu',
         ]
records = []
for token in tokens:
    token = MorphAnalyzedToken(token)
    records.append({
                    'token':token,
                    'normal':token.normal,
                    'is_word':token.is_word,
                    'is_pronoun':token.is_pronoun,
                    'is_conjunction':token.is_conjunction
                   })
df = pandas.DataFrame.from_records(records, columns=['token', 'normal', 'is_word', 
                                                     'is_pronoun', 'is_conjunction'])
df.replace({False: ''})
# Out:
#                          token            normal is_word is_pronoun  \
# 0               -q-q-qqwer-ty-    -q-q-qqwer-ty-
# 1                           ja                ja    True
# 2   -v-v-v-ve-ve-vere-taoline-      vere-taoline
# 3                 vere-taoline      vere-taoline    True
# 4                    maa-alune         maa-alune    True
# 5               -maa-a-lu--ne-         maa-alune
# 6            -m-a-a-a-l-u-n-e-          maaalune
# 7                     maaalune          maaalune    True
# 8                -lil-le-pott-         lillepott
# 9                    lillepott         lillepott    True
# 10                  lille-pott        lille-pott    True
# 11              ma-tegevusnimi    ma-tegevusnimi    True
# 12                     ma-sina            masina    True       True
# 13                      masina            masina    True
# 14                  -ise-enda-          ise-enda
# 15                     iseenda           iseenda    True       True
# ...
