# %% [markdown]
# # Text segmentation
# ## Taggers
# The following taggers are involved with the text segmentation.
# ### TokensTagger
# Uses nltk WordPunctTokenizer to tokenize raw text. Creates tokens layer.

# %%
from estnltk.taggers import TokensTagger
tokens_tagger = TokensTagger()
tokens_tagger
# Out:
# <h4>Tagger</h4>
# Tags tokens in raw text.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>layer</th>
#       <th>attributes</th>
#       <th>depends_on</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>TokensTagger</td>
#       <td>tokens</td>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#   </tbody>
# </table>
# <h4>Configuration</h4>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>apply_punct_postfixes</th>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>

# %%
from estnltk import Text
T = '''Aadressilt bla@bla.ee tuli 10 000 kirja. Kirjad, st. spamm saabus 10 tunni jooksul.

A. H. Tammsaare 1935. aatal: 1,0 m / s = 3, 67 km/h.'''
text = Text(T)
tokens_tagger.tag(text)
text['tokens']
# Out:
# <h4>Layer</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>layer name</th>
#       <th>attributes</th>
#       <th>parent</th>
#       <th>enveloping</th>
#       <th>ambiguous</th>
#       <th>span count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>tokens</td>
#       <td></td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>44</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Aadressilt</td>
#     </tr>
#     <tr>
#       <td>bla</td>
#     </tr>
#     <tr>
#       <td>@</td>
#     </tr>
#     <tr>
#       <td>bla</td>
#     </tr>
#     <tr>
#       <td>.</td>
#     </tr>
#     <tr>
#       <td>ee</td>
#     </tr>
#     <tr>
#       <td>tuli</td>
#     </tr>
#     <tr>
#       <td>10</td>
#     </tr>
#     <tr>
#       <td>000</td>
#     </tr>
#     <tr>
#       <td>kirja</td>
#     </tr>
#     <tr>
#       <td>.</td>
#     </tr>
#     <tr>
#       <td>Kirjad</td>
#     </tr>
#     <tr>
#       <td>,</td>
#     </tr>
#     <tr>
#       <td>st</td>
#     </tr>
#     <tr>
#       <td>.</td>
#     </tr>
#     <tr>
#       <td>spamm</td>
#     </tr>
#     <tr>
#       <td>saabus</td>
#     </tr>
#     <tr>
#       <td>10</td>
#     </tr>
#     <tr>
#       <td>tunni</td>
#     </tr>
#     <tr>
#       <td>jooksul</td>
#     </tr>
#     <tr>
#       <td>.</td>
#     </tr>
#     <tr>
#       <td>A</td>
#     </tr>
#     <tr>
#       <td>.</td>
#     </tr>
#     <tr>
#       <td>H</td>
#     </tr>
#     <tr>
#       <td>.</td>
#     </tr>
#     <tr>
#       <td>Tammsaare</td>
#     </tr>
#     <tr>
#       <td>1935</td>
#     </tr>
#     <tr>
#       <td>.</td>
#     </tr>
#     <tr>
#       <td>aatal</td>
#     </tr>
#     <tr>
#       <td>:</td>
#     </tr>
#     <tr>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>,</td>
#     </tr>
#     <tr>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>m</td>
#     </tr>
#     <tr>
#       <td>/</td>
#     </tr>
#     <tr>
#       <td>s</td>
#     </tr>
#     <tr>
#       <td>=</td>
#     </tr>
#     <tr>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>,</td>
#     </tr>
#     <tr>
#       <td>67</td>
#     </tr>
#     <tr>
#       <td>km</td>
#     </tr>
#     <tr>
#       <td>/</td>
#     </tr>
#     <tr>
#       <td>h</td>
#     </tr>
#     <tr>
#       <td>.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### CompounTokenTagger

# %%
from estnltk.taggers import CompoundTokenTagger
compound_token_tagger = CompoundTokenTagger()
compound_token_tagger
# Out:
# <h4>Tagger</h4>
# Tags adjacent tokens that should be analyzed as one word.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>layer</th>
#       <th>attributes</th>
#       <th>depends_on</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>CompoundTokenTagger</td>
#       <td>compound_tokens</td>
#       <td>(type, normalized)</td>
#       <td>[tokens]</td>
#     </tr>
#   </tbody>
# </table>
# <h4>Configuration</h4>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>tag_numbers</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>tag_abbreviations</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>use_custom_abbreviations</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>tag_units</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>tag_hyphenations</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>tag_case_endings</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>tag_initials</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>tag_xml</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>conflict_resolving_strategy</th>
#       <td>MAX</td>
#     </tr>
#     <tr>
#       <th>tag_email_and_www</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>tag_emoticons</th>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>

# %%
compound_token_tagger.tag(text)
text['compound_tokens']
# Out:
# <h4>Layer</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>layer name</th>
#       <th>attributes</th>
#       <th>parent</th>
#       <th>enveloping</th>
#       <th>ambiguous</th>
#       <th>span count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>compound_tokens</td>
#       <td>type, normalized</td>
#       <td>None</td>
#       <td>tokens</td>
#       <td>False</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>type</th>
#       <th>normalized</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><b>bla</b><b>@</b><b>bla</b><b>.</b><b>ee</b></td>
#       <td>(email,)</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td><b>10</b> <b>000</b></td>
#       <td>(numeric,)</td>
#       <td>10000</td>
#     </tr>
#     <tr>
#       <td><b>st</b><b>.</b></td>
#       <td>(non_ending_abbreviation,)</td>
#       <td>st.</td>
#     </tr>
#     <tr>
#       <td><b>A</b><b>.</b> <b>H</b><b>.</b> <b>Tammsaare</b></td>
#       <td>(name_with_initial,)</td>
#       <td>A. H. Tammsaare</td>
#     </tr>
#     <tr>
#       <td><b>1935</b><b>.</b></td>
#       <td>(numeric,)</td>
#       <td>1935</td>
#     </tr>
#     <tr>
#       <td><b>1</b><b>,</b><b>0</b></td>
#       <td>(numeric,)</td>
#       <td>1,0</td>
#     </tr>
#     <tr>
#       <td><b>m</b> <b>/</b> <b>s</b></td>
#       <td>(unit,)</td>
#       <td>m/s</td>
#     </tr>
#     <tr>
#       <td><b>km</b><b>/</b><b>h</b></td>
#       <td>(unit,)</td>
#       <td>km/h</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### WordTagger

# %%
from estnltk.taggers import WordTagger
word_tagger = WordTagger()
word_tagger
# Out:
# <h4>Tagger</h4>
# Creates layer 'words' based on the layers 'tokens' and 'compound_tokens'.
#                      Provides normalized forms of the words, which are used in the succeeding
#                      phase of morphological analysis.
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>layer</th>
#       <th>attributes</th>
#       <th>depends_on</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>WordTagger</td>
#       <td>words</td>
#       <td>[normalized_form]</td>
#       <td>[compound_tokens]</td>
#     </tr>
#   </tbody>
# </table>
# No configuration parameters.

# %%
word_tagger.tag(text)
text['words']
# Out:
# <h4>Layer</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>layer name</th>
#       <th>attributes</th>
#       <th>parent</th>
#       <th>enveloping</th>
#       <th>ambiguous</th>
#       <th>span count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>words</td>
#       <td>normalized_form</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>normalized_form</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Aadressilt</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>bla@bla.ee</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>tuli</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>10 000</td>
#       <td>10000</td>
#     </tr>
#     <tr>
#       <td>kirja</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>.</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>Kirjad</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>,</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>st.</td>
#       <td>st.</td>
#     </tr>
#     <tr>
#       <td>spamm</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>saabus</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>tunni</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>jooksul</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>.</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>A. H. Tammsaare</td>
#       <td>A. H. Tammsaare</td>
#     </tr>
#     <tr>
#       <td>1935.</td>
#       <td>1935</td>
#     </tr>
#     <tr>
#       <td>aatal</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>:</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>1,0</td>
#       <td>1,0</td>
#     </tr>
#     <tr>
#       <td>m / s</td>
#       <td>m/s</td>
#     </tr>
#     <tr>
#       <td>=</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>,</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>km/h</td>
#       <td>km/h</td>
#     </tr>
#     <tr>
#       <td>.</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### SentenceTokenizer

# %%
from estnltk.taggers import SentenceTokenizer
sentence_tokenizer = SentenceTokenizer()
sentence_tokenizer
# Out:
# <h4>Tagger</h4>
# Groups words into sentences, and applies sentence tokenization post-corrections, if required.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>layer</th>
#       <th>attributes</th>
#       <th>depends_on</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>SentenceTokenizer</td>
#       <td>sentences</td>
#       <td>()</td>
#       <td>[compound_tokens, words]</td>
#     </tr>
#   </tbody>
# </table>
# <h4>Configuration</h4>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>fix_numeric</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>fix_paragraph_endings</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>use_emoticons_as_endings</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>fix_double_quotes</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>fix_parentheses</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>fix_inner_title_punct</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>fix_repeated_ending_punct</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>fix_compound_tokens</th>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>

# %%
sentence_tokenizer.tag(text)
text['sentences']
# Out:
# <h4>Layer</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>layer name</th>
#       <th>attributes</th>
#       <th>parent</th>
#       <th>enveloping</th>
#       <th>ambiguous</th>
#       <th>span count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>sentences</td>
#       <td></td>
#       <td>None</td>
#       <td>words</td>
#       <td>False</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><b>Aadressilt</b> <b>bla@bla.ee</b> <b>tuli</b> <b>10 000</b> <b>kirja</b><b>.</b></td>
#     </tr>
#     <tr>
#       <td><b>Kirjad</b><b>,</b> <b>st.</b> <b>spamm</b> <b>saabus</b> <b>10</b> <b>tunni</b> <b>jooksul</b><b>.</b></td>
#     </tr>
#     <tr>
#       <td><b>A. H. Tammsaare</b> <b>1935.</b> <b>aatal</b><b>:</b> <b>1,0</b> <b>m / s</b> <b>=</b> <b>3</b><b>,</b> <b>67</b> <b>km/h</b><b>.</b></td>
#     </tr>
#   </tbody>
# </table>

# %%
t = '''Aadressilt bla@bla.ee tuli 10 000 kirja, st. spammi aadressile foo@foo.ee 10 tunni jooksul 2017. aastal. \
A. H. Tammsaare: 1,0 m / s = 3, 67 km/h.'''

# %%
from estnltk.taggers import ParagraphTokenizer
paragraph_tokenizer = ParagraphTokenizer()
paragraph_tokenizer
# Out:
# <h4>Tagger</h4>
# Tags adjacent sentences that form a paragraph.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>layer</th>
#       <th>attributes</th>
#       <th>depends_on</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ParagraphTokenizer</td>
#       <td>paragraphs</td>
#       <td>[]</td>
#       <td>[sentences]</td>
#     </tr>
#   </tbody>
# </table>
# <h4>Configuration</h4>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>regex</th>
#       <td>\s*\n\n</td>
#     </tr>
#   </tbody>
# </table>

# %%
paragraph_tokenizer.tag(text)
text['paragraphs']
# Out:
# <h4>Layer</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>layer name</th>
#       <th>attributes</th>
#       <th>parent</th>
#       <th>enveloping</th>
#       <th>ambiguous</th>
#       <th>span count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>paragraphs</td>
#       <td></td>
#       <td>None</td>
#       <td>sentences</td>
#       <td>False</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><b>Aadressilt bla@bla.ee tuli 10 000 kirja.</b> <b>Kirjad, st. spamm saabus 10 tunni jooksul.</b></td>
#     </tr>
#     <tr>
#       <td><b>A. H. Tammsaare 1935. aatal: 1,0 m / s = 3, 67 km/h.</b></td>
#     </tr>
#   </tbody>
# </table>

# %%
text
# Out:
# Text(text="Aadressilt bla@bla.ee tuli 10 000 kirja. Kirjad, st. spamm saabus 10 tunni jooksul.
#
# A. H. Tammsaare 1935. aatal: 1,0 m / s = 3, 67 km/h.")

# %% [markdown]
# # tag_layer
# All above is equivalent to

# %%
Text(T).tag_layer(['paragraphs'])
# Out:
# Text(text="Aadressilt bla@bla.ee tuli 10 000 kirja. Kirjad, st. spamm saabus 10 tunni jooksul.
#
# A. H. Tammsaare 1935. aatal: 1,0 m / s = 3, 67 km/h.")

# %% [markdown]
# # analyse
# One can also write

# %%
Text(T).analyse('segmentation')
# Out:
# Text(text="Aadressilt bla@bla.ee tuli 10 000 kirja. Kirjad, st. spamm saabus 10 tunni jooksul.
#
# A. H. Tammsaare 1935. aatal: 1,0 m / s = 3, 67 km/h.")

# %% [markdown]
# Here auxiliary layers are deleted.

# %% [markdown]
# # Word tokenization

# %%
from estnltk import Text

t = '''Aadressilt bla@bla.ee tuli 10 000 kirja, st. spammi aadressile foo@foo.ee 10 tunni jooksul 2017. aastal. \
A. H. Tammsaare: 1,0 m / s = 3, 67 km/h.'''
t
# Out:
# 'Aadressilt bla@bla.ee tuli 10 000 kirja, st. spammi aadressile foo@foo.ee 10 tunni jooksul 2017. aastal. A. H. Tammsaare: 1,0 m / s = 3, 67 km/h.'

# %%
text = Text(t)
text.tag_layer(['words'])
text['words']
# Out:
# <h4>Layer</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>layer name</th>
#       <th>attributes</th>
#       <th>parent</th>
#       <th>enveloping</th>
#       <th>ambiguous</th>
#       <th>span count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>words</td>
#       <td>normalized_form</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>26</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>normalized_form</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Aadressilt</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>bla@bla.ee</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>tuli</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>10 000</td>
#       <td>10000</td>
#     </tr>
#     <tr>
#       <td>kirja</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>,</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>st.</td>
#       <td>st.</td>
#     </tr>
#     <tr>
#       <td>spammi</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>aadressile</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>foo@foo.ee</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>tunni</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>jooksul</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>2017.</td>
#       <td>2017</td>
#     </tr>
#     <tr>
#       <td>aastal</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>.</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>A. H. Tammsaare</td>
#       <td>A. H. Tammsaare</td>
#     </tr>
#     <tr>
#       <td>:</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>1,0</td>
#       <td>1,0</td>
#     </tr>
#     <tr>
#       <td>m / s</td>
#       <td>m/s</td>
#     </tr>
#     <tr>
#       <td>=</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>,</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td>km/h</td>
#       <td>km/h</td>
#     </tr>
#     <tr>
#       <td>.</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
