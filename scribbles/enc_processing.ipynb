# %% [markdown]
# # ENC processing
#
# ## MorphMultiwordProperNamesCorrector

# %%
from estnltk import Text, Layer, Annotation

from estnltk.taggers import Retagger
from estnltk.taggers import VabamorfTagger
from estnltk.taggers import MorphAnalysisReorderer
from estnltk.taggers import VabamorfCorpusTagger

class MorphMultiwordProperNamesCorrector(Retagger):
    """Reanalyses sentences that contain multiword propername phrases with VabamorfTagger."""
    conf_param = ('vabamorftagger', 'morph_reorderer')
    
    def __init__(self, output_layer='morph_analysis', input_layers=['morph_analysis', 'sentences']):
        self.output_layer = output_layer
        self.input_layers = input_layers
        self.output_attributes = VabamorfTagger.output_attributes
        # addition:
        # use slang_lex to enable extended morph lexicon
        self.vabamorftagger    = VabamorfTagger(slang_lex=True)
        self.morph_reorderer   = MorphAnalysisReorderer()

    def _change_layer(self, raw_text, layers, status):
        # Analyse input sentence by sentence
        morph_layer = layers[self.output_layer]
        morph_span_id = 0
        reanalysed_sentences = 0
        reanalysed_words     = 0
        for sentence in layers[ self.input_layers[1] ]:
            multiword_propernames_locations = set()
            last_partofspeech = None
            words_in_sentence = []
            local_word_id = 0
            while morph_span_id < len( morph_layer): 
                morph_span = morph_layer[morph_span_id]
                if sentence.start <= morph_span.start and \
                    morph_span.end <= sentence.end:
                    # a) word is in this sentence
                    if 'H' in morph_span.partofspeech and last_partofspeech == 'H':
                        # Remember locations of multiword propernames
                        multiword_propernames_locations.add( local_word_id - 1 )
                        multiword_propernames_locations.add( local_word_id )
                    words_in_sentence.append( morph_span )
                    morph_span_id += 1
                    local_word_id += 1
                    last_partofspeech = 'H' if 'H' in morph_span.partofspeech else morph_span.annotations[0]['partofspeech']
                elif sentence.end <= morph_span.start:
                    # b) word is in the next sentence
                    break
            # Reanalyse the sentence that contains multiword proper names
            if len(multiword_propernames_locations) > 0:
                # Make a new Text for sentence; add tokenization
                sentence_str = sentence.enclosing_text
                sentence_text = Text(sentence_str).tag_layer(['words', 'sentences'])
                # If everything is ok with tokenization, then reapply morph
                if len(sentence_text['words']) == len(words_in_sentence):
                    # Add morph + reordering
                    self.vabamorftagger.tag( sentence_text )
                    self.morph_reorderer.retag( sentence_text )
                    # Transfer new analyses to multiword propernames
                    for wid, old_morph_span in enumerate( words_in_sentence ):
                        if wid in multiword_propernames_locations:
                            new_morph_annotations = sentence_text['morph_analysis'][wid].annotations
                            old_morph_span.clear_annotations()
                            for annotation in new_morph_annotations:
                                new_annotation_dict = annotation.to_record(with_text=False)
                                del new_annotation_dict['start']
                                del new_annotation_dict['end']
                                old_morph_span.add_annotation( Annotation(old_morph_span, **new_annotation_dict) )
                            reanalysed_words += 1
                    reanalysed_sentences += 1
        # Record stats
        morph_layer.meta['reanalysed_words'] = reanalysed_words
        morph_layer.meta['reanalysed_sentences'] = reanalysed_sentences
# Out:
# INFO:utils.py:157: NumExpr defaulting to 4 threads.

# %% [markdown]
# ## Stanza

# %% [markdown]
# First, you'll need models:  https://entu.keeleressursid.ee/public-document/entity-9862/2021-05-29

# %%
# For the best performance with StanzaSyntaxTagger, you should use input_type='morph_extended'
# This requires that the 'morph_extended' layer is computed
#
from estnltk.taggers.syntax.stanza_tagger.stanza_tagger import StanzaSyntaxTagger
stanza_model = 'stanza_resources\et\depparse\morph_extended.pt'
stanza_tagger = StanzaSyntaxTagger( input_type='morph_extended', 
                                    input_morph_layer='morph_extended',  
                                    depparse_path=stanza_model,
                                    add_parent_and_children=True  # add parent and children spans explcitly
                                   )  # Note: add use_gpu=True, if you can use GPU

# What stanza needs?
stanza_tagger.input_layers
# Out:
# ('sentences', 'morph_extended', 'words')

# %%
# StanzaSyntaxEnsembleTagger is statistically more preferable than StanzaSyntaxTagger, 
# but is approx. 10x slower as we run 10 Stanza models.
# The performance difference in LAS scores is about 0.5 percent points.
# Additionally it is more stable and does not depend so much on the training set. 
#
import os
from estnltk.taggers.syntax.stanza_tagger.ensemble_tagger import StanzaSyntaxEnsembleTagger
models_dir = 'stanza_resources\et\depparse\ensemble_models'
model_paths = []
for fname in os.listdir(models_dir):
    if fname.endswith('.pt'):
        print(fname)
        model_paths.append( os.path.join(models_dir, fname) )
#print(model_paths)
stanza_ensemble_tagger = StanzaSyntaxEnsembleTagger( model_paths=model_paths,
                                                     add_parent_and_children=True  # add parent and children spans explcitly
                                                    )  # Note: add use_gpu=True, if you can use GPU

# What stanza needs?
stanza_ensemble_tagger.input_layers
# Out:
# model_1.pt
# model_10.pt
# model_2.pt
# model_3.pt
# model_4.pt
# model_5.pt
# model_6.pt
# model_7.pt
# model_8.pt
# model_9.pt
# ('sentences', 'morph_extended', 'words')

# %% [markdown]
# ## 1. Apply VabamorfCorpusTagger + MorphMultiwordProperNamesCorrector
#
# The first part of the pipeline should stay as it is, because analyses with Vabamorf's categories are still needed in the output.

# %%
text_str='''
Vormi mängude ja materjali valiku eest lavastusele " Nähtamatu poiss " Haapsalu Noorte Huvikeskuse loovus- ja 
draamaring " Üks " juhendajad Anne Suislep ja Triin Reemann Energilise lastepärase huumori ja loo jutustamise
eest lavastuses " Ull Jaak ehk küll on häda kui pea on mäda " juhendaja Kadi Kronberg Lasva Rahvamaja laste 
näitering ( Võrumaa ). Preemia väljaandjaks on MTÜ Vilde Teater. Edgar Savisaar. Siin lauses pole midagi analüüsida. 
See on Tõlkebüroo Filosoof. Suur koer jälitas kiiret kassi.'''

disambiguator = VabamorfCorpusTagger(slang_lex=True)
corrector = MorphMultiwordProperNamesCorrector()

disambiguated_texts = disambiguator.tag([ Text(text_str).tag_layer(['words', 'sentences']) ])
t = disambiguated_texts[0]
t
# Out:
# Text(text='\nVormi mängude ja materjali valiku eest lavastusele " Nähtamatu poiss " Haapsalu Noorte Huvikeskuse loovus- ja \ndraamaring " Üks " juhendajad Anne Suislep ja Triin Reemann Energilise lastepärase huumori ja loo jutustamise\neest lavastuses " Ull Jaak ehk küll on häda kui pea on mäda " juhendaja Kadi Kronberg Lasva Rahvamaja laste \nnäitering ( Võrumaa ). Preemia väljaandjaks on MTÜ Vilde Teater. Edgar Savisaar. Siin lauses pole midagi analüüsida. \nSee on Tõlkebüroo Filosoof. Suur koer jälitas kiiret kassi.')

# %%
corrector.retag(t)
t.morph_analysis
# Out:
# Layer(name='morph_analysis', attributes=('normalized_text', 'lemma', 'root', 'root_tokens', 'ending', 'clitic', 'form', 'partofspeech'), spans=SL[Span('Vormi', [{'normalized_text': 'Vormi', 'lemma': 'vorm', 'root': 'vorm', 'root_tokens': ['vorm'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}]),
# Span('mängude', [{'normalized_text': 'mängude', 'lemma': 'mäng', 'root': 'mäng', 'root_tokens': ['mäng'], 'ending': 'de', 'clitic': '', 'form': 'pl g', 'partofspeech': 'S'}]),
# Span('ja', [{'normalized_text': 'ja', 'lemma': 'ja', 'root': 'ja', 'root_tokens': ['ja'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'J'}]),
# Span('materjali', [{'normalized_text': 'materjali', 'lemma': 'materjal', 'root': 'materjal', 'root_tokens': ['materjal'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}]),
# Span('valiku', [{'normalized_text': 'valiku', 'lemma': 'valik', 'root': 'valik', 'root_tokens': ['valik'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}]),
# Span('eest', [{'normalized_text': 'eest', 'lemma': 'eest', 'root': 'eest', 'root_tokens': ['eest'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'K'}]),
# Span('lavastusele', [{'normalized_text': 'lavastusele', 'lemma': 'lavastus', 'root': 'lavastus', 'root_tokens': ['lavastus'], 'ending': 'le', 'clitic': '', 'form': 'sg all', 'partofspeech': 'S'}]),
# Span('"', [{'normalized_text': '"', 'lemma': '"', 'root': '"', 'root_tokens': ['"'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('Nähtamatu', [{'normalized_text': 'Nähtamatu', 'lemma': 'nähtamatu', 'root': 'nähtamatu', 'root_tokens': ['nähtamatu'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'A'}]),
# Span('poiss', [{'normalized_text': 'poiss', 'lemma': 'poiss', 'root': 'poiss', 'root_tokens': ['poiss'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}]),
# Span('"', [{'normalized_text': '"', 'lemma': '"', 'root': '"', 'root_tokens': ['"'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('Haapsalu', [{'normalized_text': 'Haapsalu', 'lemma': 'haapsalu', 'root': 'haap_salu', 'root_tokens': ['haap', 'salu'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'G'}]),
# Span('Noorte', [{'normalized_text': 'Noorte', 'lemma': 'noor', 'root': 'noor', 'root_tokens': ['noor'], 'ending': 'te', 'clitic': '', 'form': 'pl g', 'partofspeech': 'S'}]),
# Span('Huvikeskuse', [{'normalized_text': 'Huvikeskuse', 'lemma': 'huvikeskus', 'root': 'huvi_keskus', 'root_tokens': ['huvi', 'keskus'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}]),
# Span('loovus-', [{'normalized_text': 'loovus-', 'lemma': 'loovus', 'root': 'loovus', 'root_tokens': ['loovus'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}]),
# Span('ja', [{'normalized_text': 'ja', 'lemma': 'ja', 'root': 'ja', 'root_tokens': ['ja'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'J'}]),
# Span('draamaring', [{'normalized_text': 'draamaring', 'lemma': 'draamaring', 'root': 'draama_ring', 'root_tokens': ['draama', 'ring'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}]),
# Span('"', [{'normalized_text': '"', 'lemma': '"', 'root': '"', 'root_tokens': ['"'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('Üks', [{'normalized_text': 'Üks', 'lemma': 'üks', 'root': 'üks', 'root_tokens': ['üks'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'P'}, {'normalized_text': 'Üks', 'lemma': 'üks', 'root': 'üks', 'root_tokens': ['üks'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'N'}]),
# Span('"', [{'normalized_text': '"', 'lemma': '"', 'root': '"', 'root_tokens': ['"'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('juhendajad', [{'normalized_text': 'juhendajad', 'lemma': 'juhendaja', 'root': 'juhendaja', 'root_tokens': ['juhendaja'], 'ending': 'd', 'clitic': '', 'form': 'pl n', 'partofspeech': 'S'}]),
# Span('Anne', [{'normalized_text': 'Anne', 'lemma': 'Anne', 'root': 'Anne', 'root_tokens': ['Anne'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}]),
# Span('Suislep', [{'normalized_text': 'Suislep', 'lemma': 'Suislep', 'root': 'Suislep', 'root_tokens': ['Suislep'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}]),
# Span('ja', [{'normalized_text': 'ja', 'lemma': 'ja', 'root': 'ja', 'root_tokens': ['ja'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'J'}]),
# Span('Triin', [{'normalized_text': 'Triin', 'lemma': 'Triin', 'root': 'Triin', 'root_tokens': ['Triin'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}]),
# Span('Reemann', [{'normalized_text': 'Reemann', 'lemma': 'Reemann', 'root': 'Ree_mann', 'root_tokens': ['Ree', 'mann'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}, {'normalized_text': 'Reemann', 'lemma': 'Reemann', 'root': 'Reemann', 'root_tokens': ['Reemann'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}]),
# Span('Energilise', [{'normalized_text': 'Energilise', 'lemma': 'Energiline', 'root': 'Energiline', 'root_tokens': ['Energiline'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'H'}]),
# Span('lastepärase', [{'normalized_text': 'lastepärase', 'lemma': 'lastepärane', 'root': 'laste_pärane', 'root_tokens': ['laste', 'pärane'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'A'}]),
# Span('huumori', [{'normalized_text': 'huumori', 'lemma': 'huumor', 'root': 'huumor', 'root_tokens': ['huumor'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}]),
# Span('ja', [{'normalized_text': 'ja', 'lemma': 'ja', 'root': 'ja', 'root_tokens': ['ja'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'J'}]),
# Span('loo', [{'normalized_text': 'loo', 'lemma': 'lugu', 'root': 'lugu', 'root_tokens': ['lugu'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}, {'normalized_text': 'loo', 'lemma': 'lood', 'root': 'lood', 'root_tokens': ['lood'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}, {'normalized_text': 'loo', 'lemma': 'loog', 'root': 'loog', 'root_tokens': ['loog'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}]),
# Span('jutustamise', [{'normalized_text': 'jutustamise', 'lemma': 'jutustamine', 'root': 'jutustamine', 'root_tokens': ['jutustamine'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}]),
# Span('eest', [{'normalized_text': 'eest', 'lemma': 'eest', 'root': 'eest', 'root_tokens': ['eest'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'K'}]),
# Span('lavastuses', [{'normalized_text': 'lavastuses', 'lemma': 'lavastus', 'root': 'lavastus', 'root_tokens': ['lavastus'], 'ending': 's', 'clitic': '', 'form': 'sg in', 'partofspeech': 'S'}]),
# Span('"', [{'normalized_text': '"', 'lemma': '"', 'root': '"', 'root_tokens': ['"'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('Ull', [{'normalized_text': 'Ull', 'lemma': 'Ull', 'root': 'Ull', 'root_tokens': ['Ull'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}]),
# Span('Jaak', [{'normalized_text': 'Jaak', 'lemma': 'Jaak', 'root': 'Jaak', 'root_tokens': ['Jaak'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}]),
# Span('ehk', [{'normalized_text': 'ehk', 'lemma': 'ehk', 'root': 'ehk', 'root_tokens': ['ehk'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'D'}]),
# Span('küll', [{'normalized_text': 'küll', 'lemma': 'küll', 'root': 'küll', 'root_tokens': ['küll'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'D'}]),
# Span('on', [{'normalized_text': 'on', 'lemma': 'olema', 'root': 'ole', 'root_tokens': ['ole'], 'ending': '0', 'clitic': '', 'form': 'b', 'partofspeech': 'V'}, {'normalized_text': 'on', 'lemma': 'olema', 'root': 'ole', 'root_tokens': ['ole'], 'ending': '0', 'clitic': '', 'form': 'vad', 'partofspeech': 'V'}]),
# Span('häda', [{'normalized_text': 'häda', 'lemma': 'häda', 'root': 'häda', 'root_tokens': ['häda'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}]),
# Span('kui', [{'normalized_text': 'kui', 'lemma': 'kui', 'root': 'kui', 'root_tokens': ['kui'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'J'}, {'normalized_text': 'kui', 'lemma': 'kui', 'root': 'kui', 'root_tokens': ['kui'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'D'}]),
# Span('pea', [{'normalized_text': 'pea', 'lemma': 'pea', 'root': 'pea', 'root_tokens': ['pea'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}]),
# Span('on', [{'normalized_text': 'on', 'lemma': 'olema', 'root': 'ole', 'root_tokens': ['ole'], 'ending': '0', 'clitic': '', 'form': 'b', 'partofspeech': 'V'}, {'normalized_text': 'on', 'lemma': 'olema', 'root': 'ole', 'root_tokens': ['ole'], 'ending': '0', 'clitic': '', 'form': 'vad', 'partofspeech': 'V'}]),
# Span('mäda', [{'normalized_text': 'mäda', 'lemma': 'mäda', 'root': 'mäda', 'root_tokens': ['mäda'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'A'}]),
# Span('"', [{'normalized_text': '"', 'lemma': '"', 'root': '"', 'root_tokens': ['"'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('juhendaja', [{'normalized_text': 'juhendaja', 'lemma': 'juhendaja', 'root': 'juhendaja', 'root_tokens': ['juhendaja'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}]),
# Span('Kadi', [{'normalized_text': 'Kadi', 'lemma': 'Kadi', 'root': 'Kadi', 'root_tokens': ['Kadi'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}]),
# Span('Kronberg', [{'normalized_text': 'Kronberg', 'lemma': 'Kronberg', 'root': 'Kronberg', 'root_tokens': ['Kronberg'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}]),
# Span('Lasva', [{'normalized_text': 'Lasva', 'lemma': 'Lasva', 'root': 'Lasva', 'root_tokens': ['Lasva'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'H'}]),
# Span('Rahvamaja', [{'normalized_text': 'Rahvamaja', 'lemma': 'rahvamaja', 'root': 'rahva_maja', 'root_tokens': ['rahva', 'maja'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}]),
# Span('laste', [{'normalized_text': 'laste', 'lemma': 'laps', 'root': 'laps', 'root_tokens': ['laps'], 'ending': 'te', 'clitic': '', 'form': 'pl g', 'partofspeech': 'S'}]),
# Span('näitering', [{'normalized_text': 'näitering', 'lemma': 'näitering', 'root': 'näite_ring', 'root_tokens': ['näite', 'ring'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}]),
# Span('(', [{'normalized_text': '(', 'lemma': '(', 'root': '(', 'root_tokens': ['('], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('Võrumaa', [{'normalized_text': 'Võrumaa', 'lemma': 'võrumaa', 'root': 'võru_maa', 'root_tokens': ['võru', 'maa'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'G'}]),
# Span(')', [{'normalized_text': ')', 'lemma': ')', 'root': ')', 'root_tokens': [')'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('.', [{'normalized_text': '.', 'lemma': '.', 'root': '.', 'root_tokens': ['.'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('Preemia', [{'normalized_text': 'Preemia', 'lemma': 'preemia', 'root': 'preemia', 'root_tokens': ['preemia'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}]),
# Span('väljaandjaks', [{'normalized_text': 'väljaandjaks', 'lemma': 'väljaandja', 'root': 'välja_andja', 'root_tokens': ['välja', 'andja'], 'ending': 'ks', 'clitic': '', 'form': 'sg tr', 'partofspeech': 'S'}]),
# Span('on', [{'normalized_text': 'on', 'lemma': 'olema', 'root': 'ole', 'root_tokens': ['ole'], 'ending': '0', 'clitic': '', 'form': 'b', 'partofspeech': 'V'}, {'normalized_text': 'on', 'lemma': 'olema', 'root': 'ole', 'root_tokens': ['ole'], 'ending': '0', 'clitic': '', 'form': 'vad', 'partofspeech': 'V'}]),
# Span('MTÜ', [{'normalized_text': 'MTÜ', 'lemma': 'MTÜ', 'root': 'MTÜ', 'root_tokens': ['MTÜ'], 'ending': '0', 'clitic': '', 'form': '?', 'partofspeech': 'Y'}]),
# Span('Vilde', [{'normalized_text': 'Vilde', 'lemma': 'Vilde', 'root': 'Vilde', 'root_tokens': ['Vilde'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'H'}]),
# Span('Teater', [{'normalized_text': 'Teater', 'lemma': 'teater', 'root': 'teater', 'root_tokens': ['teater'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}]),
# Span('.', [{'normalized_text': '.', 'lemma': '.', 'root': '.', 'root_tokens': ['.'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('Edgar', [{'normalized_text': 'Edgar', 'lemma': 'Edgar', 'root': 'Edgar', 'root_tokens': ['Edgar'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}]),
# Span('Savisaar', [{'normalized_text': 'Savisaar', 'lemma': 'Savisaar', 'root': 'Savi_saar', 'root_tokens': ['Savi', 'saar'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}, {'normalized_text': 'Savisaar', 'lemma': 'Savisaar', 'root': 'Savisaar', 'root_tokens': ['Savisaar'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'H'}]),
# Span('.', [{'normalized_text': '.', 'lemma': '.', 'root': '.', 'root_tokens': ['.'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('Siin', [{'normalized_text': 'Siin', 'lemma': 'siin', 'root': 'siin', 'root_tokens': ['siin'], 'ending': '0', 'clitic': '', 'form': '', 'partofspeech': 'D'}]),
# Span('lauses', [{'normalized_text': 'lauses', 'lemma': 'lause', 'root': 'lause', 'root_tokens': ['lause'], 'ending': 's', 'clitic': '', 'form': 'sg in', 'partofspeech': 'S'}]),
# Span('pole', [{'normalized_text': 'pole', 'lemma': 'olema', 'root': 'ole', 'root_tokens': ['ole'], 'ending': '0', 'clitic': '', 'form': 'neg o', 'partofspeech': 'V'}]),
# Span('midagi', [{'normalized_text': 'midagi', 'lemma': 'miski', 'root': 'miski', 'root_tokens': ['miski'], 'ending': 'dagi', 'clitic': '', 'form': 'sg p', 'partofspeech': 'P'}]),
# Span('analüüsida', [{'normalized_text': 'analüüsida', 'lemma': 'analüüsima', 'root': 'analüüsi', 'root_tokens': ['analüüsi'], 'ending': 'da', 'clitic': '', 'form': 'da', 'partofspeech': 'V'}]),
# Span('.', [{'normalized_text': '.', 'lemma': '.', 'root': '.', 'root_tokens': ['.'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('See', [{'normalized_text': 'See', 'lemma': 'see', 'root': 'see', 'root_tokens': ['see'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'P'}]),
# Span('on', [{'normalized_text': 'on', 'lemma': 'olema', 'root': 'ole', 'root_tokens': ['ole'], 'ending': '0', 'clitic': '', 'form': 'b', 'partofspeech': 'V'}, {'normalized_text': 'on', 'lemma': 'olema', 'root': 'ole', 'root_tokens': ['ole'], 'ending': '0', 'clitic': '', 'form': 'vad', 'partofspeech': 'V'}]),
# Span('Tõlkebüroo', [{'normalized_text': 'Tõlkebüroo', 'lemma': 'tõlkebüroo', 'root': 'tõlke_büroo', 'root_tokens': ['tõlke', 'büroo'], 'ending': '0', 'clitic': '', 'form': 'sg g', 'partofspeech': 'S'}]),
# Span('Filosoof', [{'normalized_text': 'Filosoof', 'lemma': 'filosoof', 'root': 'filosoof', 'root_tokens': ['filosoof'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}]),
# Span('.', [{'normalized_text': '.', 'lemma': '.', 'root': '.', 'root_tokens': ['.'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}]),
# Span('Suur', [{'normalized_text': 'Suur', 'lemma': 'suur', 'root': 'suur', 'root_tokens': ['suur'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'A'}]),
# Span('koer', [{'normalized_text': 'koer', 'lemma': 'koer', 'root': 'koer', 'root_tokens': ['koer'], 'ending': '0', 'clitic': '', 'form': 'sg n', 'partofspeech': 'S'}]),
# Span('jälitas', [{'normalized_text': 'jälitas', 'lemma': 'jälitama', 'root': 'jälita', 'root_tokens': ['jälita'], 'ending': 's', 'clitic': '', 'form': 's', 'partofspeech': 'V'}]),
# Span('kiiret', [{'normalized_text': 'kiiret', 'lemma': 'kiire', 'root': 'kiire', 'root_tokens': ['kiire'], 'ending': 't', 'clitic': '', 'form': 'sg p', 'partofspeech': 'A'}]),
# Span('kassi', [{'normalized_text': 'kassi', 'lemma': 'kass', 'root': 'kass', 'root_tokens': ['kass'], 'ending': '0', 'clitic': '', 'form': 'sg p', 'partofspeech': 'S'}]),
# Span('.', [{'normalized_text': '.', 'lemma': '.', 'root': '.', 'root_tokens': ['.'], 'ending': '', 'clitic': '', 'form': '', 'partofspeech': 'Z'}])])

# %% [markdown]
# ## 2. Apply Syntax

# %%
# Add syntax
t.tag_layer('morph_extended')
stanza_tagger.tag(t)
#
# Or use:  stanza_ensemble_tagger.tag(t)
#          then the layer name will be 'stanza_ensemble_syntax'
t.stanza_syntax
# Out:
# Layer(name='stanza_syntax', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc', 'parent_span', 'children'), spans=SL[Span('Vormi', [{'id': 1, 'lemma': 'vorm', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 2, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('mängude', [{'id': 2, 'lemma': 'mäng', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 5, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('valiku', [{'id': 5, 'lemma': 'valik', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 7, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Kadi', [{'id' ...
# Span('mängude', [{'id': 2, 'lemma': 'mäng', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 5, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('valiku', [{'id': 5, 'lemma': 'valik', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 7, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Kadi', [{'id': 48, 'lemma': 'Kadi', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Kronberg', [{'id': 49, 'lemma': 'Kronberg', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]),  ...
# Span('ja', [{'id': 3, 'lemma': 'ja', 'upostag': 'J', 'xpostag': 'J', 'feats': OrderedDict([('sub', 'sub'), ('crd', 'crd')]), 'head': 4, 'deprel': 'cc', 'deps': '_', 'misc': '_', 'parent_span': Span('materjali', [{'id': 4, 'lemma': 'materjal', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 2, 'deprel': 'conj', 'deps': '_', 'misc': '_', 'parent_span': Span('mängude', [{'id': 2, 'lemma': 'mäng', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 5, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('valiku', [{'id': 5, 'lemma': 'valik', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 7, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ...
# Span('materjali', [{'id': 4, 'lemma': 'materjal', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 2, 'deprel': 'conj', 'deps': '_', 'misc': '_', 'parent_span': Span('mängude', [{'id': 2, 'lemma': 'mäng', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 5, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('valiku', [{'id': 5, 'lemma': 'valik', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 7, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Kadi', [{'id': 48, 'lemma': 'Kadi', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel':  ...
# Span('valiku', [{'id': 5, 'lemma': 'valik', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 7, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Kadi', [{'id': 48, 'lemma': 'Kadi', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Kronberg', [{'id': 49, 'lemma': 'Kronberg', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 48, 'deprel': 'flat', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Lasva', [{'id': 50, 'lemma': 'Lasva', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg' ...
# Span('eest', [{'id': 6, 'lemma': 'eest', 'upostag': 'K', 'xpostag': 'K', 'feats': OrderedDict([('post', 'post')]), 'head': 5, 'deprel': 'case', 'deps': '_', 'misc': '_', 'parent_span': Span('valiku', [{'id': 5, 'lemma': 'valik', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 7, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Kadi', [{'id': 48, 'lemma': 'Kadi', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Kronberg', [{'id': 49, 'lemma': 'Kronberg', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 48, 'deprel': 'flat', ' ...
# Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Kadi', [{'id': 48, 'lemma': 'Kadi', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Kronberg', [{'id': 49, 'lemma': 'Kronberg', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 48, 'deprel': 'flat', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Lasva', [{'id': 50, 'lemma': 'Lasva', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 48, 'deprel': 'flat', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('on', [{'id': 40, 'lemma': 'olema', 'upostag': 'V', 'xpostag':  ...
# Span('"', [{'id': 8, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 10, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': Span('poiss', [{'id': 10, 'lemma': 'poiss', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 7, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Kadi', [{'id': 48, 'lemma': 'Kadi', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Kronberg', [{'id': 49, 'lemma': 'Kronberg', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 48, 'deprel': 'flat', 'deps': '_', 'misc': ' ...
# Span('Nähtamatu', [{'id': 9, 'lemma': 'nähtamatu', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 10, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': Span('poiss', [{'id': 10, 'lemma': 'poiss', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 7, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Kadi', [{'id': 48, 'lemma': 'Kadi', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Kronberg', [{'id': 49, 'lemma': 'Kronberg', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', ' ...
# Span('poiss', [{'id': 10, 'lemma': 'poiss', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 7, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Kadi', [{'id': 48, 'lemma': 'Kadi', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Kronberg', [{'id': 49, 'lemma': 'Kronberg', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 48, 'deprel': 'flat', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Lasva', [{'id': 50, 'lemma': 'Lasva', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg ...
# Span('"', [{'id': 11, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 10, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': Span('poiss', [{'id': 10, 'lemma': 'poiss', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 7, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastusele', [{'id': 7, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('all', 'all')]), 'head': 34, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('lavastuses', [{'id': 34, 'lemma': 'lavastus', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('in', 'in')]), 'head': 36, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Ull', [{'id': 36, 'lemma': 'Ull', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 41, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('häda', [{'id': 41, 'lemma': 'häda', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('juhendaja', [{'id': 47, 'lemma': 'juhendaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('näitering', [{'id': 53, 'lemma': 'näitering', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('laste', [{'id': 52, 'lemma': 'laps', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 53, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Rahvamaja', [{'id': 51, 'lemma': 'rahvamaja', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 52, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('Võrumaa', [{'id': 55, 'lemma': 'võrumaa', 'upostag': 'G', 'xpostag': 'G', 'feats': OrderedDict(), 'head': 53, 'deprel': 'parataxis', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('(', [{'id': 54, 'lemma': '(', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span(')', [{'id': 56, 'lemma': ')', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 55, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]))}]), 'children': (..., Span('mäda', [{'id': 45, 'lemma': 'mäda', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('on', [{'id': 44, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('pl', 'pl'), ('ps', 'ps'), ('af', 'af')]), 'head': 45, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('"', [{'id': 46, 'lemma': '"', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 47, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Kadi', [{'id': 48, 'lemma': 'Kadi', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 47, 'deprel': 'appos', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Kronberg', [{'id': 49, 'lemma': 'Kronberg', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('prop', 'prop'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 48, 'deprel': 'flat', 'deps': '_', 'misc':  ...
# ...
# Span('See', [{'id': 1, 'lemma': 'see', 'upostag': 'P', 'xpostag': 'P', 'feats': OrderedDict([('sg', 'sg'), ('nom', 'nom')]), 'head': 4, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': Span('Filosoof', [{'id': 4, 'lemma': 'filosoof', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('on', [{'id': 2, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 4, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Tõlkebüroo', [{'id': 3, 'lemma': 'tõlkebüroo', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 4, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('.', [{'id': 5, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 4, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]), 'children': ()}]),
# Span('on', [{'id': 2, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 4, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': Span('Filosoof', [{'id': 4, 'lemma': 'filosoof', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (Span('See', [{'id': 1, 'lemma': 'see', 'upostag': 'P', 'xpostag': 'P', 'feats': OrderedDict([('sg', 'sg'), ('nom', 'nom')]), 'head': 4, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), ..., Span('Tõlkebüroo', [{'id': 3, 'lemma': 'tõlkebüroo', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 4, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('.', [{'id': 5, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 4, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]), 'children': ()}]),
# Span('Tõlkebüroo', [{'id': 3, 'lemma': 'tõlkebüroo', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 4, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': Span('Filosoof', [{'id': 4, 'lemma': 'filosoof', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (Span('See', [{'id': 1, 'lemma': 'see', 'upostag': 'P', 'xpostag': 'P', 'feats': OrderedDict([('sg', 'sg'), ('nom', 'nom')]), 'head': 4, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('on', [{'id': 2, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 4, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), ..., Span('.', [{'id': 5, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 4, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]), 'children': ()}]),
# Span('Filosoof', [{'id': 4, 'lemma': 'filosoof', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (Span('See', [{'id': 1, 'lemma': 'see', 'upostag': 'P', 'xpostag': 'P', 'feats': OrderedDict([('sg', 'sg'), ('nom', 'nom')]), 'head': 4, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('on', [{'id': 2, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 4, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Tõlkebüroo', [{'id': 3, 'lemma': 'tõlkebüroo', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 4, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('.', [{'id': 5, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 4, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]),
# Span('.', [{'id': 5, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 4, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': Span('Filosoof', [{'id': 4, 'lemma': 'filosoof', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (Span('See', [{'id': 1, 'lemma': 'see', 'upostag': 'P', 'xpostag': 'P', 'feats': OrderedDict([('sg', 'sg'), ('nom', 'nom')]), 'head': 4, 'deprel': 'nsubj:cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('on', [{'id': 2, 'lemma': 'olema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('mod', 'mod'), ('indic', 'indic'), ('pres', 'pres'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 4, 'deprel': 'cop', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), Span('Tõlkebüroo', [{'id': 3, 'lemma': 'tõlkebüroo', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 4, 'deprel': 'nmod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]), ...)}]), 'children': ()}]),
# Span('Suur', [{'id': 1, 'lemma': 'suur', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 2, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': Span('koer', [{'id': 2, 'lemma': 'koer', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 3, 'deprel': 'nsubj', 'deps': '_', 'misc': '_', 'parent_span': Span('jälitas', [{'id': 3, 'lemma': 'jälitama', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('aux', 'aux'), ('indic', 'indic'), ('impf', 'impf'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('kassi', [{'id': 5, 'lemma': 'kass', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('part', 'part')]), 'head': 3, 'deprel': 'obj', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('kiiret', [{'id': 4, 'lemma': 'kiire', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('part', 'part')]), 'head': 5, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('.', [{'id': 6, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 3, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]), 'children': (...,)}]), 'children': ()}]),
# Span('koer', [{'id': 2, 'lemma': 'koer', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 3, 'deprel': 'nsubj', 'deps': '_', 'misc': '_', 'parent_span': Span('jälitas', [{'id': 3, 'lemma': 'jälitama', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('aux', 'aux'), ('indic', 'indic'), ('impf', 'impf'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (..., Span('kassi', [{'id': 5, 'lemma': 'kass', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('part', 'part')]), 'head': 3, 'deprel': 'obj', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('kiiret', [{'id': 4, 'lemma': 'kiire', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('part', 'part')]), 'head': 5, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('.', [{'id': 6, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 3, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]), 'children': (Span('Suur', [{'id': 1, 'lemma': 'suur', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 2, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]),
# Span('jälitas', [{'id': 3, 'lemma': 'jälitama', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('aux', 'aux'), ('indic', 'indic'), ('impf', 'impf'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (Span('koer', [{'id': 2, 'lemma': 'koer', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 3, 'deprel': 'nsubj', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Suur', [{'id': 1, 'lemma': 'suur', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 2, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('kassi', [{'id': 5, 'lemma': 'kass', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('part', 'part')]), 'head': 3, 'deprel': 'obj', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('kiiret', [{'id': 4, 'lemma': 'kiire', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('part', 'part')]), 'head': 5, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('.', [{'id': 6, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 3, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]),
# Span('kiiret', [{'id': 4, 'lemma': 'kiire', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('part', 'part')]), 'head': 5, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': Span('kassi', [{'id': 5, 'lemma': 'kass', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('part', 'part')]), 'head': 3, 'deprel': 'obj', 'deps': '_', 'misc': '_', 'parent_span': Span('jälitas', [{'id': 3, 'lemma': 'jälitama', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('aux', 'aux'), ('indic', 'indic'), ('impf', 'impf'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (Span('koer', [{'id': 2, 'lemma': 'koer', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 3, 'deprel': 'nsubj', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Suur', [{'id': 1, 'lemma': 'suur', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 2, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), ..., Span('.', [{'id': 6, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 3, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]), 'children': (...,)}]), 'children': ()}]),
# Span('kassi', [{'id': 5, 'lemma': 'kass', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('part', 'part')]), 'head': 3, 'deprel': 'obj', 'deps': '_', 'misc': '_', 'parent_span': Span('jälitas', [{'id': 3, 'lemma': 'jälitama', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('aux', 'aux'), ('indic', 'indic'), ('impf', 'impf'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (Span('koer', [{'id': 2, 'lemma': 'koer', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 3, 'deprel': 'nsubj', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Suur', [{'id': 1, 'lemma': 'suur', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 2, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), ..., Span('.', [{'id': 6, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 3, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]))}]), 'children': (Span('kiiret', [{'id': 4, 'lemma': 'kiire', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('part', 'part')]), 'head': 5, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]),
# Span('.', [{'id': 6, 'lemma': '.', 'upostag': 'Z', 'xpostag': 'Z', 'feats': OrderedDict(), 'head': 3, 'deprel': 'punct', 'deps': '_', 'misc': '_', 'parent_span': Span('jälitas', [{'id': 3, 'lemma': 'jälitama', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('aux', 'aux'), ('indic', 'indic'), ('impf', 'impf'), ('ps3', 'ps3'), ('sg', 'sg'), ('ps', 'ps'), ('af', 'af')]), 'head': 0, 'deprel': 'root', 'deps': '_', 'misc': '_', 'parent_span': None, 'children': (Span('koer', [{'id': 2, 'lemma': 'koer', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 3, 'deprel': 'nsubj', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('Suur', [{'id': 1, 'lemma': 'suur', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('nom', 'nom')]), 'head': 2, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), Span('kassi', [{'id': 5, 'lemma': 'kass', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('part', 'part')]), 'head': 3, 'deprel': 'obj', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': (Span('kiiret', [{'id': 4, 'lemma': 'kiire', 'upostag': 'A', 'xpostag': 'A', 'feats': OrderedDict([('pos', 'pos'), ('sg', 'sg'), ('part', 'part')]), 'head': 5, 'deprel': 'amod', 'deps': '_', 'misc': '_', 'parent_span': ..., 'children': ()}]),)}]), ...)}]), 'children': ()}])])

# %% [markdown]
# ## 3. Assemble output

# %%
# Put it all together
def print_token(token, fp):
    #  ****  Old fields
    word = token.text
    ana = token.morph_analysis.annotations[0]
    tag = ana.partofspeech
    features = '_'.join(ana.form.split())
    longtag = '.'.join([tag] + ana.form.split())
    lempos = '%s-%s' % (ana.lemma, tag.lower())
    root = ana.root
    root_tokens = ' '.join(ana.root_tokens)
    clitic = ana.clitic
    ending = ana.ending
    #  ****  New fields
    # First, there are morphosyntactic annotations 
    # from the 'morph_extended' layer (this info is 
    # also used by stanza)
    morph_extended = token.morph_extended.annotations[0]
    extended_feat = '_'.join(morph_extended.form.split())
    # There are some fields, which may not be filled in 
    # for every word. Check that values are not None
    # before including them
    punctuation_type = ''
    pronoun_type = ''
    finite_verb = ''
    subcat = ''
    if morph_extended.punctuation_type is not None:
        punctuation_type = morph_extended.punctuation_type
    if morph_extended.pronoun_type is not None:
        pronoun_type = '_'.join(morph_extended.pronoun_type)
    if morph_extended.fin is not None:
        finite_verb = 'fin' if morph_extended.fin else 'inf'
    if morph_extended.subcat is not None:
        subcat = '_'.join(morph_extended.subcat)
    
    # Syntactic info from stanza
    # ( alternatively, use stanza_ensemble_syntax if you use StanzaSyntaxEnsembleTagger )
    syn_id = token.stanza_syntax.id
    syn_head = token.stanza_syntax.head
    syn_rel = token.stanza_syntax.deprel
    
    # Finally, add information about the syntactic head / parent
    # (if the word is syntactic root, these fields will be empty)
    head_word = ''
    head_lemma = ''
    head_tag = ''
    head_features = ''
    head_syn_rel = ''
    if token.stanza_syntax.parent_span is not None:
        # ( alternatively, use stanza_ensemble_syntax if you use StanzaSyntaxEnsembleTagger )
        # Get parent token
        parent_token = token.stanza_syntax.parent_span
        # Get features of the parent token:
        parent_analysis = parent_token.morph_analysis.annotations[0]
        head_word = parent_token.text
        head_lemma = parent_analysis.lemma
        head_tag = parent_analysis.partofspeech
        head_features = '_'.join(parent_analysis.form.split())
        head_syn_rel = parent_token.stanza_syntax.deprel
    out_str = \
        f'{word}\t{longtag}\t{lempos}\t{features}\t{root_tokens}\t{root}\t{ending}\t{clitic}\t{extended_feat}\t{punctuation_type}\t{pronoun_type}\t{finite_verb}\t{subcat}\t{syn_id}\t{syn_head}\t{syn_rel}\t{head_word}\t{head_lemma}\t{head_tag}\t{head_features}\t{head_syn_rel}'.replace('\n', ' ')
    if fp:
        fp.write( out_str + '\n' )
    else:
        print( out_str )

# %%
for token in t.words:
    print_token(token, None)
# Out:
# Vormi	S.sg.g	vorm-s	sg_g	vorm	vorm	0		com_sg_gen					1	2	nmod	mängude	mäng	S	pl_g	nmod
# mängude	S.pl.g	mäng-s	pl_g	mäng	mäng	de		com_pl_gen					2	5	nmod	valiku	valik	S	sg_g	nmod
# ja	J	ja-j		ja	ja	0		sub_crd					3	4	cc	materjali	materjal	S	sg_g	conj
# materjali	S.sg.g	materjal-s	sg_g	materjal	materjal	0		com_sg_gen					4	2	conj	mängude	mäng	S	pl_g	nmod
# valiku	S.sg.g	valik-s	sg_g	valik	valik	0		com_sg_gen					5	7	nmod	lavastusele	lavastus	S	sg_all	nmod
# eest	K	eest-k		eest	eest	0		post				gen	6	5	case	valiku	valik	S	sg_g	nmod
# lavastusele	S.sg.all	lavastus-s	sg_all	lavastus	lavastus	le		com_sg_all					7	34	nmod	lavastuses	lavastus	S	sg_in	nmod
# "	Z	"-z		"	"				Quo				8	10	punct	poiss	poiss	S	sg_n	appos
# Nähtamatu	A.sg.n	nähtamatu-a	sg_n	nähtamatu	nähtamatu	0		pos_sg_nom					9	10	amod	poiss	poiss	S	sg_n	appos
# poiss	S.sg.n	poiss-s	sg_n	poiss	poiss	0		com_sg_nom					10	7	appos	lavastusele	lavastus	S	sg_all	nmod
# "	Z	"-z		"	"				Quo				11	10	punct	poiss	poiss	S	sg_n	appos
# Haapsalu	G	haapsalu-g		haap salu	haap_salu	0							12	14	amod	Huvikeskuse	huvikeskus	S	sg_g	nmod
# Noorte	S.pl.g	noor-s	pl_g	noor	noor	te		com_pl_gen					13	14	nmod	Huvikeskuse	huvikeskus	S	sg_g	nmod
# Huvikeskuse	S.sg.g	huvikeskus-s	sg_g	huvi keskus	huvi_keskus	0		com_sg_gen					14	15	nmod	loovus-	loovus	S	sg_n	appos
# loovus-	S.sg.n	loovus-s	sg_n	loovus	loovus	0		com_sg_nom					15	10	appos	poiss	poiss	S	sg_n	appos
# ja	J	ja-j		ja	ja	0		sub_crd					16	17	cc	draamaring	draamaring	S	sg_n	conj
# draamaring	S.sg.n	draamaring-s	sg_n	draama ring	draama_ring	0		com_sg_nom					17	15	conj	loovus-	loovus	S	sg_n	appos
# "	Z	"-z		"	"				Quo				18	15	punct	loovus-	loovus	S	sg_n	appos
# Üks	P.sg.n	üks-p	sg_n	üks	üks	0		sg_nom		dem_indef			19	21	det	juhendajad	juhendaja	S	pl_n	appos
# "	Z	"-z		"	"				Quo				20	21	punct	juhendajad	juhendaja	S	pl_n	appos
# juhendajad	S.pl.n	juhendaja-s	pl_n	juhendaja	juhendaja	d		com_pl_nom					21	15	appos	loovus-	loovus	S	sg_n	appos
# Anne	H.sg.n	Anne-h	sg_n	Anne	Anne	0		prop_sg_nom					22	21	appos	juhendajad	juhendaja	S	pl_n	appos
# Suislep	H.sg.n	Suislep-h	sg_n	Suislep	Suislep	0		prop_sg_nom					23	22	flat	Anne	Anne	H	sg_n	appos
# ja	J	ja-j		ja	ja	0		sub_crd					24	25	cc	Triin	Triin	H	sg_n	nmod
# Triin	H.sg.n	Triin-h	sg_n	Triin	Triin	0		prop_sg_nom					25	29	nmod	huumori	huumor	S	sg_g	nmod
# Reemann	H.sg.n	Reemann-h	sg_n	Ree mann	Ree_mann	0		prop_sg_nom					26	25	flat	Triin	Triin	H	sg_n	nmod
# Energilise	H.sg.g	Energiline-h	sg_g	Energiline	Energiline	0		prop_sg_gen					27	25	flat	Triin	Triin	H	sg_n	nmod
# lastepärase	A.sg.g	lastepärane-a	sg_g	laste pärane	laste_pärane	0		pos_sg_gen					28	29	amod	huumori	huumor	S	sg_g	nmod
# huumori	S.sg.g	huumor-s	sg_g	huumor	huumor	0		com_sg_gen					29	32	nmod	jutustamise	jutustamine	S	sg_g	nmod
# ja	J	ja-j		ja	ja	0		sub_crd					30	31	cc	loo	lugu	S	sg_g	conj
# loo	S.sg.g	lugu-s	sg_g	lugu	lugu	0		com_sg_gen					31	29	conj	huumori	huumor	S	sg_g	nmod
# jutustamise	S.sg.g	jutustamine-s	sg_g	jutustamine	jutustamine	0		com_sg_gen					32	21	nmod	juhendajad	juhendaja	S	pl_n	appos
# eest	K	eest-k		eest	eest	0		post				gen	33	32	case	jutustamise	jutustamine	S	sg_g	nmod
# lavastuses	S.sg.in	lavastus-s	sg_in	lavastus	lavastus	s		com_sg_in					34	36	nmod	Ull	Ull	H	sg_n	nsubj:cop
# "	Z	"-z		"	"				Quo				35	36	punct	Ull	Ull	H	sg_n	nsubj:cop
# Ull	H.sg.n	Ull-h	sg_n	Ull	Ull	0		prop_sg_nom					36	41	nsubj:cop	häda	häda	S	sg_n	nsubj:cop
# Jaak	H.sg.n	Jaak-h	sg_n	Jaak	Jaak	0		prop_sg_nom					37	36	flat	Ull	Ull	H	sg_n	nsubj:cop
# ehk	D	ehk-d		ehk	ehk	0							38	36	advmod	Ull	Ull	H	sg_n	nsubj:cop
# küll	D	küll-d		küll	küll	0							39	36	advmod	Ull	Ull	H	sg_n	nsubj:cop
# on	V.b	olema-v	b	ole	ole	0		mod_indic_pres_ps3_sg_ps_af			fin	Intr	40	41	cop	häda	häda	S	sg_n	nsubj:cop
# häda	S.sg.n	häda-s	sg_n	häda	häda	0		com_sg_nom					41	47	nsubj:cop	juhendaja	juhendaja	S	sg_n	nmod
# kui	J	kui-j		kui	kui	0		sub_crd					42	43	mark	pea	pea	S	sg_n	advcl
# pea	S.sg.n	pea-s	sg_n	pea	pea	0		com_sg_nom					43	41	advcl	häda	häda	S	sg_n	nsubj:cop
# on	V.b	olema-v	b	ole	ole	0		mod_indic_pres_ps3_sg_ps_af			fin	Intr	44	45	cop	mäda	mäda	A	sg_n	amod
# mäda	A.sg.n	mäda-a	sg_n	mäda	mäda	0		pos_sg_nom					45	47	amod	juhendaja	juhendaja	S	sg_n	nmod
# "	Z	"-z		"	"				Quo				46	47	punct	juhendaja	juhendaja	S	sg_n	nmod
# juhendaja	S.sg.n	juhendaja-s	sg_n	juhendaja	juhendaja	0		com_sg_nom					47	53	nmod	näitering	näitering	S	sg_n	root
# Kadi	H.sg.n	Kadi-h	sg_n	Kadi	Kadi	0		prop_sg_nom					48	47	appos	juhendaja	juhendaja	S	sg_n	nmod
# Kronberg	H.sg.n	Kronberg-h	sg_n	Kronberg	Kronberg	0		prop_sg_nom					49	48	flat	Kadi	Kadi	H	sg_n	appos
# Lasva	H.sg.g	Lasva-h	sg_g	Lasva	Lasva	0		prop_sg_gen					50	48	flat	Kadi	Kadi	H	sg_n	appos
# Rahvamaja	S.sg.g	rahvamaja-s	sg_g	rahva maja	rahva_maja	0		com_sg_gen					51	52	nmod	laste	laps	S	pl_g	nmod
# laste	S.pl.g	laps-s	pl_g	laps	laps	te		com_pl_gen					52	53	nmod	näitering	näitering	S	sg_n	root
# näitering	S.sg.n	näitering-s	sg_n	näite ring	näite_ring	0		com_sg_nom					53	0	root
# (	Z	(-z		(	(				Opr				54	55	punct	Võrumaa	võrumaa	G		parataxis
# Võrumaa	G	võrumaa-g		võru maa	võru_maa	0							55	53	parataxis	näitering	näitering	S	sg_n	root
# )	Z	)-z		)	)				Cpr				56	55	punct	Võrumaa	võrumaa	G		parataxis
# .	Z	.-z		.	.				Fst				57	41	punct	häda	häda	S	sg_n	nsubj:cop
# Preemia	S.sg.g	preemia-s	sg_g	preemia	preemia	0		com_sg_gen					1	2	nmod	väljaandjaks	väljaandja	S	sg_tr	root
# väljaandjaks	S.sg.tr	väljaandja-s	sg_tr	välja andja	välja_andja	ks		com_sg_tr					2	0	root
# on	V.b	olema-v	b	ole	ole	0		mod_indic_pres_ps3_sg_ps_af			fin	Intr	3	2	cop	väljaandjaks	väljaandja	S	sg_tr	root
# MTÜ	Y.?	MTÜ-y	?	MTÜ	MTÜ	0		nominal					4	6	nmod	Teater	teater	S	sg_n	nsubj:cop
# Vilde	H.sg.g	Vilde-h	sg_g	Vilde	Vilde	0		prop_sg_gen					5	4	flat	MTÜ	MTÜ	Y	?	nmod
# Teater	S.sg.n	teater-s	sg_n	teater	teater	0		com_sg_nom					6	2	nsubj:cop	väljaandjaks	väljaandja	S	sg_tr	root
# .	Z	.-z		.	.				Fst				7	2	punct	väljaandjaks	väljaandja	S	sg_tr	root
# Edgar	H.sg.n	Edgar-h	sg_n	Edgar	Edgar	0		prop_sg_nom					1	0	root
# Savisaar	H.sg.n	Savisaar-h	sg_n	Savi saar	Savi_saar	0		prop_sg_nom					2	1	flat	Edgar	Edgar	H	sg_n	root
# .	Z	.-z		.	.				Fst				3	1	punct	Edgar	Edgar	H	sg_n	root
# Siin	D	siin-d		siin	siin	0							1	2	advmod	lauses	lause	S	sg_in	root
# lauses	S.sg.in	lause-s	sg_in	lause	lause	s		com_sg_in					2	0	root
# pole	V.neg.o	olema-v	neg_o	ole	ole	0		aux_imper_pres_ps2_sg_ps_neg			fin	Intr	3	2	cop	lauses	lause	S	sg_in	root
# midagi	P.sg.p	miski-p	sg_p	miski	miski	dagi		sg_part		inter_rel			4	5	obj	analüüsida	analüüsima	V	da	csubj:cop
# analüüsida	V.da	analüüsima-v	da	analüüsi	analüüsi	da		mod_inf			inf		5	2	csubj:cop	lauses	lause	S	sg_in	root
# .	Z	.-z		.	.				Fst				6	2	punct	lauses	lause	S	sg_in	root
# See	P.sg.n	see-p	sg_n	see	see	0		sg_nom		dem			1	4	nsubj:cop	Filosoof	filosoof	S	sg_n	root
# on	V.b	olema-v	b	ole	ole	0		mod_indic_pres_ps3_sg_ps_af			fin	Intr	2	4	cop	Filosoof	filosoof	S	sg_n	root
# Tõlkebüroo	S.sg.g	tõlkebüroo-s	sg_g	tõlke büroo	tõlke_büroo	0		com_sg_gen					3	4	nmod	Filosoof	filosoof	S	sg_n	root
# Filosoof	S.sg.n	filosoof-s	sg_n	filosoof	filosoof	0		com_sg_nom					4	0	root
# .	Z	.-z		.	.				Fst				5	4	punct	Filosoof	filosoof	S	sg_n	root
# Suur	A.sg.n	suur-a	sg_n	suur	suur	0		pos_sg_nom					1	2	amod	koer	koer	S	sg_n	nsubj
# koer	S.sg.n	koer-s	sg_n	koer	koer	0		com_sg_nom					2	3	nsubj	jälitas	jälitama	V	s	root
# jälitas	V.s	jälitama-v	s	jälita	jälita	s		mod_indic_impf_ps3_sg_ps_af			fin	Part	3	0	root
# kiiret	A.sg.p	kiire-a	sg_p	kiire	kiire	t		pos_sg_part					4	5	amod	kassi	kass	S	sg_p	obj
# kassi	S.sg.p	kass-s	sg_p	kass	kass	0		com_sg_part					5	3	obj	jälitas	jälitama	V	s	root
# .	Z	.-z		.	.				Fst				6	3	punct	jälitas	jälitama	V	s	root

# %%
# Just for testing: separate rows with ===
for token in t.words:
    print_token(token, None)
    print('='*100)
# Out:
# Vormi	S.sg.g	vorm-s	sg_g	vorm	vorm	0		com_sg_gen					1	2	nmod	mängude	mäng	S	pl_g	nmod
# ====================================================================================================
# mängude	S.pl.g	mäng-s	pl_g	mäng	mäng	de		com_pl_gen					2	5	nmod	valiku	valik	S	sg_g	nmod
# ====================================================================================================
# ja	J	ja-j		ja	ja	0		sub_crd					3	4	cc	materjali	materjal	S	sg_g	conj
# ====================================================================================================
# materjali	S.sg.g	materjal-s	sg_g	materjal	materjal	0		com_sg_gen					4	2	conj	mängude	mäng	S	pl_g	nmod
# ====================================================================================================
# valiku	S.sg.g	valik-s	sg_g	valik	valik	0		com_sg_gen					5	7	nmod	lavastusele	lavastus	S	sg_all	nmod
# ====================================================================================================
# eest	K	eest-k		eest	eest	0		post				gen	6	5	case	valiku	valik	S	sg_g	nmod
# ====================================================================================================
# lavastusele	S.sg.all	lavastus-s	sg_all	lavastus	lavastus	le		com_sg_all					7	34	nmod	lavastuses	lavastus	S	sg_in	nmod
# ====================================================================================================
# "	Z	"-z		"	"				Quo				8	10	punct	poiss	poiss	S	sg_n	appos
# ====================================================================================================
# Nähtamatu	A.sg.n	nähtamatu-a	sg_n	nähtamatu	nähtamatu	0		pos_sg_nom					9	10	amod	poiss	poiss	S	sg_n	appos
# ====================================================================================================
# poiss	S.sg.n	poiss-s	sg_n	poiss	poiss	0		com_sg_nom					10	7	appos	lavastusele	lavastus	S	sg_all	nmod
# ====================================================================================================
# "	Z	"-z		"	"				Quo				11	10	punct	poiss	poiss	S	sg_n	appos
# ====================================================================================================
# Haapsalu	G	haapsalu-g		haap salu	haap_salu	0							12	14	amod	Huvikeskuse	huvikeskus	S	sg_g	nmod
# ====================================================================================================
# Noorte	S.pl.g	noor-s	pl_g	noor	noor	te		com_pl_gen					13	14	nmod	Huvikeskuse	huvikeskus	S	sg_g	nmod
# ====================================================================================================
# Huvikeskuse	S.sg.g	huvikeskus-s	sg_g	huvi keskus	huvi_keskus	0		com_sg_gen					14	15	nmod	loovus-	loovus	S	sg_n	appos
# ====================================================================================================
# loovus-	S.sg.n	loovus-s	sg_n	loovus	loovus	0		com_sg_nom					15	10	appos	poiss	poiss	S	sg_n	appos
# ====================================================================================================
# ja	J	ja-j		ja	ja	0		sub_crd					16	17	cc	draamaring	draamaring	S	sg_n	conj
# ====================================================================================================
# draamaring	S.sg.n	draamaring-s	sg_n	draama ring	draama_ring	0		com_sg_nom					17	15	conj	loovus-	loovus	S	sg_n	appos
# ====================================================================================================
# "	Z	"-z		"	"				Quo				18	15	punct	loovus-	loovus	S	sg_n	appos
# ====================================================================================================
# Üks	P.sg.n	üks-p	sg_n	üks	üks	0		sg_nom		dem_indef			19	21	det	juhendajad	juhendaja	S	pl_n	appos
# ====================================================================================================
# "	Z	"-z		"	"				Quo				20	21	punct	juhendajad	juhendaja	S	pl_n	appos
# ====================================================================================================
# juhendajad	S.pl.n	juhendaja-s	pl_n	juhendaja	juhendaja	d		com_pl_nom					21	15	appos	loovus-	loovus	S	sg_n	appos
# ====================================================================================================
# Anne	H.sg.n	Anne-h	sg_n	Anne	Anne	0		prop_sg_nom					22	21	appos	juhendajad	juhendaja	S	pl_n	appos
# ====================================================================================================
# Suislep	H.sg.n	Suislep-h	sg_n	Suislep	Suislep	0		prop_sg_nom					23	22	flat	Anne	Anne	H	sg_n	appos
# ====================================================================================================
# ja	J	ja-j		ja	ja	0		sub_crd					24	25	cc	Triin	Triin	H	sg_n	nmod
# ====================================================================================================
# Triin	H.sg.n	Triin-h	sg_n	Triin	Triin	0		prop_sg_nom					25	29	nmod	huumori	huumor	S	sg_g	nmod
# ====================================================================================================
# Reemann	H.sg.n	Reemann-h	sg_n	Ree mann	Ree_mann	0		prop_sg_nom					26	25	flat	Triin	Triin	H	sg_n	nmod
# ====================================================================================================
# Energilise	H.sg.g	Energiline-h	sg_g	Energiline	Energiline	0		prop_sg_gen					27	25	flat	Triin	Triin	H	sg_n	nmod
# ====================================================================================================
# lastepärase	A.sg.g	lastepärane-a	sg_g	laste pärane	laste_pärane	0		pos_sg_gen					28	29	amod	huumori	huumor	S	sg_g	nmod
# ====================================================================================================
# huumori	S.sg.g	huumor-s	sg_g	huumor	huumor	0		com_sg_gen					29	32	nmod	jutustamise	jutustamine	S	sg_g	nmod
# ====================================================================================================
# ja	J	ja-j		ja	ja	0		sub_crd					30	31	cc	loo	lugu	S	sg_g	conj
# ====================================================================================================
# loo	S.sg.g	lugu-s	sg_g	lugu	lugu	0		com_sg_gen					31	29	conj	huumori	huumor	S	sg_g	nmod
# ====================================================================================================
# jutustamise	S.sg.g	jutustamine-s	sg_g	jutustamine	jutustamine	0		com_sg_gen					32	21	nmod	juhendajad	juhendaja	S	pl_n	appos
# ====================================================================================================
# eest	K	eest-k		eest	eest	0		post				gen	33	32	case	jutustamise	jutustamine	S	sg_g	nmod
# ====================================================================================================
# lavastuses	S.sg.in	lavastus-s	sg_in	lavastus	lavastus	s		com_sg_in					34	36	nmod	Ull	Ull	H	sg_n	nsubj:cop
# ====================================================================================================
# "	Z	"-z		"	"				Quo				35	36	punct	Ull	Ull	H	sg_n	nsubj:cop
# ====================================================================================================
# Ull	H.sg.n	Ull-h	sg_n	Ull	Ull	0		prop_sg_nom					36	41	nsubj:cop	häda	häda	S	sg_n	nsubj:cop
# ====================================================================================================
# Jaak	H.sg.n	Jaak-h	sg_n	Jaak	Jaak	0		prop_sg_nom					37	36	flat	Ull	Ull	H	sg_n	nsubj:cop
# ====================================================================================================
# ehk	D	ehk-d		ehk	ehk	0							38	36	advmod	Ull	Ull	H	sg_n	nsubj:cop
# ====================================================================================================
# küll	D	küll-d		küll	küll	0							39	36	advmod	Ull	Ull	H	sg_n	nsubj:cop
# ====================================================================================================
# on	V.b	olema-v	b	ole	ole	0		mod_indic_pres_ps3_sg_ps_af			fin	Intr	40	41	cop	häda	häda	S	sg_n	nsubj:cop
# ====================================================================================================
# häda	S.sg.n	häda-s	sg_n	häda	häda	0		com_sg_nom					41	47	nsubj:cop	juhendaja	juhendaja	S	sg_n	nmod
# ====================================================================================================
# kui	J	kui-j		kui	kui	0		sub_crd					42	43	mark	pea	pea	S	sg_n	advcl
# ====================================================================================================
# pea	S.sg.n	pea-s	sg_n	pea	pea	0		com_sg_nom					43	41	advcl	häda	häda	S	sg_n	nsubj:cop
# ====================================================================================================
# on	V.b	olema-v	b	ole	ole	0		mod_indic_pres_ps3_sg_ps_af			fin	Intr	44	45	cop	mäda	mäda	A	sg_n	amod
# ====================================================================================================
# mäda	A.sg.n	mäda-a	sg_n	mäda	mäda	0		pos_sg_nom					45	47	amod	juhendaja	juhendaja	S	sg_n	nmod
# ====================================================================================================
# "	Z	"-z		"	"				Quo				46	47	punct	juhendaja	juhendaja	S	sg_n	nmod
# ====================================================================================================
# juhendaja	S.sg.n	juhendaja-s	sg_n	juhendaja	juhendaja	0		com_sg_nom					47	53	nmod	näitering	näitering	S	sg_n	root
# ====================================================================================================
# Kadi	H.sg.n	Kadi-h	sg_n	Kadi	Kadi	0		prop_sg_nom					48	47	appos	juhendaja	juhendaja	S	sg_n	nmod
# ====================================================================================================
# Kronberg	H.sg.n	Kronberg-h	sg_n	Kronberg	Kronberg	0		prop_sg_nom					49	48	flat	Kadi	Kadi	H	sg_n	appos
# ====================================================================================================
# Lasva	H.sg.g	Lasva-h	sg_g	Lasva	Lasva	0		prop_sg_gen					50	48	flat	Kadi	Kadi	H	sg_n	appos
# ====================================================================================================
# Rahvamaja	S.sg.g	rahvamaja-s	sg_g	rahva maja	rahva_maja	0		com_sg_gen					51	52	nmod	laste	laps	S	pl_g	nmod
# ====================================================================================================
# laste	S.pl.g	laps-s	pl_g	laps	laps	te		com_pl_gen					52	53	nmod	näitering	näitering	S	sg_n	root
# ====================================================================================================
# näitering	S.sg.n	näitering-s	sg_n	näite ring	näite_ring	0		com_sg_nom					53	0	root
# ====================================================================================================
# (	Z	(-z		(	(				Opr				54	55	punct	Võrumaa	võrumaa	G		parataxis
# ====================================================================================================
# Võrumaa	G	võrumaa-g		võru maa	võru_maa	0							55	53	parataxis	näitering	näitering	S	sg_n	root
# ====================================================================================================
# )	Z	)-z		)	)				Cpr				56	55	punct	Võrumaa	võrumaa	G		parataxis
# ====================================================================================================
# .	Z	.-z		.	.				Fst				57	41	punct	häda	häda	S	sg_n	nsubj:cop
# ====================================================================================================
# Preemia	S.sg.g	preemia-s	sg_g	preemia	preemia	0		com_sg_gen					1	2	nmod	väljaandjaks	väljaandja	S	sg_tr	root
# ====================================================================================================
# väljaandjaks	S.sg.tr	väljaandja-s	sg_tr	välja andja	välja_andja	ks		com_sg_tr					2	0	root
# ====================================================================================================
# on	V.b	olema-v	b	ole	ole	0		mod_indic_pres_ps3_sg_ps_af			fin	Intr	3	2	cop	väljaandjaks	väljaandja	S	sg_tr	root
# ====================================================================================================
# MTÜ	Y.?	MTÜ-y	?	MTÜ	MTÜ	0		nominal					4	6	nmod	Teater	teater	S	sg_n	nsubj:cop
# ====================================================================================================
# Vilde	H.sg.g	Vilde-h	sg_g	Vilde	Vilde	0		prop_sg_gen					5	4	flat	MTÜ	MTÜ	Y	?	nmod
# ====================================================================================================
# Teater	S.sg.n	teater-s	sg_n	teater	teater	0		com_sg_nom					6	2	nsubj:cop	väljaandjaks	väljaandja	S	sg_tr	root
# ====================================================================================================
# .	Z	.-z		.	.				Fst				7	2	punct	väljaandjaks	väljaandja	S	sg_tr	root
# ====================================================================================================
# Edgar	H.sg.n	Edgar-h	sg_n	Edgar	Edgar	0		prop_sg_nom					1	0	root
# ====================================================================================================
# Savisaar	H.sg.n	Savisaar-h	sg_n	Savi saar	Savi_saar	0		prop_sg_nom					2	1	flat	Edgar	Edgar	H	sg_n	root
# ====================================================================================================
# .	Z	.-z		.	.				Fst				3	1	punct	Edgar	Edgar	H	sg_n	root
# ====================================================================================================
# Siin	D	siin-d		siin	siin	0							1	2	advmod	lauses	lause	S	sg_in	root
# ====================================================================================================
# lauses	S.sg.in	lause-s	sg_in	lause	lause	s		com_sg_in					2	0	root
# ====================================================================================================
# pole	V.neg.o	olema-v	neg_o	ole	ole	0		aux_imper_pres_ps2_sg_ps_neg			fin	Intr	3	2	cop	lauses	lause	S	sg_in	root
# ====================================================================================================
# midagi	P.sg.p	miski-p	sg_p	miski	miski	dagi		sg_part		inter_rel			4	5	obj	analüüsida	analüüsima	V	da	csubj:cop
# ====================================================================================================
# analüüsida	V.da	analüüsima-v	da	analüüsi	analüüsi	da		mod_inf			inf		5	2	csubj:cop	lauses	lause	S	sg_in	root
# ====================================================================================================
# .	Z	.-z		.	.				Fst				6	2	punct	lauses	lause	S	sg_in	root
# ====================================================================================================
# See	P.sg.n	see-p	sg_n	see	see	0		sg_nom		dem			1	4	nsubj:cop	Filosoof	filosoof	S	sg_n	root
# ====================================================================================================
# on	V.b	olema-v	b	ole	ole	0		mod_indic_pres_ps3_sg_ps_af			fin	Intr	2	4	cop	Filosoof	filosoof	S	sg_n	root
# ====================================================================================================
# Tõlkebüroo	S.sg.g	tõlkebüroo-s	sg_g	tõlke büroo	tõlke_büroo	0		com_sg_gen					3	4	nmod	Filosoof	filosoof	S	sg_n	root
# ====================================================================================================
# Filosoof	S.sg.n	filosoof-s	sg_n	filosoof	filosoof	0		com_sg_nom					4	0	root
# ====================================================================================================
# .	Z	.-z		.	.				Fst				5	4	punct	Filosoof	filosoof	S	sg_n	root
# ====================================================================================================
# Suur	A.sg.n	suur-a	sg_n	suur	suur	0		pos_sg_nom					1	2	amod	koer	koer	S	sg_n	nsubj
# ====================================================================================================
# koer	S.sg.n	koer-s	sg_n	koer	koer	0		com_sg_nom					2	3	nsubj	jälitas	jälitama	V	s	root
# ====================================================================================================
# jälitas	V.s	jälitama-v	s	jälita	jälita	s		mod_indic_impf_ps3_sg_ps_af			fin	Part	3	0	root
# ====================================================================================================
# kiiret	A.sg.p	kiire-a	sg_p	kiire	kiire	t		pos_sg_part					4	5	amod	kassi	kass	S	sg_p	obj
# ====================================================================================================
# kassi	S.sg.p	kass-s	sg_p	kass	kass	0		com_sg_part					5	3	obj	jälitas	jälitama	V	s	root
# ====================================================================================================
# .	Z	.-z		.	.				Fst				6	3	punct	jälitas	jälitama	V	s	root
# ====================================================================================================
