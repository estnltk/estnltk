# %% [markdown]
# ## Small test: how new Vabamorf binary dictionaries work compared to old ones

# %%
from estnltk import Text
from estnltk.vabamorf.morf import Vabamorf as VabamorfInstance
from estnltk.taggers import VabamorfAnalyzer, VabamorfDisambiguator, VabamorfTagger

# Create morph analyser that uses new dictionaries
def create_new_vm_tagger_components( lex_path, disamb_lex_path ):
    # change dictionary
    # for details, see:  https://github.com/estnltk/estnltk/blob/version_1.6/tutorials/nlp_pipeline/B_06_morphological_analysis.ipynb
    vm_instance   = VabamorfInstance( lex_path=lex_path, disamb_lex_path=disamb_lex_path )
    analyser      = VabamorfAnalyzer( output_layer='new_morph_analysis', vm_instance=vm_instance )
    disambiguator = VabamorfDisambiguator( output_layer='new_morph_analysis', vm_instance=vm_instance )
    tagger        = VabamorfTagger( output_layer='new_morph_analysis', vm_instance=vm_instance )
    return analyser, disambiguator, tagger

# download new dictionaries from:  https://github.com/Filosoft/vabamorf/tree/master/dct/binary
new_analyser, new_disambiguator, new_tagger = create_new_vm_tagger_components( '2019-10-15_et.dct', '2019-10-15_et3.dct' )

# %% [markdown]
# ### Test on Estonian Web Treebank (web texts)

# %%
import os

# corpus from  https://github.com/UniversalDependencies/UD_Estonian-EWT/ (exact commit: 6cd4d14)
eval_data_dir = 'UD_Estonian-EWT-master'

from estnltk.converters.conll_importer import conll_to_texts_list

loaded_texts = []
for fname in os.listdir( eval_data_dir ):
    if fname.endswith('.conllu'):
        fpath = os.path.join( eval_data_dir, fname )
        texts = conll_to_texts_list(file = fpath, syntax_layer='ud_syntax')
        for text in texts:
            text.meta['file'] = fname
            loaded_texts.append( text )

# %%
total_words = 0
differences = 0
for text in loaded_texts:
    # 1) add default/old morph analysis
    text.tag_layer(['morph_analysis'])
    # 2) add new morph analysis
    new_tagger.tag(text)
    # 3) compare
    for word in text.words:
        # old morph analyses
        old_morph = word.morph_analysis
        # new morph analyses
        new_morph = word.new_morph_analysis
        if old_morph != new_morph:
            # Output changed analyses
            old_analyses = [(a.root, a.partofspeech, a.form) for a in old_morph.annotations]
            new_analyses = [(a.root, a.partofspeech, a.form) for a in new_morph.annotations]
            print(word.text, old_analyses, '-->', new_analyses)
            print()
            differences += 1
        total_words += 1
print ('Total differences: ', differences, '/', total_words)
# Out:
# mürasem [('mürasem', 'S', 'sg n')] --> [('mürase=m', 'C', 'sg n')]
#
# suht [('suht', 'S', 'sg n')] --> [('suht', 'D', '')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# jura [('jura', 'V', 'o')] --> [('jura', 'S', 'sg p')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# ok [('ok', 'Y', '?')] --> [('ok', 'I', '')]
#
# ok [('ok', 'Y', '?')] --> [('ok', 'I', '')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# ups [('ups', 'S', 'sg n')] --> [('ups', 'I', '')]
#
# suht [('suht', 'S', 'sg n')] --> [('suht', 'D', '')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# masuajal [('masua=ja', 'S', 'sg ad')] --> [('masu_aeg', 'S', 'sg ad')]
#
# meilitsi [('meilits', 'S', 'adt')] --> [('meilitsi', 'D', '')]
#
# Linnutad [('Linnutad', 'H', 'sg n'), ('Linnuta', 'H', 'pl n')] --> [('linnuta', 'V', 'd')]
#
# timmid [('timmi', 'V', 'd')] --> [('timm', 'S', 'pl n')]
#
# selmet [('selmet', 'S', 'sg n')] --> [('selmet', 'J', '')]
#
# muideks [('mui', 'S', 'pl tr')] --> [('muideks', 'D', '')]
#
# muideks [('mui', 'S', 'pl tr')] --> [('muideks', 'D', '')]
#
# kontrolöri [('kontrolör', 'S', 'sg p')] --> [('kontrolör', 'S', 'sg g')]
#
# eksju [('eksju', 'S', 'sg n')] --> [('eks_ju', 'D', '')]
#
# suht [('suht', 'S', 'sg n')] --> [('suht', 'D', '')]
#
# muideks [('mui', 'S', 'pl tr')] --> [('muideks', 'D', '')]
#
# Muideks [('Mui', 'H', 'pl tr')] --> [('muideks', 'D', '')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# muideks [('mui', 'S', 'pl tr')] --> [('muideks', 'D', '')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# jubinad [('jubinad', 'S', 'sg n'), ('jubina', 'S', 'pl n'), ('jubin', 'S', 'pl n')] --> [('jubin', 'S', 'pl n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# transarasvavabasid [('transarasva_vaba', 'A', 'pl p')] --> [('transa_rasva_vaba', 'A', 'pl p')]
#
# Hiinalinn [('Hiinalinn', 'H', 'sg n')] --> [('hiina_linn', 'S', 'sg n')]
#
# Kokkamine [('Kokka=mine', 'H', 'sg n')] --> [('kokka=mine', 'S', 'sg n')]
#
# mingi [('mingi', 'P', 'sg g')] --> [('mingi', 'P', 'sg n')]
#
# niidi [('niit', 'S', 'sg g')] --> [('niiti', 'V', 'o')]
#
# tegelt [('tegelt', 'S', 'sg n')] --> [('tegelt', 'D', '')]
#
# suht [('suht', 'S', 'sg n')] --> [('suht', 'D', '')]
#
# Jõuluvanausuliste [('jõulu_vana_usuline', 'A', 'pl g')] --> [('jõulu_vana_usu=line', 'A', 'pl g')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# sõbrantsile [('sõbrantsi', 'S', 'sg all'), ('sõbrants', 'S', 'sg all')] --> [('sõbrants', 'S', 'sg all')]
#
# tegelt [('tegelt', 'S', 'sg n')] --> [('tegelt', 'D', '')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# beibeks [('beib', 'S', 'sg tr')] --> [('beibe', 'S', 'sg tr')]
#
# suht [('suht', 'S', 'sg n')] --> [('suht', 'D', '')]
#
# suht [('suht', 'S', 'sg n')] --> [('suht', 'D', '')]
#
# narusmaili [('narus_mail', 'S', 'sg g')] --> [('naru_smaili', 'S', 'sg g')]
#
# ta [('tema', 'P', 'sg g')] --> [('tema', 'P', 'sg n')]
#
# suht [('suht', 'S', 'sg n')] --> [('suht', 'D', '')]
#
# naerusmaili [('naerus_mail', 'S', 'sg p')] --> [('naeru_smaili', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# veits [('veits', 'S', 'sg n')] --> [('veits', 'D', '')]
#
# onju [('onju', 'S', 'sg n')] --> [('on_ju', 'D', '')]
#
# ok [('ok', 'Y', '?')] --> [('ok', 'I', '')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# playlisti [('playl=ist', 'S', 'sg g')] --> [('play_list', 'S', 'sg g')]
#
# playlist [('playlist', 'S', 'sg n')] --> [('play_list', 'S', 'sg n')]
#
# jopanud [('jopa=nud', 'A', ''), ('jopa=nud', 'A', 'sg n'), ('jopa=nud', 'A', 'pl n')] --> [('jopa=nud', 'A', ''), ('jopa=nud', 'A', 'sg n'), ('jopa=nud', 'A', 'pl n'), ('joppa', 'V', 'nud')]
#
# muideks [('mui', 'S', 'pl tr')] --> [('muideks', 'D', '')]
#
# playlisti [('playl=ist', 'S', 'sg g')] --> [('play_list', 'S', 'sg g')]
#
# playlisti [('playl=ist', 'S', 'sg g')] --> [('play_list', 'S', 'sg g')]
#
# playlistis [('playl=ist', 'S', 'sg in')] --> [('play_list', 'S', 'sg in')]
#
# playlisti [('playl=ist', 'S', 'sg g')] --> [('play_list', 'S', 'sg g')]
#
# progedel [('prog_edel', 'S', 'sg n')] --> [('proge', 'S', 'pl ad')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# mingise [('mingis', 'S', 'sg g')] --> [('mingine', 'P', 'sg g')]
#
# jargi [('jargi', 'S', 'sg n')] --> [('jarg', 'S', 'sg p')]
#
# tegelt [('tegelt', 'S', 'sg n')] --> [('tegelt', 'D', '')]
#
# suht [('suht', 'S', 'sg n')] --> [('suht', 'D', '')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# hängin [('hängi', 'V', 'n'), ('hänki', 'V', 'n')] --> [('hängi', 'V', 'n')]
#
# orgunnida [('orgunnida', 'S', 'sg n')] --> [('orgunni', 'V', 'da')]
#
# orgunni [('orgunn', 'S', 'sg g'), ('orgunni', 'S', 'sg g')] --> [('orgunni', 'V', 'o')]
#
# mina [('mina', 'P', 'sg n')] --> [('mina', 'S', 'sg p')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Blogid [('Blog', 'H', 'pl n'), ('Blogid', 'H', 'sg n'), ('Blogi', 'H', 'pl n')] --> [('blogi', 'S', 'pl n')]
#
# ok [('ok', 'Y', '?')] --> [('ok', 'I', '')]
#
# telklasse [('telk_lass', 'S', 'pl p')] --> [('telkla', 'S', 'sg ill')]
#
# telklas [('telklas', 'S', 'sg n')] --> [('telkla', 'S', 'sg in')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# kellegiga [('kelle_giga', 'S', 'sg p')] --> [('kelleg', 'S', 'sg kom'), ('kellegi', 'S', 'sg kom')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Muideks [('Mui', 'H', 'pl tr')] --> [('muideks', 'D', '')]
#
# fotokad [('fotoka', 'S', 'pl n'), ('fotokas', 'S', 'pl n')] --> [('fotokas', 'S', 'pl n')]
#
# antikristust [('antikristu', 'S', 'sg el')] --> [('anti_kristus', 'S', 'sg p')]
#
# konsentratsiooniks [('konsentratsioo_niks', 'S', 'sg n')] --> [('konsentratsiooni', 'V', 'ks')]
#
# eksid [('eksi', 'V', 'd')] --> [('eks', 'S', 'pl n')]
#
# muideks [('mui', 'S', 'pl tr')] --> [('muideks', 'D', '')]
#
# Total differences:  98 / 27286

# %% [markdown]
# ### Test on Estonian UD corpus (more or less standard written language)

# %%
import os

# corpus from  https://github.com/UniversalDependencies/UD_Estonian-EDT (version 2.4)
eval_data_dir = 'UD_Estonian-EDT-master'

from estnltk.converters.conll_importer import conll_to_texts_list

loaded_texts = []
for fname in os.listdir( eval_data_dir ):
    if fname.endswith('dev.conllu'):  # Take out dev part of the corpus
        fpath = os.path.join( eval_data_dir, fname )
        texts = conll_to_texts_list(file = fpath, syntax_layer='ud_syntax')
        for text in texts:
            text.meta['file'] = fname
            loaded_texts.append( text )

# %%
total_words = 0
differences = 0
for text in loaded_texts:
    # 1) add default/old morph analysis
    text.tag_layer(['morph_analysis'])
    # 2) add new morph analysis
    new_tagger.tag(text)
    # 3) compare
    for word in text.words:
        # old morph analyses
        old_morph = word.morph_analysis
        # new morph analyses
        new_morph = word.new_morph_analysis
        if old_morph != new_morph:
            # Output changed analyses
            old_analyses = [(a.root, a.partofspeech, a.form) for a in old_morph.annotations]
            new_analyses = [(a.root, a.partofspeech, a.form) for a in new_morph.annotations]
            print(word.text, old_analyses, '-->', new_analyses)
            print()
            differences += 1
        total_words += 1
print ('Total differences: ', differences, '/', total_words)
# Out:
# millenniumi [('millennium', 'S', 'sg g'), ('millenniumi', 'S', 'sg g')] --> [('millennium', 'S', 'sg g')]
#
# Manerism [('Manerism', 'H', 'sg n')] --> [('manerism', 'S', 'sg n')]
#
# tselluliidile [('tselluliid', 'S', 'sg all'), ('tselluliit', 'S', 'sg all')] --> [('tselluliit', 'S', 'sg all')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# ugrimugride [('ugrimugr', 'S', 'pl g'), ('ugrimugri', 'S', 'pl g')] --> [('ugri_mugri', 'S', 'pl g')]
#
# venelikku [('vene_ligu', 'S', 'adt')] --> [('venelik', 'A', 'sg p')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# udmurdi [('udmurt', 'S', 'sg g')] --> [('udmurdi', 'G', '')]
#
# Kalašnikovi [('Kalašnikov', 'H', 'sg g')] --> [('kalašnikov', 'S', 'sg g')]
#
# Udmurdi [('Udmurd', 'H', 'sg g'), ('Udmurdi', 'H', 'sg g'), ('Udmurt', 'H', 'sg g')] --> [('udmurdi', 'G', '')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# MIKS [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# miksidel [('miks', 'S', 'pl ad'), ('miksi', 'S', 'pl ad')] --> [('miks', 'S', 'pl ad')]
#
# burgerit [('burgeri', 'S', 'sg p'), ('burger', 'S', 'sg p')] --> [('burger', 'S', 'sg p')]
#
# burgerit [('burgeri', 'S', 'sg p'), ('burger', 'S', 'sg p')] --> [('burger', 'S', 'sg p')]
#
# burgeri [('burger', 'S', 'sg g'), ('burgeri', 'S', 'sg g')] --> [('burger', 'S', 'sg g')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# rannavolle [('ranna_voll', 'S', 'pl p')] --> [('ranna_volle', 'S', 'sg g')]
#
# EM-i [('EM', 'Y', 'sg g')] --> [('EM', 'Y', 'adt')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# eurobeibid [('eurobeib', 'S', 'pl n'), ('eurobeibi', 'S', 'pl n'), ('eurobeip', 'S', 'pl n')] --> [('euro_beib', 'S', 'pl n')]
#
# eesmärgistatud [('ees_märgista=tud', 'A', ''), ('ees_märgista=tud', 'A', 'sg n'), ('ees_märgista=tud', 'A', 'pl n')] --> [('ees_märgista=tud', 'A', ''), ('ees_märgista=tud', 'A', 'sg n'), ('ees_märgista=tud', 'A', 'pl n'), ('ees_märgista', 'V', 'tud')]
#
# Laia [('laid', 'S', 'sg g')] --> [('lai', 'A', 'sg g')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# ekspansionistlikku [('ekspansion=istlik', 'A', 'sg p')] --> [('ekspansionistlik', 'A', 'sg p')]
#
# müslipakis [('müsli_pakis', 'S', 'sg n')] --> [('müsli_pakk', 'S', 'sg in')]
#
# galadineel [('galadi_neel', 'S', 'sg n')] --> [('gala_dinee', 'S', 'sg ad')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Laia [('laid', 'S', 'sg g')] --> [('lai', 'A', 'sg g')]
#
# opi [('opi', 'S', 'sg n')] --> [('opp', 'S', 'sg g')]
#
# opi [('opi', 'S', 'sg n')] --> [('opp', 'S', 'sg g')]
#
# karukuskused [('karukuskus', 'S', 'pl n')] --> [('karu_kuskus', 'S', 'pl n')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Päris [('päris', 'A', '')] --> [('päris', 'D', '')]
#
# eakatest [('eakas', 'A', 'pl el')] --> [('eakas', 'S', 'pl el')]
#
# vennikese [('vennike', 'S', 'sg g')] --> [('vennike', 'S', 'sg g'), ('vennikene', 'S', 'sg g')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Kolumn [('Kolumn', 'H', 'sg n')] --> [('kolumn', 'S', 'sg n')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# kommi [('komm', 'S', 'sg p')] --> [('komm', 'S', 'adt')]
#
# torti [('tort', 'S', 'sg p')] --> [('tort', 'S', 'adt')]
#
# retsil [('retsi', 'S', 'sg ad'), ('rets', 'S', 'sg ad')] --> [('rets', 'S', 'sg ad')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# tõsiusklikud [('tõsi_usklik', 'A', 'pl n')] --> [('tõsi_usk=lik', 'A', 'pl n')]
#
# ämbrist [('ämber', 'S', 'sg el')] --> [('ämbrine', 'A', 'sg p')]
#
# kokaiini [('kokaiin', 'S', 'sg g')] --> [('kokaiin', 'S', 'sg p')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# headmeelt [('head_meel', 'S', 'sg p')] --> [('hea_meel', 'S', 'sg p')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# klõnksuna [('klõnksu', 'S', 'sg es')] --> [('klõnks', 'S', 'sg es')]
#
# miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# Miks [('miks', 'D', '')] --> [('miks', 'D', ''), ('miks', 'S', 'sg n')]
#
# meioosis [('meio_osis', 'S', 'sg n')] --> [('meioos', 'S', 'sg in')]
#
# karüotüübis [('karüo_tüüp', 'S', 'sg in')] --> [('karüotüüp', 'S', 'sg in')]
#
# karüotüübid [('karüo_tüüp', 'S', 'pl n')] --> [('karüotüüp', 'S', 'pl n')]
#
# karüotüübiga [('karüo_tüüp', 'S', 'sg kom')] --> [('karüotüüp', 'S', 'sg kom')]
#
# karüotüüp [('karüo_tüüp', 'S', 'sg n')] --> [('karüotüüp', 'S', 'sg n')]
#
# koksartroosi [('koksart_roos', 'S', 'sg g')] --> [('koks_artroos', 'S', 'sg g')]
#
# osteoartroosi [('osteoart_roos', 'S', 'sg g')] --> [('osteo_artroos', 'S', 'sg g')]
#
# osteoartroosi [('osteoart_roos', 'S', 'sg g')] --> [('osteo_artroos', 'S', 'sg g')]
#
# reumatoid-artriidiga [('reuma_toi+d-artriit', 'S', 'sg kom')] --> [('reumatoid-artriit', 'S', 'sg kom')]
#
# osteoartroosiga [('osteoartroo_siga', 'A', 'sg n')] --> [('osteo_artroos', 'S', 'sg kom')]
#
# Osteoartroosi-haigetel [('Osteoartroosi-haige', 'S', 'pl ad')] --> [('osteo_artroosi-haige', 'S', 'pl ad')]
#
# artroosi [('art_roos', 'S', 'sg g')] --> [('artroos', 'S', 'sg g')]
#
# Osteoartroos [('Osteoartroos', 'H', 'sg n')] --> [('osteo_artroos', 'S', 'sg n')]
#
# Reumatoidartriidi [('Reumatoid_artriit', 'H', 'sg g')] --> [('reumatoid_artriit', 'S', 'sg g')]
#
# koksartroosi [('koksart_roos', 'S', 'sg g')] --> [('koks_artroos', 'S', 'sg g')]
#
# osteoartroosi- [('osteoart_roos', 'S', 'adt')] --> [('osteo_artroos', 'S', 'adt')]
#
# reumatoid-artriidihaigetel [('reuma_toi+d-artriidi_haige', 'S', 'pl ad')] --> [('reumatoid-artriidi_haige', 'S', 'pl ad')]
#
# kooskõlastumine [('kooskõlastu=mine', 'S', 'sg n')] --> [('koos_kõlastu=mine', 'S', 'sg n')]
#
# osteoartroosi [('osteoart_roos', 'S', 'sg g')] --> [('osteo_artroos', 'S', 'sg g')]
#
# Reumatoidartriidihaigetel [('Reumatoidartriidi_haige', 'H', 'pl ad')] --> [('reumatoid_artriidi_haige', 'S', 'pl ad')]
#
# osteoartroosihaigetele [('osteoartroosi_haige', 'S', 'pl all')] --> [('osteo_artroosi_haige', 'S', 'pl all')]
#
# reumatoidartriidihaigete [('reumatoidartriidi_haige', 'S', 'pl g')] --> [('reumatoid_artriidi_haige', 'S', 'pl g')]
#
# osteoartroosi [('osteoart_roos', 'S', 'sg g')] --> [('osteo_artroos', 'S', 'sg g')]
#
# isheemilise [('isheemi=line', 'A', 'sg g')] --> [('isheemiline', 'A', 'sg g')]
#
# sümptomaatika [('sümptoma_atika', 'G', '')] --> [('sümptomaatika', 'S', 'sg n')]
#
# sümptomaatika [('sümptoma_atika', 'G', '')] --> [('sümptomaatika', 'S', 'sg g')]
#
# distaalsema [('distaalsema', 'S', 'sg g')] --> [('distaalse=m', 'C', 'sg g')]
#
# motoorikahäirena [('moto_orika_häire', 'S', 'sg es')] --> [('motoorika_häire', 'S', 'sg es')]
#
# Isheemilist [('Isheemili', 'H', 'sg el')] --> [('isheemiline', 'A', 'sg p')]
#
# sümptomaatikat [('sümptomaatikas', 'S', 'sg p'), ('sümptomaatika', 'S', 'sg p')] --> [('sümptomaatika', 'S', 'sg p')]
#
# sümptomaatikaga [('sümptomaa_tikk', 'S', 'sg kom')] --> [('sümptomaatika', 'S', 'sg kom')]
#
# motoorika [('moto_orikas', 'S', 'sg g')] --> [('motoorika', 'S', 'sg g')]
#
# isheemiline [('isheemi=line', 'A', 'sg n')] --> [('isheemiline', 'A', 'sg n')]
#
# kortikonukleaarsetes [('kortikonukleaarne', 'A', 'pl in')] --> [('kortiko_nukleaarne', 'A', 'pl in')]
#
# isheemilise [('isheemi=line', 'A', 'sg g')] --> [('isheemiline', 'A', 'sg g')]
#
# isheemiliste [('isheemi=line', 'A', 'pl g')] --> [('isheemiline', 'A', 'pl g')]
#
# isheemilisele [('isheemi=line', 'A', 'sg all')] --> [('isheemiline', 'A', 'sg all')]
#
# hüdrotsefaalia [('hüdrotsefaalia', 'S', 'sg n')] --> [('hüdro_tsefaalia', 'S', 'sg n')]
# Isheemilise [('Isheemilinen', 'H', 'sg g')] --> [('isheemiline', 'A', 'sg g')]
#
# isheemilised [('isheemi=line', 'A', 'pl n')] --> [('isheemiline', 'A', 'pl n')]
#
# isheemilised [('isheemi=line', 'A', 'pl n')] --> [('isheemiline', 'A', 'pl n')]
#
# isheemilist [('isheemili', 'S', 'sg el')] --> [('isheemiline', 'A', 'sg p')]
#
# sümptomaatika [('sümptoma_atika', 'G', '')] --> [('sümptomaatika', 'S', 'sg n')]
#
# kolde-sümptomaatika [('kolde-sümptoma_atika', 'G', '')] --> [('kolde-sümptomaatika', 'S', 'sg g')]
#
# sümptomaatika [('sümptoma_atika', 'G', '')] --> [('sümptomaatika', 'S', 'sg n')]
#
# isheemilisest [('isheemi=line', 'A', 'sg el')] --> [('isheemiline', 'A', 'sg el')]
#
# blokaatoril [('blokaatori', 'S', 'sg ad'), ('blokaator', 'S', 'sg ad')] --> [('blokaator', 'S', 'sg ad')]
#
# koldesümptomaatika [('koldesümptoma_atika', 'G', '')] --> [('kolde_sümptomaatika', 'S', 'sg n')]
#
# Amüloidnaastude [('Amüloid_naast', 'H', 'pl g')] --> [('amüloid_naast', 'S', 'pl g')]
#
# Total differences:  109 / 44632

# %% [markdown]
# ---
