# %% [markdown]
# Handling large text collections with Elastic database
# =====================================================
#
# Estnltk has database module that simplifies working with large corpora.
# Check out wikipedia\_tutorial, tei\_tutorial for more information about
# getting started with larger text document collections.
#
# Estnltk database integrates with
# [Elastic](https://www.elastic.co/downloads/elasticsearch), which is a
# distributed RESTful schema-free JSON database, based on [Apache
# Lucene](https://lucene.apache.org/). See this
# [guide](https://www.elastic.co/guide/en/elasticsearch/reference/current/_installation.html)
# for installation.
#
# When the installation is complete you can run Elastic (from Elastic
# folder) with the command:

# %% [markdown]
#     ./bin/elasticsearch

# %% [markdown]
# If you have trouble running Elastic, please refer to [Elastic guide](https://www.elastic.co/guide/index.html).
#
#    * Do your research before asking us. Estnltk has only a very thin wrapper around the [Elastic Python API](https://elasticsearch-py.readthedocs.org/en/master/) .

# %% [markdown]
# Estnltk Elastic wrapper
# -----------------------
#
# To access estnltk elasticsearch wrappers:

# %%
# TODO: test if this whole tutorial works if you have elasticsearch

from estnltk.database.elastic import *

# %% [markdown]
# To create an index:

# %%
index = create_index('demo_index')
# Out:
# PUT http://localhost:9200/demo_index [status:N/A request:0.006s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8aac18>: Failed to establish a new connection: [Errno 111] Connection refused
# PUT http://localhost:9200/demo_index [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8aabe0>: Failed to establish a new connection: [Errno 111] Connection refused
# PUT http://localhost:9200/demo_index [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8aa0f0>: Failed to establish a new connection: [Errno 111] Connection refused
# PUT http://localhost:9200/demo_index [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8aa080>: Failed to establish a new connection: [Errno 111] Connection refused
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py in _new_conn(self)
#     134             conn = connection.create_connection(
# --> 135                 (self.host, self.port), self.timeout, **extra_kw)
#     136
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      89     if err is not None:
# ---> 90         raise err
#      91
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79                 sock.bind(source_address)
# ---> 80             sock.connect(sa)
#      81             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore)
#      77
# ---> 78             response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#      79             duration = time.time() - start
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     608             retries = retries.increment(method, url, error=e, _pool=self,
# --> 609                                         _stacktrace=sys.exc_info()[2])
#     610             retries.sleep()
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     221             # Disabled, indicate to re-raise the error.
# --> 222             raise six.reraise(type(error), error, _stacktrace)
#     223
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py in reraise(tp, value, tb)
#     309             raise value.with_traceback(tb)
# --> 310         raise value
#     311
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     352         # urllib3.request. It also calls makefile (recv) on the socket.
# --> 353         conn.request(method, url, **httplib_request_kw)
#     354
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py in connect(self)
#     159     def connect(self):
# --> 160         conn = self._new_conn()
#     161         self._prepare_conn(conn)
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py in _new_conn(self)
#     143             raise NewConnectionError(
# --> 144                 self, "Failed to establish a new connection: %s" % e)
#     145
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8aa080>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-7-929e8a07f638> in <module>()
# ----> 1 index = create_index('demo_index')
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/estnltk/database/elastic/__init__.py in create_index(index_name, **kwargs)
#      29     """
#      30     es = elasticsearch.Elasticsearch(**kwargs)
# ---> 31     es.indices.create(index=index_name, body=mapping)
#      32     return connect(index_name, **kwargs)
#      33
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#      67                 if p in kwargs:
#      68                     params[p] = kwargs.pop(p)
# ---> 69             return func(*args, params=params, **kwargs)
#      70         return _wrapped
#      71     return _wrapper
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/client/indices.py in create(self, index, body, params)
#     103             raise ValueError("Empty value passed for a required argument 'index'.")
#     104         _, data = self.transport.perform_request('PUT', _make_path(index),
# --> 105             params=params, body=body)
#     106         return data
#     107
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/transport.py in perform_request(self, method, url, params, body)
#     305
#     306             try:
# --> 307                 status, headers, data = connection.perform_request(method, url, params, body, ignore=ignore, timeout=timeout)
#     308
#     309             except TransportError as e:
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore)
#      87         except Exception as e:
#      88             self.log_request_fail(method, full_url, body, time.time() - start, exception=e)
# ---> 89             raise ConnectionError('N/A', str(e), e)
#      90
#      91         if not (200 <= response.status < 300) and response.status not in ignore:
#
# ConnectionError: ConnectionError(<urllib3.connection.HTTPConnection object at 0x7f238c8aa080>: Failed to establish a new connection: [Errno 111] Connection refused) caused by: NewConnectionError(<urllib3.connection.HTTPConnection object at 0x7f238c8aa080>: Failed to establish a new connection: [Errno 111] Connection refused)

# %% [markdown]
# Or to connect to an existing index:

# %%
index = connect('demo_index')
# Out:
# HEAD http://localhost:9200/demo_index [status:N/A request:0.003s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8db898>: Failed to establish a new connection: [Errno 111] Connection refused
# HEAD http://localhost:9200/demo_index [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8aaf98>: Failed to establish a new connection: [Errno 111] Connection refused
# HEAD http://localhost:9200/demo_index [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8aabe0>: Failed to establish a new connection: [Errno 111] Connection refused
# HEAD http://localhost:9200/demo_index [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8aac18>: Failed to establish a new connection: [Errno 111] Connection refused
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py in _new_conn(self)
#     134             conn = connection.create_connection(
# --> 135                 (self.host, self.port), self.timeout, **extra_kw)
#     136
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      89     if err is not None:
# ---> 90         raise err
#      91
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79                 sock.bind(source_address)
# ---> 80             sock.connect(sa)
#      81             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore)
#      77
# ---> 78             response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#      79             duration = time.time() - start
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     608             retries = retries.increment(method, url, error=e, _pool=self,
# --> 609                                         _stacktrace=sys.exc_info()[2])
#     610             retries.sleep()
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     221             # Disabled, indicate to re-raise the error.
# --> 222             raise six.reraise(type(error), error, _stacktrace)
#     223
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py in reraise(tp, value, tb)
#     309             raise value.with_traceback(tb)
# --> 310         raise value
#     311
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     352         # urllib3.request. It also calls makefile (recv) on the socket.
# --> 353         conn.request(method, url, **httplib_request_kw)
#     354
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py in connect(self)
#     159     def connect(self):
# --> 160         conn = self._new_conn()
#     161         self._prepare_conn(conn)
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py in _new_conn(self)
#     143             raise NewConnectionError(
# --> 144                 self, "Failed to establish a new connection: %s" % e)
#     145
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8aac18>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-8-c6d01fd57ff7> in <module>()
# ----> 1 index = connect('demo_index')
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/estnltk/database/elastic/__init__.py in connect(index_name, **kwargs)
#      50     """
#      51     client = elasticsearch.Elasticsearch(**kwargs)
# ---> 52     return Index(client, index_name)
#      53
#      54
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/estnltk/database/elastic/__init__.py in __init__(self, client, index_name)
#      64         self.index_name = index_name
#      65         self.client = client
# ---> 66         assert client.indices.exists(index=index_name), 'Index "{}" does not exist'.format(index_name)
#      67
#      68     def sentences(self, exclude_ids=None, query=None, return_estnltk_object=True, **kwargs):
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#      67                 if p in kwargs:
#      68                     params[p] = kwargs.pop(p)
# ---> 69             return func(*args, params=params, **kwargs)
#      70         return _wrapped
#      71     return _wrapper
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/client/indices.py in exists(self, index, params)
#     224         try:
#     225             self.transport.perform_request('HEAD', _make_path(index),
# --> 226                 params=params)
#     227         except NotFoundError:
#     228             return False
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/transport.py in perform_request(self, method, url, params, body)
#     305
#     306             try:
# --> 307                 status, headers, data = connection.perform_request(method, url, params, body, ignore=ignore, timeout=timeout)
#     308
#     309             except TransportError as e:
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore)
#      87         except Exception as e:
#      88             self.log_request_fail(method, full_url, body, time.time() - start, exception=e)
# ---> 89             raise ConnectionError('N/A', str(e), e)
#      90
#      91         if not (200 <= response.status < 300) and response.status not in ignore:
#
# ConnectionError: ConnectionError(<urllib3.connection.HTTPConnection object at 0x7f238c8aac18>: Failed to establish a new connection: [Errno 111] Connection refused) caused by: NewConnectionError(<urllib3.connection.HTTPConnection object at 0x7f238c8aac18>: Failed to establish a new connection: [Errno 111] Connection refused)

# %% [markdown]
# To specify non-default arguments to elasticsearch connection, you can
# either pass the parameters to either method or create and Index instance
# manually, passing the Elastic python API client object as the first
# parameter.
#
# These methods return an index object that has two important methods:
# save and sentences:

# %%
from estnltk import Text

t = Text('See on demolause. Sellele järgneb veel üks.')
index.save(t)

for sentence in index.sentences():
    print(t.lemmas) #note that the sentences generator returns estnltk Text objects by default.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4c051038e9ee> in <module>()
#       2
#       3 t = Text('See on demolause. Sellele järgneb veel üks.')
# ----> 4 index.save(t)
#       5
#       6 for sentence in index.sentences():
#
# NameError: name 'index' is not defined

# %% [markdown]
# To see the mapping and data structure in the elasticsearch index, refer
# to the mappings.py file.

# %% [markdown]
# Iterating over corpora
# ----------------------
#
# To iterate over the entire corpus use the Index.sentences generator. In
# the general case it is enough to do:

# %%
index = connect('demo_index')
for sentence in index.sentences():
    print(index)
# Out:
# HEAD http://localhost:9200/demo_index [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8db828>: Failed to establish a new connection: [Errno 111] Connection refused
# HEAD http://localhost:9200/demo_index [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8dbac8>: Failed to establish a new connection: [Errno 111] Connection refused
# HEAD http://localhost:9200/demo_index [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8dbb38>: Failed to establish a new connection: [Errno 111] Connection refused
# HEAD http://localhost:9200/demo_index [status:N/A request:0.001s]
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 135, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 90, in create_connection
#     raise err
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py", line 80, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py", line 78, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 609, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py", line 222, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 559, in urlopen
#     body=body, headers=headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py", line 353, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1106, in request
#     self._send_request(method, url, body, headers)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1151, in _send_request
#     self.endheaders(body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 1102, in endheaders
#     self._send_output(message_body)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 934, in _send_output
#     self.send(msg)
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py", line 877, in send
#     self.connect()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 160, in connect
#     conn = self._new_conn()
#   File "/home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py", line 144, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8dbcf8>: Failed to establish a new connection: [Errno 111] Connection refused
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py in _new_conn(self)
#     134             conn = connection.create_connection(
# --> 135                 (self.host, self.port), self.timeout, **extra_kw)
#     136
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      89     if err is not None:
# ---> 90         raise err
#      91
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79                 sock.bind(source_address)
# ---> 80             sock.connect(sa)
#      81             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore)
#      77
# ---> 78             response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#      79             duration = time.time() - start
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     608             retries = retries.increment(method, url, error=e, _pool=self,
# --> 609                                         _stacktrace=sys.exc_info()[2])
#     610             retries.sleep()
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     221             # Disabled, indicate to re-raise the error.
# --> 222             raise six.reraise(type(error), error, _stacktrace)
#     223
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/packages/six.py in reraise(tp, value, tb)
#     309             raise value.with_traceback(tb)
# --> 310         raise value
#     311
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     352         # urllib3.request. It also calls makefile (recv) on the socket.
# --> 353         conn.request(method, url, **httplib_request_kw)
#     354
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/http/client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py in connect(self)
#     159     def connect(self):
# --> 160         conn = self._new_conn()
#     161         self._prepare_conn(conn)
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/urllib3-1.12-py3.5.egg/urllib3/connection.py in _new_conn(self)
#     143             raise NewConnectionError(
# --> 144                 self, "Failed to establish a new connection: %s" % e)
#     145
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f238c8dbcf8>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-12-43cc02afc0d6> in <module>()
# ----> 1 index = connect('demo_index')
#       2 for sentence in index.sentences():
#       3     print(index)
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/estnltk/database/elastic/__init__.py in connect(index_name, **kwargs)
#      50     """
#      51     client = elasticsearch.Elasticsearch(**kwargs)
# ---> 52     return Index(client, index_name)
#      53
#      54
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/estnltk/database/elastic/__init__.py in __init__(self, client, index_name)
#      64         self.index_name = index_name
#      65         self.client = client
# ---> 66         assert client.indices.exists(index=index_name), 'Index "{}" does not exist'.format(index_name)
#      67
#      68     def sentences(self, exclude_ids=None, query=None, return_estnltk_object=True, **kwargs):
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#      67                 if p in kwargs:
#      68                     params[p] = kwargs.pop(p)
# ---> 69             return func(*args, params=params, **kwargs)
#      70         return _wrapped
#      71     return _wrapper
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/client/indices.py in exists(self, index, params)
#     224         try:
#     225             self.transport.perform_request('HEAD', _make_path(index),
# --> 226                 params=params)
#     227         except NotFoundError:
#     228             return False
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/transport.py in perform_request(self, method, url, params, body)
#     305
#     306             try:
# --> 307                 status, headers, data = connection.perform_request(method, url, params, body, ignore=ignore, timeout=timeout)
#     308
#     309             except TransportError as e:
#
# /home/dage/anaconda3/envs/working_estnltk/lib/python3.5/site-packages/elasticsearch-2.1.0-py3.5.egg/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore)
#      87         except Exception as e:
#      88             self.log_request_fail(method, full_url, body, time.time() - start, exception=e)
# ---> 89             raise ConnectionError('N/A', str(e), e)
#      90
#      91         if not (200 <= response.status < 300) and response.status not in ignore:
#
# ConnectionError: ConnectionError(<urllib3.connection.HTTPConnection object at 0x7f238c8dbcf8>: Failed to establish a new connection: [Errno 111] Connection refused) caused by: NewConnectionError(<urllib3.connection.HTTPConnection object at 0x7f238c8dbcf8>: Failed to establish a new connection: [Errno 111] Connection refused)

# %% [markdown]
# Iterating over query results
# ----------------------------
#
# To iterate over query results, pass the elasticsearch query to the
# sentences generator as the "query" parameter. The query should be a
# dictionary as expected by elasticsearch python API. It will be
# transformed into json before being transmitted.
#
# To simplify writing some queries, see the query\_helper module. It
# defines the Word class that maps well to estnltk morphological analysis
# results. The general workflow is:
#
# 1.  Define words to match with the Word class.
# 2.  Combine them with boolean operators "&" and "|"
# 3.  Wrap them in a Grammar object
# 4.  Get the query via the Grammar.query() method.
# 5.  Annotate the results with the Grammar.annotate() method that creates
#     a layer that marks the matching words.
#
# For example:

# %%
grammar = Grammar(Word(lemma='karu') & Word(lemma='jahimees') & Word(partofspeech='V'))
for sentence in index.sentences(query=grammar.query()):
    grammar.annotate(sentence, 'result')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-08f7dd4d881e> in <module>()
# ----> 1 grammar = Grammar(Word(lemma='karu') & Word(lemma='jahimees') & Word(partofspeech='V'))
#       2 for sentence in index.sentences(query=grammar.query()):
#       3     grammar.annotate(sentence, 'result')
#
# NameError: name 'Grammar' is not defined

# %% [markdown]
# The results can be visualised with the PrettyPrinter class or worked on
# using any other standard tools that work on estnltk layers.
