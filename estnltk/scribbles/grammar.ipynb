# %%
from estnltk import Text

from pandas import read_csv
from estnltk.taggers import RegexTagger

from estnltk.spans import Span, SpanList
from estnltk.layer import Layer
from estnltk.finite_grammar.layer_graph import print_nodes

# %%
with open("examples_.txt", "r") as fin:
    lines = fin.readlines()
lines = [line.strip() for line in lines]

# %%
lines
# Out:
# ['PSA 03042012 - 0,83ng/ml perearsti poolt .',
#  'PSA 2010. 3ng/ml, PSA 2012. 1,53ng/ml . - Bx va',
#  'PSA 20105,99 ja 26.01.2012 uuesti .',
#  'PSA 2011 oli 0 , 4 nG7ml .',
#  'PSA 201222,25ng/ml',
#  'PSA 2 aastajooksuldünaamikata , eriuuring',
#  ':psa 16,81! ! ! ! ! ,',
#  'Happe-aluse tasakaal 6.0 ( 5.0 .. 8.0 )',
#  'loli 25 mgx1 ja Monoprili 10 mg Kolesterool 2011a',
#  'Kolesterool 1k aastas .',
#  'Kõrgenenud kolesterool 2a ( mõõdetud ). Ei pea dieetist kinni',
#  'Kontr Verekol 08.12a Per-le juurde .',
#  's vas munajuha kasvaja op , günekol 3a tagssi .',
#  '08.11.2010 PSA 13.12.2011 7,2ng/ml PSADT on väike .',
#  'Rütmihäire tsüklipikkus 330 msek',
#  'Loote pikkus : \xa0 3 mm - vastab\xa0 5 nädalat 6 päeva.',
#  'Põhjendus: PALAT 10 # ALAT maksanäitaja',
#  'ärme vähk 2007 aastast cT3N0M0PSA 59ng/ml .',
#  'PSA 8,5( püsib aastaid selles väärtus',
#  'S , P-PSA 4.130( <4.100 µg/L )',
#  'PSA 5,2.',
#  'Kolesterool oli 7,9 mmol/l 0',
#  'kolesterool 6.4.',
#  'Kolesterool 5,2 mmol/l - esialgu dieet .',
#  'SK 3900 g , SP 51 cm .',
#  'Lapse kaal 5,4 kg/82 mg/0,82 ml i/m .',
#  'Kehakaal 80,2 kg , KMI 25,9',
#  'S , P-NT-proBNP 668 ( <125 pg/mL ) S , P-Albumiin 43 ( 35 .. 52 g/L ) S , P-ALAT 25 ( <33 U/L )',
#  'PSA 6,5 ng/ml, eesnäärme maht67cm3',
#  'rjeldus : Siinusbradükardia Fr 587min']

# %%
vocabulary = 'regexes.csv'

# %%
vocabulary = read_csv(vocabulary, na_filter=False, index_col=False)

# %%
test_regex_tagger = RegexTagger(vocabulary=vocabulary[:27],
                                attributes=['regex_type', 'value', 'grammar_symbol'],
                                conflict_resolving_strategy='MAX',
                                overlapped=False,
                                layer_name='type')

# %%
spaces = vocabulary[27:]

# %%
spaces
# Out:
#          _regex_pattern_  _group_  _priority_ regex_type  value grammar_symbol
# 27             [-=.>< ]*        0           1      space  space          SPACE
# 28           \.?\s*-?\s*        0           1      space  space          SPACE
# 29  [-=.>< ]*(on|oli)\s*        0           1      space  space          SPACE
# 30         \s*-?:?\s*\<?        0           1      space  space          SPACE
# 31                   \s*        0           1      space  space          SPACE

# %%
space_tagger = RegexTagger(layer_name='space',
                           vocabulary = spaces,
                           attributes = [],
                           conflict_resolving_strategy='MAX',
                           overlapped=True
                         )

# %%
from estnltk.taggers import GapTagger

gaps_tagger = GapTagger(layer_name='random_text_layer',
                        input_layers=['space', 'type'],
                        attributes=['no_idea', 'grammar_symbol'],
                        decorator=lambda t: {'no_idea':'text', 'grammar_symbol':'RANDOM_TEXT'})

# %%
from estnltk.taggers import MergeTagger
merge_tagger = MergeTagger(layer_name='grammar_tags',
                           input_layers=['type', 'random_text_layer'],
                           attributes=('grammar_symbol', 'value'))

# %%
lines
# Out:
# ['PSA 03042012 - 0,83ng/ml perearsti poolt .',
#  'PSA 2010. 3ng/ml, PSA 2012. 1,53ng/ml . - Bx va',
#  'PSA 20105,99 ja 26.01.2012 uuesti .',
#  'PSA 2011 oli 0 , 4 nG7ml .',
#  'PSA 201222,25ng/ml',
#  'PSA 2 aastajooksuldünaamikata , eriuuring',
#  ':psa 16,81! ! ! ! ! ,',
#  'Happe-aluse tasakaal 6.0 ( 5.0 .. 8.0 )',
#  'loli 25 mgx1 ja Monoprili 10 mg Kolesterool 2011a',
#  'Kolesterool 1k aastas .',
#  'Kõrgenenud kolesterool 2a ( mõõdetud ). Ei pea dieetist kinni',
#  'Kontr Verekol 08.12a Per-le juurde .',
#  's vas munajuha kasvaja op , günekol 3a tagssi .',
#  '08.11.2010 PSA 13.12.2011 7,2ng/ml PSADT on väike .',
#  'Rütmihäire tsüklipikkus 330 msek',
#  'Loote pikkus : \xa0 3 mm - vastab\xa0 5 nädalat 6 päeva.',
#  'Põhjendus: PALAT 10 # ALAT maksanäitaja',
#  'ärme vähk 2007 aastast cT3N0M0PSA 59ng/ml .',
#  'PSA 8,5( püsib aastaid selles väärtus',
#  'S , P-PSA 4.130( <4.100 µg/L )',
#  'PSA 5,2.',
#  'Kolesterool oli 7,9 mmol/l 0',
#  'kolesterool 6.4.',
#  'Kolesterool 5,2 mmol/l - esialgu dieet .',
#  'SK 3900 g , SP 51 cm .',
#  'Lapse kaal 5,4 kg/82 mg/0,82 ml i/m .',
#  'Kehakaal 80,2 kg , KMI 25,9',
#  'S , P-NT-proBNP 668 ( <125 pg/mL ) S , P-Albumiin 43 ( 35 .. 52 g/L ) S , P-ALAT 25 ( <33 U/L )',
#  'PSA 6,5 ng/ml, eesnäärme maht67cm3',
#  'rjeldus : Siinusbradükardia Fr 587min']

# %%
j = Text(lines[0])

# %%
test_regex_tagger.tag(j)

# %%
j.type
# Out:
# SL[Span(PSA, {'grammar_symbol': 'MO', 'regex_type': 'measurement_object', 'value': 'psa'}),
# Span(03042012, {'grammar_symbol': 'DATE', 'regex_type': 'date4', 'value': 'date'}),
# Span(0,83, {'grammar_symbol': 'NUMBER', 'regex_type': 'number1', 'value': 'whatever'}),
# Span(ng/ml, {'grammar_symbol': 'UNIT', 'regex_type': 'unit', 'value': 'psa_unit'})]

# %%
tagged_lines = []
lines_to_texts = {}
for line in lines:
    print(line)
    text = Text(line)
    test_regex_tagger.tag(text)
    space_tagger.tag(text)
    gaps_tagger.tag(text)
    merge_tagger.tag(text)
    tagged_lines.append(text)
    lines_to_texts[line] = text
# Out:
# PSA 03042012 - 0,83ng/ml perearsti poolt .
# PSA 2010. 3ng/ml, PSA 2012. 1,53ng/ml . - Bx va
# PSA 20105,99 ja 26.01.2012 uuesti .
# PSA 2011 oli 0 , 4 nG7ml .
# PSA 201222,25ng/ml
# PSA 2 aastajooksuldünaamikata , eriuuring
# :psa 16,81! ! ! ! ! ,
# Happe-aluse tasakaal 6.0 ( 5.0 .. 8.0 )
# loli 25 mgx1 ja Monoprili 10 mg Kolesterool 2011a
# Kolesterool 1k aastas .
# Kõrgenenud kolesterool 2a ( mõõdetud ). Ei pea dieetist kinni
# Kontr Verekol 08.12a Per-le juurde .
# s vas munajuha kasvaja op , günekol 3a tagssi .
# 08.11.2010 PSA 13.12.2011 7,2ng/ml PSADT on väike .
# Rütmihäire tsüklipikkus 330 msek
# Loote pikkus :   3 mm - vastab  5 nädalat 6 päeva.
# Põhjendus: PALAT 10 # ALAT maksanäitaja
# ärme vähk 2007 aastast cT3N0M0PSA 59ng/ml .
# PSA 8,5( püsib aastaid selles väärtus
# S , P-PSA 4.130( <4.100 µg/L )
# PSA 5,2.
# Kolesterool oli 7,9 mmol/l 0
# kolesterool 6.4.
# Kolesterool 5,2 mmol/l - esialgu dieet .
# SK 3900 g , SP 51 cm .
# Lapse kaal 5,4 kg/82 mg/0,82 ml i/m .
# Kehakaal 80,2 kg , KMI 25,9
# S , P-NT-proBNP 668 ( <125 pg/mL ) S , P-Albumiin 43 ( 35 .. 52 g/L ) S , P-ALAT 25 ( <33 U/L )
# PSA 6,5 ng/ml, eesnäärme maht67cm3
# rjeldus : Siinusbradükardia Fr 587min

# %%
for line in tagged_lines:
    print(line.text)
    #print(line.regex_type)
    #print(line.random_text_layer)
    print(line.grammar_tags)
    print('-----------------------------------------------------')
# Out:
# PSA 03042012 - 0,83ng/ml perearsti poolt .
# SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(03042012, {'grammar_symbol': 'DATE', 'value': 'date'}),
# Span(0,83, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'}),
# Span(perearsti, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(poolt, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# PSA 2010. 3ng/ml, PSA 2012. 1,53ng/ml . - Bx va
# SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(2010, {'grammar_symbol': 'DATE', 'value': 'partial_date'}),
# Span(3, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span( PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(2012, {'grammar_symbol': 'DATE', 'value': 'partial_date'}),
# Span(1,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(53, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'}),
# Span(B, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(x, {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(va, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# PSA 20105,99 ja 26.01.2012 uuesti .
# SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(20105, {'grammar_symbol': 'DATE', 'value': 'date'}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(99, {'grammar_symbol': 'NUMBER', 'value': 'some_int'}),
# Span(j, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(26.01, {'grammar_symbol': 'DATE', 'value': 'date'}),
# Span(2012, {'grammar_symbol': 'DATE', 'value': 'partial_date'}),
# Span(uuesti, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# PSA 2011 oli 0 , 4 nG7ml .
# SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(2011, {'grammar_symbol': 'DATE', 'value': 'partial_date'}),
# Span(0 , 4, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(n, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(G, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'}),
# Span(7, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(l, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# PSA 201222,25ng/ml
# SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(20122, {'grammar_symbol': 'DATE', 'value': 'date'}),
# Span(2,25, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'})]
# -----------------------------------------------------
# PSA 2 aastajooksuldünaamikata , eriuuring
# SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(2, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(aasta, {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(jooksuldünaa, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(ikat, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(eriuurin, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(g, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'})]
# -----------------------------------------------------
# :psa 16,81! ! ! ! ! ,
# SL[Span(ps, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(16,81, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(!, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(!, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(!, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(!, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(!, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# Happe-aluse tasakaal 6.0 ( 5.0 .. 8.0 )
# SL[Span(Happe, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(aluse, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(tasakaal , {'grammar_symbol': 'RUBBISH', 'value': 'kaal_trash'}),
# Span(6.0, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span((, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(5.0, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(8.0, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(), {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# loli 25 mgx1 ja Monoprili 10 mg Kolesterool 2011a
# SL[Span(l, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(25, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(mg, {'grammar_symbol': 'UNIT', 'value': 'not_pikkus_unit'}),
# Span(x, {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(1, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(j, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(M, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(oprili, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(10, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(mg, {'grammar_symbol': 'UNIT', 'value': 'not_pikkus_unit'}),
# Span(Kolesterool, {'grammar_symbol': 'MO', 'value': 'kolesterool'}),
# Span(2011a, {'grammar_symbol': 'DATE', 'value': 'partial_date'})]
# -----------------------------------------------------
# Kolesterool 1k aastas .
# SL[Span(Kolesterool, {'grammar_symbol': 'MO', 'value': 'kolesterool'}),
# Span(1, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(k, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(aasta, {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(s, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# Kõrgenenud kolesterool 2a ( mõõdetud ). Ei pea dieetist kinni
# SL[Span(Kõr, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(g, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'}),
# Span(enenud, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(kolesterool, {'grammar_symbol': 'MO', 'value': 'kolesterool'}),
# Span(2, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span((, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(õõdetud, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(), {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(Ei, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(pe, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(dieetist, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(kinni, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# Kontr Verekol 08.12a Per-le juurde .
# SL[Span(K, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(tr, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(Vere, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(kol, {'grammar_symbol': 'MO', 'value': 'kolesterool'}),
# Span(08.12, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(Per, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(le, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(juurde, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# s vas munajuha kasvaja op , günekol 3a tagssi .
# SL[Span(s, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(vas, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(unajuh, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(kasv, {'grammar_symbol': 'MO', 'value': 'pikkus'}),
# Span(aj, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(op, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(g, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'}),
# Span(üne, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(kol, {'grammar_symbol': 'MO', 'value': 'kolesterool'}),
# Span(3, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(ta, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(g, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'}),
# Span(ssi, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# 08.11.2010 PSA 13.12.2011 7,2ng/ml PSADT on väike .
# SL[Span(08.11.2010, {'grammar_symbol': 'DATE', 'value': 'date'}),
# Span( PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(13.12, {'grammar_symbol': 'DATE', 'value': 'date'}),
# Span(2011, {'grammar_symbol': 'DATE', 'value': 'partial_date'}),
# Span(7,2, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'}),
# Span( PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(DT, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(väike, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# Rütmihäire tsüklipikkus 330 msek
# SL[Span(Rüt, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(ihäire, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(ts, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(ük, {'grammar_symbol': 'MO', 'value': 'kolesterool'}),
# Span(li, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(pikkus, {'grammar_symbol': 'MO', 'value': 'pikkus'}),
# Span(330, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(msek, {'grammar_symbol': 'UNIT', 'value': 'time_unit'})]
# -----------------------------------------------------
# Loote pikkus :   3 mm - vastab  5 nädalat 6 päeva.
# SL[Span(Loote, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(pikkus, {'grammar_symbol': 'MO', 'value': 'pikkus'}),
# Span(3, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(mm, {'grammar_symbol': 'UNIT', 'value': 'not_pikkus_unit'}),
# Span(vastab, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(5, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(nädal, {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(at, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(6, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(päev, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(a., {'grammar_symbol': 'UNIT', 'value': 'time_unit'})]
# -----------------------------------------------------
# Põhjendus: PALAT 10 # ALAT maksanäitaja
# SL[Span(Põhjendus, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(PALAT, {'grammar_symbol': 'RUBBISH', 'value': 'alat_trash'}),
# Span(10, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(#, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(ALAT, {'grammar_symbol': 'MO', 'value': 'alat'}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(aksanäitaja, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# ärme vähk 2007 aastast cT3N0M0PSA 59ng/ml .
# SL[Span(är, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(e, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(vähk, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(2007 a, {'grammar_symbol': 'DATE', 'value': 'partial_date'}),
# Span(astast, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(cT, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(3, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(N, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(0, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(M, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(0, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(59, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'})]
# -----------------------------------------------------
# PSA 8,5( püsib aastaid selles väärtus
# SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(8,5, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span((, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(püsib, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(aasta, {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(id, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(selles, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(väärtus, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# S , P-PSA 4.130( <4.100 µg/L )
# SL[Span(S , P-PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(4.130, {'grammar_symbol': 'DATE', 'value': 'date'}),
# Span((, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(4.100, {'grammar_symbol': 'DATE', 'value': 'date'}),
# Span(µg/L, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'}),
# Span(), {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# PSA 5,2.
# SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(5,2, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})]
# -----------------------------------------------------
# Kolesterool oli 7,9 mmol/l 0
# SL[Span(Kolesterool, {'grammar_symbol': 'MO', 'value': 'kolesterool'}),
# Span(7,9, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(mmol/l, {'grammar_symbol': 'UNIT', 'value': 'not_pikkus_unit'}),
# Span(0, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})]
# -----------------------------------------------------
# kolesterool 6.4.
# SL[Span(kolesterool, {'grammar_symbol': 'MO', 'value': 'kolesterool'}),
# Span(6.4, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})]
# -----------------------------------------------------
# Kolesterool 5,2 mmol/l - esialgu dieet .
# SL[Span(Kolesterool, {'grammar_symbol': 'MO', 'value': 'kolesterool'}),
# Span(5,2, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(mmol/l, {'grammar_symbol': 'UNIT', 'value': 'not_pikkus_unit'}),
# Span(esial, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(g, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'}),
# Span(u, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(dieet, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# SK 3900 g , SP 51 cm .
# SL[Span(SK, {'grammar_symbol': 'MO', 'value': 'kaal'}),
# Span(3900, {'grammar_symbol': 'DATE', 'value': 'date'}),
# Span(g, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span( SP, {'grammar_symbol': 'MO', 'value': 'pikkus'}),
# Span(51, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(cm, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'})]
# -----------------------------------------------------
# Lapse kaal 5,4 kg/82 mg/0,82 ml i/m .
# SL[Span(Lapse, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(kaal, {'grammar_symbol': 'MO', 'value': 'kaal'}),
# Span(5,4, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(kg, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'}),
# Span(/, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(82, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(mg, {'grammar_symbol': 'UNIT', 'value': 'not_pikkus_unit'}),
# Span(/, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(0,82, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(l, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(i/, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'})]
# -----------------------------------------------------
# Kehakaal 80,2 kg , KMI 25,9
# SL[Span(Kehakaal, {'grammar_symbol': 'MO', 'value': 'kaal'}),
# Span(80,2, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(kg, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(KMI, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(25,9, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})]
# -----------------------------------------------------
# S , P-NT-proBNP 668 ( <125 pg/mL ) S , P-Albumiin 43 ( 35 .. 52 g/L ) S , P-ALAT 25 ( <33 U/L )
# SL[Span(S, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(P, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(NT, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(proBNP, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(668, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span((, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(125, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(p, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(g, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'}),
# Span(/, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(L, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(), {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(S, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(P, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(Albu, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(iin, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(43, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span((, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(35, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(52, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(g, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'}),
# Span(/L, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(), {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(S, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(P, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(ALAT, {'grammar_symbol': 'MO', 'value': 'alat'}),
# Span(25, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span((, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(33, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(U/L, {'grammar_symbol': 'UNIT', 'value': 'alat_unit'}),
# Span(), {'grammar_symbol': 'RANDOM_TEXT', 'value': None})]
# -----------------------------------------------------
# PSA 6,5 ng/ml, eesnäärme maht67cm3
# SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'}),
# Span(6,5, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'}),
# Span(,, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(eesnäär, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(e, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(m, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(aht, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(67, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(cm, {'grammar_symbol': 'UNIT', 'value': 'pikkus_unit'}),
# Span(3, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})]
# -----------------------------------------------------
# rjeldus : Siinusbradükardia Fr 587min
# SL[Span(rjeldus, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(Siinusbrad, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(ük, {'grammar_symbol': 'MO', 'value': 'kolesterool'}),
# Span(ardi, {'grammar_symbol': 'RANDOM_TEXT', 'value': None}),
# Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'}),
# Span(Fr, {'grammar_symbol': 'MO', 'value': 'pulss'}),
# Span(587, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(min, {'grammar_symbol': 'UNIT', 'value': 'time_unit'})]
# -----------------------------------------------------

# %% [markdown]
# # GRAMMAR
#
# (MO = measurement_object)<br>
# QNUMBER = NUMBER_UNIT<br>
# QNUMBER = NUMBER<br>
# MEASUREMENT = MO_DATE_QNUMBER<br>
# MEASUREMENT = MO_QNUMBER<br>
# TRASH = RUBBISH_NUMBER<br>
# TRASH = RUBBISH_MO_NUMBER<br>
# TRASH = RUBBISH<br>
# TRASH = MO_DATE

# %%
from estnltk.finite_grammar.grammar import Rule, Grammar


def qnumber_decorator(nodes):
    number, unit = nodes
    unit_type = unit.value
    return {'value': float(number.text.replace(',', '.').replace(' ', '')),
            'unit': unit.text,
            'unit_type': unit_type,
            'mtype': 'continuous'}

def measurement_decorator(nodes):
    return {'date': nodes[1].value}

def measurement_validator(nodes):
    #if len(nodes) == 2:
    mo, qnumber = nodes[0], nodes[1]
    #units = {'psa':'psa_unit',
    #         'kolesterool':'chol_unit',
    ##         'pulss':'pulss_unit',
    #         'pikkus':'pikkus_unit',
    #         'kaal':'kaal_unit',
    #         'alat':'alat_unit'
    #        }
    #elif len(nodes) == 3:
    #    mo, qnumber = nodes[0], nodes[2]
    #    units = {'psa':'xx_unit',
                 #'kolesterool':'chol_unit',
                 #'pulss':'pulss_unit',
                 #'pikkus':'pikkus_unit',
                 #'kaal':'kaal_unit',
                #'alat':'alat_unit'
                #}
    if hasattr(qnumber, 'unit_type'):
        return True
        #return units[mo.value] == qnumber.unit_type
    return False

rules = []
rules.append(Rule('QNUMBER', 'NUMBER UNIT',
                  priority=0,
                  decorator=qnumber_decorator))
rules.append(Rule('QNUMBER', 'NUMBER',
                  priority=1))
rules.append(Rule('MEASUREMENT', 'MO DATE QNUMBER',
                  priority=0,
                  decorator=measurement_decorator,
                  validator=measurement_validator))
rules.append(Rule('MEASUREMENT', 'MO QNUMBER',
                  validator=measurement_validator))
rules.append(Rule('TRASH', 'RUBBISH NUMBER'))
rules.append(Rule('TRASH', 'RUBBISH MO NUMBER'))
rules.append(Rule('TRASH', 'RUBBISH'))
rules.append(Rule('TRASH', 'MO DATE'))

grammar = Grammar(start_symbols=['MEASUREMENT', 'TRASH'], rules=rules, max_depth=4,
                 legal_attributes=['value', 'unit', 'unit_type', 'mtype'])
grammar
# Out:
# Grammar:
# 	start: MEASUREMENT, TRASH
# 	terminals: DATE, MO, NUMBER, RUBBISH, UNIT
# 	nonterminals: MEASUREMENT, QNUMBER, TRASH
# 	legal attributes: frozenset({'unit', 'unit_type', 'value', 'mtype'})
# 	max_depth: 4
# Rules:
# 	QNUMBER -> NUMBER UNIT	: 0, val: default_validator, dec: qnumber_decorator
# 	QNUMBER -> NUMBER	: 1, val: default_validator, dec: default_decorator
# 	MEASUREMENT -> MO DATE QNUMBER	: 0, val: measurement_validator, dec: measurement_decorator
# 	MEASUREMENT -> MO QNUMBER	: 0, val: measurement_validator, dec: default_decorator
# 	TRASH -> RUBBISH NUMBER	: 0, val: default_validator, dec: default_decorator
# 	TRASH -> RUBBISH MO NUMBER	: 0, val: default_validator, dec: default_decorator
# 	TRASH -> RUBBISH	: 0, val: default_validator, dec: default_decorator
# 	TRASH -> MO DATE	: 0, val: default_validator, dec: default_decorator

# %%
from estnltk.taggers.grammar_parsing.grammar_parsing_tagger import GrammarParsingTagger
parsing_tagger = GrammarParsingTagger(layer_name='parse',
                                      attributes=['name', 'value','unit_type', 'regex_type'],
                                      layer_of_tokens='grammar_tags',
                                      grammar=grammar,
                                      output_nodes={'DATE','UNIT','QNUMBER', 'MEASUREMENT', 'MO', 'NUMBER'})

# %%
parsing_tagger
# Out:
# GrammarParsingTagger(resolve_conflicts=True)

# %%
from estnltk.finite_grammar import phrase_list_generator

for phrase in phrase_list_generator(grammar, max_depth=5):
    print(phrase)
# Out:
# ['MO', 'DATE', 'NUMBER', 'UNIT', 'RUBBISH', 'NUMBER']
# ['MO', 'DATE', 'NUMBER', 'UNIT', 'RUBBISH', 'MO', 'NUMBER']
# ['MO', 'DATE', 'NUMBER', 'UNIT', 'RUBBISH']
# ['MO', 'DATE', 'NUMBER', 'UNIT', 'MO', 'DATE']
# ['MO', 'DATE', 'NUMBER', 'RUBBISH', 'NUMBER']
# ['MO', 'DATE', 'NUMBER', 'RUBBISH', 'MO', 'NUMBER']
# ['MO', 'DATE', 'NUMBER', 'RUBBISH']
# ['MO', 'DATE', 'NUMBER', 'MO', 'DATE']
# ['MO', 'NUMBER', 'UNIT', 'RUBBISH', 'NUMBER']
# ['MO', 'NUMBER', 'UNIT', 'RUBBISH', 'MO', 'NUMBER']
# ['MO', 'NUMBER', 'UNIT', 'RUBBISH']
# ['MO', 'NUMBER', 'UNIT', 'MO', 'DATE']
# ['MO', 'NUMBER', 'RUBBISH', 'NUMBER']
# ['MO', 'NUMBER', 'RUBBISH', 'MO', 'NUMBER']
# ['MO', 'NUMBER', 'RUBBISH']
# ['MO', 'NUMBER', 'MO', 'DATE']

# %%
from estnltk.finite_grammar.layer_graph import layer_to_graph, plot_graph
from estnltk.finite_grammar.grammar import parse_graph
print(text.text)
graph = layer_to_graph(text['grammar_tags'])
graph = parse_graph(graph, grammar, 4)
plot_graph(graph)
# Out:
# rjeldus : Siinusbradükardia Fr 587min

# %%
t = 'PSA 03042012 - 0,83ng/ml perearsti poolt .'

# %%
t2 = 'PSA 2010. 3ng/ml, PSA 2012. 1,53ng/ml . - Bx va'

# %%
t3 = 'Kehakaal 80,2 kg , KMI 25,9'

# %%
text = Text(t)
test_regex_tagger.tag(text)
space_tagger.tag(text)
gaps_tagger.tag(text)
merge_tagger.tag(text)
print(text.text)
graph = layer_to_graph(text['grammar_tags'])
graph = parse_graph(graph, grammar, 4)
print_nodes(graph, text, 
        names={'DATE','UNIT','QNUMBER', 'MEASUREMENT', 'MO', 'NUMBER'},
        attributes=['name', 'text', 'value', 'unit_type', 'regex_type'])
# Out:
# PSA 03042012 - 0,83ng/ml perearsti poolt .
# name                text                value               unit_type           regex_type
#
# DATE                03042012            date
# MO                  PSA                 psa
# NUMBER              0,83                whatever
# QNUMBER             0,83
# QNUMBER             0,83ng/ml           0.83                psa_unit
# UNIT                ng/ml               psa_unit

# %%
parsing_tagger.tag(text)
text.parse
# Out:
# SL[SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'})],
# SL[Span(03042012, {'grammar_symbol': 'DATE', 'value': 'date'})],
# SL[Span(0,83, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})],
# SL[Span(0,83, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})],
# SL[Span(0,83, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'})],
# SL[Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'})]]

# %%
text = Text(t2)
test_regex_tagger.tag(text)
space_tagger.tag(text)
gaps_tagger.tag(text)
merge_tagger.tag(text)
print(text.text)
graph = layer_to_graph(text['grammar_tags'])
graph = parse_graph(graph, grammar, 4)
print_nodes(graph, text, 
        names={'DATE','UNIT','QNUMBER', 'MEASUREMENT', 'MO', 'NUMBER'},
        attributes=['name', 'text', 'value','unit_type', 'regex_type'])
# Out:
# PSA 2010. 3ng/ml, PSA 2012. 1,53ng/ml . - Bx va
# name                text                value               unit_type           regex_type
#
# DATE                2010                partial_date
# DATE                2012                partial_date
# MO                   PSA                psa
# MO                  PSA                 psa
# NUMBER              53                  whatever
# QNUMBER             53
# QNUMBER             53ng/ml             53.0                psa_unit
# UNIT                ng/ml               psa_unit
# UNIT                ng/ml               psa_unit
# UNIT                x                   time_unit

# %%
parsing_tagger.tag(text)
text.parse
# Out:
# SL[SL[Span(PSA, {'grammar_symbol': 'MO', 'value': 'psa'})],
# SL[Span(2010, {'grammar_symbol': 'DATE', 'value': 'partial_date'})],
# SL[Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'})],
# SL[Span( PSA, {'grammar_symbol': 'MO', 'value': 'psa'})],
# SL[Span(2012, {'grammar_symbol': 'DATE', 'value': 'partial_date'})],
# SL[Span(53, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})],
# SL[Span(53, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})],
# SL[Span(53, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'})],
# SL[Span(ng/ml, {'grammar_symbol': 'UNIT', 'value': 'psa_unit'})],
# SL[Span(x, {'grammar_symbol': 'UNIT', 'value': 'time_unit'})]]

# %%
text = Text(t3)
test_regex_tagger.tag(text)
space_tagger.tag(text)
gaps_tagger.tag(text)
merge_tagger.tag(text)
print(text.text)
graph = layer_to_graph(text['grammar_tags'])
graph = parse_graph(graph, grammar, 4)
print_nodes(graph, text, 
        names={'DATE','UNIT','QNUMBER', 'MEASUREMENT', 'MO', 'NUMBER'},
        attributes=['name', 'text', 'value','unit_type', 'regex_type'])
# Out:
# Kehakaal 80,2 kg , KMI 25,9
# name                text                value               unit_type           regex_type
#
# MEASUREMENT         Kehakaal 80,2 kg
# MO                  Kehakaal            kaal
# NUMBER              25,9                whatever
# NUMBER              80,2                whatever
# QNUMBER             25,9
# QNUMBER             80,2
# QNUMBER             80,2 kg             80.2                kaal_unit
# UNIT                kg                  kaal_unit

# %%
parsing_tagger.tag(text)
text.parse
# Out:
# SL[SL[Span(Kehakaal, {'grammar_symbol': 'MO', 'value': 'kaal'})],
# SL[Span(Kehakaal, {'grammar_symbol': 'MO', 'value': 'kaal'}),
# Span(80,2, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(kg, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'})],
# SL[Span(80,2, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})],
# SL[Span(80,2, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})],
# SL[Span(80,2, {'grammar_symbol': 'NUMBER', 'value': 'whatever'}),
# Span(kg, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'})],
# SL[Span(kg, {'grammar_symbol': 'UNIT', 'value': 'kaal_unit'})],
# SL[Span(25,9, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})],
# SL[Span(25,9, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})]]

# %%
for line in tagged_lines:
    text = line
    print(text.text)
    graph = layer_to_graph(text['grammar_tags'])
    graph = parse_graph(graph, grammar, 4)
    print_nodes(graph, text, 
            names={'DATE','UNIT','QNUMBER', 'MEASUREMENT', 'MO', 'NUMBER'},
            attributes=['name', 'text', 'value','type', 'start', 'unit_type'])
    print('------------------------')
# Out:
# PSA 03042012 - 0,83ng/ml perearsti poolt .
# name                text                value               type                start               unit_type
#
# DATE                03042012            date                                    4
# MO                  PSA                 psa                                     0
# NUMBER              0,83                whatever                                15
# QNUMBER             0,83                                                        15
# QNUMBER             0,83ng/ml           0.83                                    15                  psa_unit
# UNIT                ng/ml               psa_unit                                19
# ------------------------
# PSA 2010. 3ng/ml, PSA 2012. 1,53ng/ml . - Bx va
# name                text                value               type                start               unit_type
#
# DATE                2010                partial_date                            4
# DATE                2012                partial_date                            22
# MO                   PSA                psa                                     17
# MO                  PSA                 psa                                     0
# NUMBER              53                  whatever                                30
# QNUMBER             53                                                          30
# QNUMBER             53ng/ml             53.0                                    30                  psa_unit
# UNIT                ng/ml               psa_unit                                11
# UNIT                ng/ml               psa_unit                                32
# UNIT                x                   time_unit                               43
# ------------------------
# PSA 20105,99 ja 26.01.2012 uuesti .
# name                text                value               type                start               unit_type
#
# DATE                20105               date                                    4
# DATE                2012                partial_date                            22
# DATE                26.01               date                                    16
# MO                  PSA                 psa                                     0
# NUMBER              99                  some_int                                10
# QNUMBER             99                                                          10
# UNIT                a                   time_unit                               14
# ------------------------
# PSA 2011 oli 0 , 4 nG7ml .
# name                text                value               type                start               unit_type
#
# DATE                2011                partial_date                            4
# MO                  PSA                 psa                                     0
# NUMBER              0 , 4               whatever                                13
# NUMBER              7                   whatever                                21
# QNUMBER             0 , 4                                                       13
# QNUMBER             7                                                           21
# QNUMBER             7m                  7.0                                     21                  pikkus_unit
# UNIT                G                   kaal_unit                               20
# UNIT                m                   pikkus_unit                             22
# ------------------------
# PSA 201222,25ng/ml
# name                text                value               type                start               unit_type
#
# DATE                20122               date                                    4
# MO                  PSA                 psa                                     0
# UNIT                ng/ml               psa_unit                                13
# ------------------------
# PSA 2 aastajooksuldünaamikata , eriuuring
# name                text                value               type                start               unit_type
#
# MEASUREMENT         PSA 2 aasta                                                 0
# MO                  PSA                 psa                                     0
# NUMBER              2                   whatever                                4
# QNUMBER             2                                                           4
# QNUMBER             2 aasta             2.0                                     4                   time_unit
# UNIT                a                   time_unit                               28
# UNIT                aasta               time_unit                               6
# UNIT                g                   kaal_unit                               40
# UNIT                m                   pikkus_unit                             23
# ------------------------
# :psa 16,81! ! ! ! ! ,
# name                text                value               type                start               unit_type
#
# NUMBER              16,81               whatever                                5
# QNUMBER             16,81                                                       5
# UNIT                a                   time_unit                               3
# ------------------------
# Happe-aluse tasakaal 6.0 ( 5.0 .. 8.0 )
# name                text                value               type                start               unit_type
#
# NUMBER              5.0                 whatever                                27
# NUMBER              6.0                 whatever                                21
# NUMBER              8.0                 whatever                                34
# QNUMBER             5.0                                                         27
# QNUMBER             6.0                                                         21
# QNUMBER             8.0                                                         34
# ------------------------
# loli 25 mgx1 ja Monoprili 10 mg Kolesterool 2011a
# name                text                value               type                start               unit_type
#
# DATE                2011a               partial_date                            44
# MO                  Kolesterool         kolesterool                             32
# NUMBER              1                   whatever                                11
# NUMBER              10                  whatever                                26
# NUMBER              25                  whatever                                5
# QNUMBER             1                                                           11
# QNUMBER             10                                                          26
# QNUMBER             10 mg               10.0                                    26                  not_pikkus_unit
# QNUMBER             25                                                          5
# QNUMBER             25 mg               25.0                                    5                   not_pikkus_unit
# UNIT                a                   time_unit                               14
# UNIT                mg                  not_pikkus_unit                         8
# UNIT                mg                  not_pikkus_unit                         29
# UNIT                x                   time_unit                               10
# ------------------------
# Kolesterool 1k aastas .
# name                text                value               type                start               unit_type
#
# MO                  Kolesterool         kolesterool                             0
# NUMBER              1                   whatever                                12
# QNUMBER             1                                                           12
# UNIT                aasta               time_unit                               15
# ------------------------
# Kõrgenenud kolesterool 2a ( mõõdetud ). Ei pea dieetist kinni
# name                text                value               type                start               unit_type
#
# MEASUREMENT         kolesterool 2a                                              11
# MO                  kolesterool         kolesterool                             11
# NUMBER              2                   whatever                                23
# QNUMBER             2                                                           23
# QNUMBER             2a                  2.0                                     23                  time_unit
# UNIT                a                   time_unit                               24
# UNIT                a                   time_unit                               45
# UNIT                g                   kaal_unit                               3
# UNIT                m                   pikkus_unit                             28
# ------------------------
# Kontr Verekol 08.12a Per-le juurde .
# name                text                value               type                start               unit_type
#
# MEASUREMENT         kol 08.12a                                                  10
# MO                  kol                 kolesterool                             10
# NUMBER              08.12               whatever                                14
# QNUMBER             08.12                                                       14
# QNUMBER             08.12a              8.12                                    14                  time_unit
# UNIT                a                   time_unit                               19
# ------------------------
# s vas munajuha kasvaja op , günekol 3a tagssi .
# name                text                value               type                start               unit_type
#
# MEASUREMENT         kol 3a                                                      32
# MO                  kasv                pikkus                                  15
# MO                  kol                 kolesterool                             32
# NUMBER              3                   whatever                                36
# QNUMBER             3                                                           36
# QNUMBER             3a                  3.0                                     36                  time_unit
# UNIT                a                   time_unit                               13
# UNIT                a                   time_unit                               21
# UNIT                a                   time_unit                               37
# UNIT                g                   kaal_unit                               28
# UNIT                g                   kaal_unit                               41
# UNIT                m                   pikkus_unit                             6
# ------------------------
# 08.11.2010 PSA 13.12.2011 7,2ng/ml PSADT on väike .
# name                text                value               type                start               unit_type
#
# DATE                08.11.2010          date                                    0
# DATE                13.12               date                                    15
# DATE                2011                partial_date                            21
# MO                   PSA                psa                                     10
# MO                   PSA                psa                                     34
# NUMBER              7,2                 whatever                                26
# QNUMBER             7,2                                                         26
# QNUMBER             7,2ng/ml            7.2                                     26                  psa_unit
# UNIT                ng/ml               psa_unit                                29
# ------------------------
# Rütmihäire tsüklipikkus 330 msek
# name                text                value               type                start               unit_type
#
# MEASUREMENT         pikkus 330 msek                                             17
# MO                  pikkus              pikkus                                  17
# MO                  ük                  kolesterool                             13
# NUMBER              330                 whatever                                24
# QNUMBER             330                                                         24
# QNUMBER             330 msek            330.0                                   24                  time_unit
# UNIT                m                   pikkus_unit                             3
# UNIT                msek                time_unit                               28
# ------------------------
# Loote pikkus :   3 mm - vastab  5 nädalat 6 päeva.
# name                text                value               type                start               unit_type
#
# MEASUREMENT         pikkus :   3 mm                                             6
# MO                  pikkus              pikkus                                  6
# NUMBER              3                   whatever                                17
# NUMBER              5                   whatever                                32
# NUMBER              6                   whatever                                42
# QNUMBER             3                                                           17
# QNUMBER             3 mm                3.0                                     17                  not_pikkus_unit
# QNUMBER             5                                                           32
# QNUMBER             5 nädal             5.0                                     32                  time_unit
# QNUMBER             6                                                           42
# UNIT                a.                  time_unit                               48
# UNIT                mm                  not_pikkus_unit                         19
# UNIT                nädal               time_unit                               34
# ------------------------
# Põhjendus: PALAT 10 # ALAT maksanäitaja
# name                text                value               type                start               unit_type
#
# MO                  ALAT                alat                                    22
# NUMBER              10                  whatever                                17
# QNUMBER             10                                                          17
# UNIT                m                   pikkus_unit                             27
# ------------------------
# ärme vähk 2007 aastast cT3N0M0PSA 59ng/ml .
# name                text                value               type                start               unit_type
#
# DATE                2007 a              partial_date                            10
# MEASUREMENT         PSA 59ng/ml                                                 30
# MO                  PSA                 psa                                     30
# NUMBER              0                   whatever                                27
# NUMBER              0                   whatever                                29
# NUMBER              3                   whatever                                25
# NUMBER              59                  whatever                                34
# QNUMBER             0                                                           27
# QNUMBER             0                                                           29
# QNUMBER             3                                                           25
# QNUMBER             59                                                          34
# QNUMBER             59ng/ml             59.0                                    34                  psa_unit
# UNIT                m                   pikkus_unit                             2
# UNIT                ng/ml               psa_unit                                36
# ------------------------
# PSA 8,5( püsib aastaid selles väärtus
# name                text                value               type                start               unit_type
#
# MO                  PSA                 psa                                     0
# NUMBER              8,5                 whatever                                4
# QNUMBER             8,5                                                         4
# UNIT                aasta               time_unit                               15
# ------------------------
# S , P-PSA 4.130( <4.100 µg/L )
# name                text                value               type                start               unit_type
#
# DATE                4.100               date                                    18
# DATE                4.130               date                                    10
# MO                  S , P-PSA           psa                                     0
# UNIT                µg/L                psa_unit                                24
# ------------------------
# PSA 5,2.
# name                text                value               type                start               unit_type
#
# MO                  PSA                 psa                                     0
# NUMBER              5,2                 whatever                                4
# QNUMBER             5,2                                                         4
# ------------------------
# Kolesterool oli 7,9 mmol/l 0
# name                text                value               type                start               unit_type
#
# MEASUREMENT         Kolesterool oli 7,9 mmol/l                                        0
# MO                  Kolesterool         kolesterool                             0
# NUMBER              0                   whatever                                27
# NUMBER              7,9                 whatever                                16
# QNUMBER             0                                                           27
# QNUMBER             7,9                                                         16
# QNUMBER             7,9 mmol/l          7.9                                     16                  not_pikkus_unit
# UNIT                mmol/l              not_pikkus_unit                         20
# ------------------------
# kolesterool 6.4.
# name                text                value               type                start               unit_type
#
# MO                  kolesterool         kolesterool                             0
# NUMBER              6.4                 whatever                                12
# QNUMBER             6.4                                                         12
# ------------------------
# Kolesterool 5,2 mmol/l - esialgu dieet .
# name                text                value               type                start               unit_type
#
# MEASUREMENT         Kolesterool 5,2 mmol/l                                        0
# MO                  Kolesterool         kolesterool                             0
# NUMBER              5,2                 whatever                                12
# QNUMBER             5,2                                                         12
# QNUMBER             5,2 mmol/l          5.2                                     12                  not_pikkus_unit
# UNIT                g                   kaal_unit                               30
# UNIT                mmol/l              not_pikkus_unit                         16
# ------------------------
# SK 3900 g , SP 51 cm .
# name                text                value               type                start               unit_type
#
# DATE                3900                date                                    3
# MEASUREMENT          SP 51 cm                                                   11
# MO                   SP                 pikkus                                  11
# MO                  SK                  kaal                                    0
# NUMBER              51                  whatever                                15
# QNUMBER             51                                                          15
# QNUMBER             51 cm               51.0                                    15                  pikkus_unit
# UNIT                cm                  pikkus_unit                             18
# UNIT                g                   kaal_unit                               8
# ------------------------
# Lapse kaal 5,4 kg/82 mg/0,82 ml i/m .
# name                text                value               type                start               unit_type
#
# MEASUREMENT         kaal 5,4 kg                                                 6
# MO                  kaal                kaal                                    6
# NUMBER              0,82                whatever                                24
# NUMBER              5,4                 whatever                                11
# NUMBER              82                  whatever                                18
# QNUMBER             0,82                                                        24
# QNUMBER             0,82 m              0.82                                    24                  pikkus_unit
# QNUMBER             5,4                                                         11
# QNUMBER             5,4 kg              5.4                                     11                  kaal_unit
# QNUMBER             82                                                          18
# QNUMBER             82 mg               82.0                                    18                  not_pikkus_unit
# UNIT                kg                  kaal_unit                               15
# UNIT                m                   pikkus_unit                             29
# UNIT                m                   pikkus_unit                             34
# UNIT                mg                  not_pikkus_unit                         21
# ------------------------
# Kehakaal 80,2 kg , KMI 25,9
# name                text                value               type                start               unit_type
#
# MEASUREMENT         Kehakaal 80,2 kg                                            0
# MO                  Kehakaal            kaal                                    0
# NUMBER              25,9                whatever                                23
# NUMBER              80,2                whatever                                9
# QNUMBER             25,9                                                        23
# QNUMBER             80,2                                                        9
# QNUMBER             80,2 kg             80.2                                    9                   kaal_unit
# UNIT                kg                  kaal_unit                               14
# ------------------------
# S , P-NT-proBNP 668 ( <125 pg/mL ) S , P-Albumiin 43 ( 35 .. 52 g/L ) S , P-ALAT 25 ( <33 U/L )
# name                text                value               type                start               unit_type
#
# MO                  ALAT                alat                                    76
# NUMBER              125                 whatever                                23
# NUMBER              25                  whatever                                81
# NUMBER              33                  whatever                                87
# NUMBER              35                  whatever                                55
# NUMBER              43                  whatever                                50
# NUMBER              52                  whatever                                61
# NUMBER              668                 whatever                                16
# QNUMBER             125                                                         23
# QNUMBER             25                                                          81
# QNUMBER             33                                                          87
# QNUMBER             33 U/L              33.0                                    87                  alat_unit
# QNUMBER             35                                                          55
# QNUMBER             43                                                          50
# QNUMBER             52                                                          61
# QNUMBER             52 g                52.0                                    61                  kaal_unit
# QNUMBER             668                                                         16
# UNIT                U/L                 alat_unit                               90
# UNIT                g                   kaal_unit                               28
# UNIT                g                   kaal_unit                               64
# UNIT                m                   pikkus_unit                             30
# UNIT                m                   pikkus_unit                             45
# ------------------------
# PSA 6,5 ng/ml, eesnäärme maht67cm3
# name                text                value               type                start               unit_type
#
# MEASUREMENT         PSA 6,5 ng/ml                                               0
# MO                  PSA                 psa                                     0
# NUMBER              3                   whatever                                33
# NUMBER              6,5                 whatever                                4
# NUMBER              67                  whatever                                29
# QNUMBER             3                                                           33
# QNUMBER             6,5                                                         4
# QNUMBER             6,5 ng/ml           6.5                                     4                   psa_unit
# QNUMBER             67                                                          29
# QNUMBER             67cm                67.0                                    29                  pikkus_unit
# UNIT                cm                  pikkus_unit                             31
# UNIT                m                   pikkus_unit                             22
# UNIT                m                   pikkus_unit                             25
# UNIT                ng/ml               psa_unit                                8
# ------------------------
# rjeldus : Siinusbradükardia Fr 587min
# name                text                value               type                start               unit_type
#
# MEASUREMENT         Fr 587min                                                   28
# MO                  Fr                  pulss                                   28
# MO                  ük                  kolesterool                             20
# NUMBER              587                 whatever                                31
# QNUMBER             587                                                         31
# QNUMBER             587min              587.0                                   31                  time_unit
# UNIT                a                   time_unit                               26
# UNIT                min                 time_unit                               34
# ------------------------

# %%
plot_graph(graph.parse_trees)

# %%
import ipywidgets as widgets


text_selection = widgets.Dropdown(
    options=lines,
    description='Text:',
)

def observe(change):
    out.clear_output()
    with out:
        line = change['new']
        graph = layer_to_graph(text['grammar_tags'])
        graph = parse_graph(graph, grammar, 4)
        print(lines_to_texts[line].text)
        plot_graph(graph)

text_selection.observe(observe, names='value')

out = widgets.Output()

display(text_selection, out)
# Out:
# Dropdown(description='Text:', options=('PSA 03042012 - 0,83ng/ml perearsti poolt .', 'PSA 2010. 3ng/ml, PSA 2012. 1,53ng/ml . - Bx va', 'PSA 20105,99 ja 26.01.2012 uuesti .', 'PSA 2011 oli 0 , 4 nG7ml .', 'PSA 201222,25ng/ml', 'PSA 2 aastajooksuldünaamikata , eriuuring', ':psa 16,81! ! ! ! ! ,', 'Happe-aluse tasakaal 6.0 ( 5.0 .. 8.0 )', 'loli 25 mgx1 ja Monoprili 10 mg Kolesterool 2011a', 'Kolesterool 1k aastas .', 'Kõrgenenud kolesterool 2a ( mõõdetud ). Ei pea dieetist kinni', 'Kontr Verekol 08.12a Per-le juurde .', 's vas munajuha kasvaja op , günekol 3a tagssi .', '08.11.2010 PSA 13.12.2011 7,2ng/ml PSADT on väike .', 'Rütmihäire tsüklipikkus 330 msek', 'Loote pikkus : \xa0 3 mm - vastab\xa0 5 nädalat 6 päeva.', 'Põhjendus: PALAT 10 # ALAT maksanäitaja', 'ärme vähk 2007 aastast cT3N0M0PSA 59ng/ml .', 'PSA 8,5( püsib aastaid selles väärtus', 'S , P-PSA 4.130( <4.100 µg/L )', 'PSA 5,2.', 'Kolesterool oli 7,9 mmol/l 0', 'kolesterool 6.4.', 'Kolesterool 5,2 mmol/l - esialgu dieet .', 'SK 3900 g , SP 51 cm .', 'Lapse kaal 5,4 kg/82 mg/0,82 ml i/m .', 'Kehakaal 80,2 kg , KMI 25,9', 'S , P-NT-proBNP 668 ( <125 pg/mL ) S , P-Albumiin 43 ( 35 .. 52 g/L ) S , P-ALAT 25 ( <33 U/L )', 'PSA 6,5 ng/ml, eesnäärme maht67cm3', 'rjeldus : Siinusbradükardia Fr 587min'), value='PSA 03042012 - 0,83ng/ml perearsti poolt .')
# Output()

# %%
for node in graph:
    node.print()
# Out:
# NonTerminalNode
#   name                 QNUMBER
#   start                31
#   end                  34
#   _support_            (TerminalNode(NUMBER, (31, 34), -3572320669870409329),)
#   _group_              -8886844308723222585
#   _priority_           1
#   _terminals_          (TerminalNode(NUMBER, (31, 34), -3572320669870409329),)
#   text_spans           ((31, 34),)
# TerminalNode
#   name                 MO
#   text                 Fr
#   start                28
#   end                  30
#   _support_            Span(Fr, {'grammar_symbol': 'MO', 'value': 'pulss'})
#   _group_              -3553993144590770579
#   _priority_           0
#   _terminals_          (TerminalNode(MO, (28, 30), -3553993144590770579),)
#   grammar_symbol       MO
#   text_spans           ((28, 30),)
#   value                pulss
# TerminalNode
#   name                 RANDOM_TEXT
#   text                 Siinusbrad
#   start                10
#   end                  20
#   _support_            Span(Siinusbrad, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})
#   _group_              5901830215109643374
#   _priority_           0
#   _terminals_          (TerminalNode(RANDOM_TEXT, (10, 20), 5901830215109643374),)
#   grammar_symbol       RANDOM_TEXT
#   text_spans           ((10, 20),)
#   value                None
# TerminalNode
#   name                 NUMBER
#   text                 587
#   start                31
#   end                  34
#   _support_            Span(587, {'grammar_symbol': 'NUMBER', 'value': 'whatever'})
#   _group_              -3572320669870409329
#   _priority_           0
#   _terminals_          (TerminalNode(NUMBER, (31, 34), -3572320669870409329),)
#   grammar_symbol       NUMBER
#   text_spans           ((31, 34),)
#   value                whatever
# TerminalNode
#   name                 MO
#   text                 ük
#   start                20
#   end                  22
#   _support_            Span(ük, {'grammar_symbol': 'MO', 'value': 'kolesterool'})
#   _group_              -4515131158400914928
#   _priority_           0
#   _terminals_          (TerminalNode(MO, (20, 22), -4515131158400914928),)
#   grammar_symbol       MO
#   text_spans           ((20, 22),)
#   value                kolesterool
# PhonyNode
#   name                 END
#   start                inf
#   end                  inf
# TerminalNode
#   name                 UNIT
#   text                 a
#   start                26
#   end                  28
#   _support_            Span(a , {'grammar_symbol': 'UNIT', 'value': 'time_unit'})
#   _group_              -130259934941642057
#   _priority_           0
#   _terminals_          (TerminalNode(UNIT, (26, 28), -130259934941642057),)
#   grammar_symbol       UNIT
#   text_spans           ((26, 28),)
#   value                time_unit
# TerminalNode
#   name                 RANDOM_TEXT
#   text                 ardi
#   start                22
#   end                  26
#   _support_            Span(ardi, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})
#   _group_              -4780742247483559846
#   _priority_           0
#   _terminals_          (TerminalNode(RANDOM_TEXT, (22, 26), -4780742247483559846),)
#   grammar_symbol       RANDOM_TEXT
#   text_spans           ((22, 26),)
#   value                None
# TerminalNode
#   name                 UNIT
#   text                 min
#   start                34
#   end                  37
#   _support_            Span(min, {'grammar_symbol': 'UNIT', 'value': 'time_unit'})
#   _group_              3728551153341409339
#   _priority_           0
#   _terminals_          (TerminalNode(UNIT, (34, 37), 3728551153341409339),)
#   grammar_symbol       UNIT
#   text_spans           ((34, 37),)
#   value                time_unit
# NonTerminalNode
#   name                 QNUMBER
#   start                31
#   end                  37
#   _support_            (TerminalNode(NUMBER, (31, 34), -3572320669870409329), TerminalNode(UNIT, (34, 37), 3728551153341409339))
#   _group_              4062319825439058887
#   _priority_           0
#   _terminals_          (TerminalNode(NUMBER, (31, 34), -3572320669870409329), TerminalNode(UNIT, (34, 37), 3728551153341409339))
#   mtype                continuous
#   text_spans           ((31, 34), (34, 37))
#   unit                 min
#   unit_type            time_unit
#   value                587.0
# NonTerminalNode
#   name                 MEASUREMENT
#   start                28
#   end                  37
#   _support_            (TerminalNode(MO, (28, 30), -3553993144590770579), NonTerminalNode(QNUMBER, (31, 37), -7560782039059797252))
#   _group_              -6806429772346861125
#   _priority_           0
#   _terminals_          (TerminalNode(MO, (28, 30), -3553993144590770579), TerminalNode(NUMBER, (31, 34), -3572320669870409329), TerminalNode(UNIT, (34, 37), 3728551153341409339))
#   text_spans           ((28, 30), (31, 34), (34, 37))
# TerminalNode
#   name                 RANDOM_TEXT
#   text                 rjeldus
#   start                0
#   end                  7
#   _support_            Span(rjeldus, {'grammar_symbol': 'RANDOM_TEXT', 'value': None})
#   _group_              8486111532006600670
#   _priority_           0
#   _terminals_          (TerminalNode(RANDOM_TEXT, (0, 7), 8486111532006600670),)
#   grammar_symbol       RANDOM_TEXT
#   text_spans           ((0, 7),)
#   value                None
# PhonyNode
#   name                 START
#   start                -inf
#   end                  -inf

# %%
nodes = sorted(graph.nodes)
nodes
# Out:
# [PhonyNode(START, (-inf, -inf), -327062290981420033),
#  TerminalNode(RANDOM_TEXT, (0, 7), 8486111532006600670),
#  TerminalNode(RANDOM_TEXT, (10, 20), 5901830215109643374),
#  TerminalNode(MO, (20, 22), -4515131158400914928),
#  TerminalNode(RANDOM_TEXT, (22, 26), -4780742247483559846),
#  TerminalNode(UNIT, (26, 28), -130259934941642057),
#  TerminalNode(MO, (28, 30), -3553993144590770579),
#  NonTerminalNode(MEASUREMENT, (28, 37), 1192906550852545658),
#  NonTerminalNode(QNUMBER, (31, 34), 2705057879940558719),
#  TerminalNode(NUMBER, (31, 34), -3572320669870409329),
#  NonTerminalNode(QNUMBER, (31, 37), -7560782039059797252),
#  TerminalNode(UNIT, (34, 37), 3728551153341409339),
#  PhonyNode(END, (inf, inf), -5937846439748828491)]

# %%
nodes[3].print()
# Out:
# TerminalNode
#   name                 MO
#   text                 ük
#   start                20
#   end                  22
#   _support_            Span(ük, {'grammar_symbol': 'MO', 'value': 'kolesterool'})
#   _group_              -4515131158400914928
#   _priority_           0
#   _terminals_          (TerminalNode(MO, (20, 22), -4515131158400914928),)
#   grammar_symbol       MO
#   text_spans           ((20, 22),)
#   value                kolesterool

# %%
from estnltk.finite_grammar.layer_graph import get_nodes
get_nodes(graph, 'QNUMBER')
# Out:
# [NonTerminalNode(QNUMBER, (31, 34), 2705057879940558719),
#  NonTerminalNode(QNUMBER, (31, 37), -7560782039059797252)]

# %%
from estnltk.finite_grammar.layer_graph import get_paths

list(get_paths(graph, nodes[3], source=nodes[0], target=nodes[11]))
# Out:
# [[PhonyNode(START, (-inf, -inf), -327062290981420033),
#   TerminalNode(RANDOM_TEXT, (0, 7), 8486111532006600670),
#   TerminalNode(RANDOM_TEXT, (10, 20), 5901830215109643374),
#   TerminalNode(MO, (20, 22), -4515131158400914928),
#   TerminalNode(RANDOM_TEXT, (22, 26), -4780742247483559846),
#   TerminalNode(UNIT, (26, 28), -130259934941642057),
#   TerminalNode(MO, (28, 30), -3553993144590770579),
#   NonTerminalNode(QNUMBER, (31, 34), 2705057879940558719),
#   TerminalNode(UNIT, (34, 37), 3728551153341409339)],
#  [PhonyNode(START, (-inf, -inf), -327062290981420033),
#   TerminalNode(RANDOM_TEXT, (0, 7), 8486111532006600670),
#   TerminalNode(RANDOM_TEXT, (10, 20), 5901830215109643374),
#   TerminalNode(MO, (20, 22), -4515131158400914928),
#   TerminalNode(RANDOM_TEXT, (22, 26), -4780742247483559846),
#   TerminalNode(UNIT, (26, 28), -130259934941642057),
#   TerminalNode(MO, (28, 30), -3553993144590770579),
#   TerminalNode(NUMBER, (31, 34), -3572320669870409329),
#   TerminalNode(UNIT, (34, 37), 3728551153341409339)]]

# %%
paths = list(get_paths(graph, nodes[3]))
paths
# Out:
# [[PhonyNode(START, (-inf, -inf), -327062290981420033),
#   TerminalNode(RANDOM_TEXT, (0, 7), 8486111532006600670),
#   TerminalNode(RANDOM_TEXT, (10, 20), 5901830215109643374),
#   TerminalNode(MO, (20, 22), -4515131158400914928),
#   TerminalNode(RANDOM_TEXT, (22, 26), -4780742247483559846),
#   TerminalNode(UNIT, (26, 28), -130259934941642057),
#   NonTerminalNode(MEASUREMENT, (28, 37), 1192906550852545658),
#   PhonyNode(END, (inf, inf), -5937846439748828491)],
#  [PhonyNode(START, (-inf, -inf), -327062290981420033),
#   TerminalNode(RANDOM_TEXT, (0, 7), 8486111532006600670),
#   TerminalNode(RANDOM_TEXT, (10, 20), 5901830215109643374),
#   TerminalNode(MO, (20, 22), -4515131158400914928),
#   TerminalNode(RANDOM_TEXT, (22, 26), -4780742247483559846),
#   TerminalNode(UNIT, (26, 28), -130259934941642057),
#   TerminalNode(MO, (28, 30), -3553993144590770579),
#   NonTerminalNode(QNUMBER, (31, 34), 2705057879940558719),
#   TerminalNode(UNIT, (34, 37), 3728551153341409339),
#   PhonyNode(END, (inf, inf), -5937846439748828491)],
#  [PhonyNode(START, (-inf, -inf), -327062290981420033),
#   TerminalNode(RANDOM_TEXT, (0, 7), 8486111532006600670),
#   TerminalNode(RANDOM_TEXT, (10, 20), 5901830215109643374),
#   TerminalNode(MO, (20, 22), -4515131158400914928),
#   TerminalNode(RANDOM_TEXT, (22, 26), -4780742247483559846),
#   TerminalNode(UNIT, (26, 28), -130259934941642057),
#   TerminalNode(MO, (28, 30), -3553993144590770579),
#   NonTerminalNode(QNUMBER, (31, 37), -7560782039059797252),
#   PhonyNode(END, (inf, inf), -5937846439748828491)],
#  [PhonyNode(START, (-inf, -inf), -327062290981420033),
#   TerminalNode(RANDOM_TEXT, (0, 7), 8486111532006600670),
#   TerminalNode(RANDOM_TEXT, (10, 20), 5901830215109643374),
#   TerminalNode(MO, (20, 22), -4515131158400914928),
#   TerminalNode(RANDOM_TEXT, (22, 26), -4780742247483559846),
#   TerminalNode(UNIT, (26, 28), -130259934941642057),
#   TerminalNode(MO, (28, 30), -3553993144590770579),
#   TerminalNode(NUMBER, (31, 34), -3572320669870409329),
#   TerminalNode(UNIT, (34, 37), 3728551153341409339),
#   PhonyNode(END, (inf, inf), -5937846439748828491)]]

# %%
grammar.rules
# Out:
# [QNUMBER -> NUMBER UNIT	: 0, val: default_validator, dec: qnumber_decorator,
#  QNUMBER -> NUMBER	: 1, val: default_validator, dec: default_decorator,
#  MEASUREMENT -> MO DATE QNUMBER	: 0, val: measurement_validator, dec: measurement_decorator,
#  MEASUREMENT -> MO QNUMBER	: 0, val: measurement_validator, dec: default_decorator,
#  TRASH -> RUBBISH NUMBER	: 0, val: default_validator, dec: default_decorator,
#  TRASH -> RUBBISH MO NUMBER	: 0, val: default_validator, dec: default_decorator,
#  TRASH -> RUBBISH	: 0, val: default_validator, dec: default_decorator,
#  TRASH -> MO DATE	: 0, val: default_validator, dec: default_decorator]

# %%
#paths[0]
from estnltk.finite_grammar.layer_graph import LayerGraph
from estnltk.finite_grammar.grammar import debug_rule

rule = grammar.rules[0]
grammar_1 = Grammar(start_symbols=[rule.lhs], rules=[rule], max_depth=4)

graph = LayerGraph()
for a, b in zip(paths[0], paths[0][1:]):
    graph.add_edge(a, b)
plot_graph(graph, 4)
parse_graph(graph, grammar_1, debug=True)
plot_graph(graph, 4)
# Out:
# rule: QNUMBER -> NUMBER UNIT	: 0, val: default_validator, dec: qnumber_decorator
# no match
