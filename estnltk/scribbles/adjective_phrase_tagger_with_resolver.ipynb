# %% [markdown]
# # AdjectivePhraseTagger
#
# A class that tags simple adjective phrases on the **Text** object.
#
# ## Usage

# %%
from estnltk.taggers import AdjectivePhraseTagger
from estnltk import Text

# %% [markdown]
# To use **AdjectivePhraseTagger**, a **Text** object needs to be created with the layer of morphological analysis added to it:

# %%
sent = Text("Eile leitud koer oli väga energiline ja mänguhimuline.").analyse('morphology')

# %% [markdown]
# We also need to create an **AdjectivePhraseTagger** object and then tag adjective phrases as a new layer on the **Text** object:

# %%
tagger = AdjectivePhraseTagger()
tagger.tag(sent)
# Out:
# Text(text="Eile leitud koer oli väga energiline ja mänguhimuline.")

# %%
sent.adjective_phrases
# Out:
# Layer(name=adjective_phrases, spans=SL[ES[AS[Span(leitud, {'grammar_symbol': 'ADJ'})]],
# ES[AS[Span(väga, {'grammar_symbol': 'ADJ_M'}), Span(väga, {'grammar_symbol': 'ADV2'})],
# AS[Span(energiline, {'grammar_symbol': 'ADJ'})],
# AS[Span(ja, {'grammar_symbol': 'CONJ'})],
# AS[Span(mänguhimuline, {'grammar_symbol': 'ADJ'})]]])

# %% [markdown]
# ### Attributes that are given with the adjective phrases:
#
# **type** is the specific type of the adjective phrase:
# * **adjective**: adjective is in its 'normal' (aka positive) form
# * **comparative**: contains a comparative adjective
# * **participle**: contains an adjective derived from a verb

# %% [markdown]
# **adverb_class** marks the intensity of the adverb in the phrase. Each class has also been assigned a weight (**adverb_weight**) noting its intensity. Currently there are 6 classes with their corresponding weights:
# * diminisher: 0.5
# * doubt: 0.7
# * affirmation: 1.5
# * strong_intensifier: 2
# * surprise: 3
# * excess: 3
#
# All the adverbs are not divided into classes, therefore some do have None as **adverb_class** and NaN as **adverb_weight**.

# %% [markdown]
# ### Example
#
# Adjective phrases can be used for sentiment analysis - determining the polarity of the text. While this is often done using only adjectives, the phrases consisting of an adverb and an adjective can give more precise results because adverbs in these kinds of phrases are usually some sort of intensifiers. For this purpose, the most frequent adverbs are already divided into classes and assigned weights based on their intensifying properties (see above).

# %% [markdown]
# To illustrate this, let's build a very simple system for sentiment analysis.
# For this, we can use *hinnavaatlus.csv* dataset that contains user reviews and their ratings (positive, negative and neutral).

# %% [markdown]
# First, let's extract adjectives from the user reviews and create separate frequency lists of adjectives appearing in positive and negative reviews.

# %%
import csv
from collections import defaultdict

pos = {}
neg = {}

adjectives = defaultdict(lambda : defaultdict(int))

with open('hinnavaatlus.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='"')
    
    for idx, row in enumerate(reader):
        text = Text(row[1]).analyse('morphology')
        tagged = tagger.tag(text)
        label = row[2]
        if len(tagged.adjective_phrases) > 0:
            for phrase in tagged.adjective_phrases:
                if len(phrase.text) > 1:
                    print(phrase.text)
# Out:
# ['väga', 'hea']
# ['väga', 'meeldivad']
# ['äärmiselt', 'asjalik']
# ['Väga', 'head']
# ['Väga', 'head']
# ['väga', 'jube']
# ['väga', 'personaalsel']
# ['väga', 'meeldiv']
# ['väga', 'vinge']
# ['tõesti', 'tibake']
# ['väga', 'hea']
# ['kõige', 'odavam']
# ['väga', 'stabiilne']
# ['suht', 'kallid']
# ['väga', 'halb']
# ['väga', 'hea']
# ['Väga', 'hea']
# ['liiga', 'kõrge']
# ['nii', 'kehv']
# ['Tõsiselt', 'kehv']
# ['nii', 'halb']
# ['nii', 'halb']
# ['Täiesti', 'mõttetu']
# ['tunduvalt', 'kallimat']
# ['Kohutavalt', 'kehv']
# ['kõige', 'viimane']
# ['Väga', 'viisakas']
# ['Väga', 'korralik']
# ['Väga', 'hea']
# ['igati', 'vajalik']
# ['väga', 'hea']
# ['Väga', 'hea']
# ['TÄIESTI', 'KORRALIKKU']
# ['Väga', 'kiire', 'ja', 'asjalik']
# ['suht', 'haige']
# ['Väga', 'kiire']
# ['väga', 'korralik']
# ['Väga', 'hea']
# ['Väga', 'asjalik', 'ja', 'kiire']
# ['Väga', 'hea']
# ['hoopiski', 'vale']
# ['väga', 'head']
# ['Igati', 'positiivne']
# ['väga', 'kiire']
# ['Igati', 'meeldiv']
# ['väga', 'head']
# ['tõesti', 'odavad', 'ning', 'kvaliteetsed']
# ['väga', 'soojad']
# ['jube', 'odav']
# ['väga', 'hea']
# ['Väga', 'positiivne']
# ['väga', 'ebastabiilse', 'ja', 'ettearvamatu']
# ['päris', 'pikk']
# ['palju', 'eksootilist']
# ['Väga', 'head']
# ['väga', 'kiire', 'ja', 'meeldiv']
# ['Igati', 'positiivne']
# ['Väga', 'hea']
# ['vägagi', 'kobeda']
# ['Väga', 'hea']
# ['Väga', 'asjalik']
# ['veel', 'soodsama']
# ['veidi', 'positiivsema']
# ['väga', 'head']
# ['väga', 'ebasõbralikud']
# ['Väga', 'vilets']
# ['väga', 'hea']
# ['väga', 'hea']
# ['väga', 'head']
# ['Väga', 'meeldiv']
# ['Tõsiselt', 'hea']
# ['Väga', 'hea']
# ['Eriti', 'meeldiv']
# ['pisut', 'kiirem']
# ['pisut', 'lühemat']
# ['tõesti', 'head']
# ['täiesti', 'mõttetu']
# ['väga', 'raske']
# ['Väga', 'head']
# ['tõsiselt', 'kiire']
# ['eriti', 'üleolev', 'ja', 'ebaviisakas']
# ['igati', 'korralik']
# ['väga', 'hea']
# ['Väga', 'positiivne']
# ['Üllatavalt', 'kiire', 'ja', 'meeldiv']
# ['hästi', 'pakitud']
# ['Täitsa', 'normaalne']
# ['väga', 'soodsa']
# ['Igati', 'positiivne']
# ['hästi', 'pakitud']
# ['veidi', 'spetsiifilisemat']
# ['Meeldivalt', 'kiire']
# ['väga', 'hea']
# ['väga', 'meeldiv']
# ['Kõige', 'odavamad']
# ['suhteliselt', 'olematu']
# ['väga', 'vastutulelikud']
# ['Väga', 'mõistlik']
# ['väga', 'viisaka']
# ['igati', 'positiivne']
# ['igati', 'positiivse']
# ['Väga', 'kiire']
# ['jube', 'kallis']
# ['Väga', 'kiire']
# ['kõige', 'soodsam']
# ['Väga', 'meeldiv']
# ['tõesti', 'lihtne']
# ['Väga', 'nõme']
# ['väga', 'hea']
# ['hästi', 'jälgitav']
# ['väga', 'professionaalne']
# ['Väga', 'ebaviisakas']
# ['väga', 'lihtne']
# ['igati', 'meeldiv']
# ['Natuke', 'nõme']
# ['väga', 'kliendisõbralik']
# ['väga', 'väikse']
# ['tunduvalt', 'odavam']
# ['üsna', 'häid']
# ['kõige', 'sootsamad']
# ['Väga', 'kiire', 'ja', 'konkreetne']
# ['väga', 'mustaks']
# ['eriti', 'viimane']
# ['Väga', 'positiivne']
# ['ülimalt', 'vajalik']
# ['Väga', 'ebausaldusväärne']
# ['Väga', 'negatiivne']
# ['igati', 'tellitav']
# ['täiesti', 'lõppenuks']
# ['natuke', 'kallim']
# ['natuke', 'lünklik']
# ['väga', 'raske']
# ['väga', 'segaseks']
# ['igati', 'positiivne']
# ['Väga', 'kiire']
# ['Päris', 'lai']
# ['oluliselt', 'odavam']
# ['veel', 'olnud']
# ['Väga', 'meeldiv', 'ja', 'ülikiire']
# ['nats', 'segane']
# ['veel', 'odavama']
# ['väga', 'hea']
# ['palju', 'oodavam']
# ['väga', 'suur']
# ['Uskumatult', 'sitt']
# ['veel', 'jõudnud']
# ['Väga', 'kahtlane']
# ['liiga', 'pikk']
# ['Väga', 'asjalik']
# ['kõige', 'odavam']
# ['kõige', 'tugevam']
# ['igati', 'vastutulelik']
# ['Meeldivalt', 'kiire']
# ['ülimalt', 'soodne']
# ['märkimisväärselt', 'soodsam']
# ['väga', 'head']
# ['Jõle', 'huvitav']
# ['väga', 'hea']
# ['veidi', 'kõrgem']
# ['väga', 'hea']
# ['väga', 'head']
# ['pisut', 'närvis']
# ['igati', 'meeldiv', 'ja', 'abivalmis']
# ['väga', 'head']
# ['Väga', 'negatiivsed']
# ['täitsa', 'vastupidine']
# ['suht', 'uue']
# ['väga', 'head']
# ['väga', 'head']
# ['väga', 'soodne']
# ['väga', 'hea']
# ['veel', 'tulnud']
# ['palju', 'tõusnud']
# ['kõige', 'soodsam']
# ['Väga', 'kiire', 'ja', 'sõbralik']
# ['suhteliselt', 'hea']
# ['igati', 'hea']
# ['Väga', 'positiivne']
# ['Äärmiselt', 'kiire']
# ['väga', 'kiire']
# ['väga', 'astutulelik']
# ['Ülimalt', 'meeldiv']
# ['väga', 'vastutulelikud']
# ['täiesti', 'korralik']
# ['päris', 'tuntav']
# ['natuke', 'põhjalikumaid']
# ['Igati', 'asjalik']
# ['igati', 'positiivne']
# ['väga', 'hea']
# ['nii', 'vaikne']
# ['oluliselt', 'madalam']
# ['Väga', 'hea', 'ja', 'kiire']
# ['sedavõrd', 'kiiret']
# ['väga', 'kiire']
# ['kõige', 'odavam']
# ['kõige', 'soodsam']
# ['väga', 'meeldiv']
# ['kõige', 'parem']
# ['kõige', 'odavama']
# ['väga', 'negatiivne']
# ['väga', 'kiire']
# ['väga', 'kiire']
# ['eriti', 'head']
# ['märksa', 'nõrgema']
# ['nii', 'dokumentaalsed']
# ['väga', 'positiivne']
# ['Väga', 'täpne']
# ['väga', 'hea']
# ['nii', 'vana']
# ['igati', 'korrektne']
# ['Väga', 'meeldiv']
# ['Hästi', 'positiivse']
# ['Väga', 'head']
# ['tunduvalt', 'madalamat']
# ['eriti', 'kahtlane']
# ['väga', 'halb']
# ['väga', 'kiire']
# ['väga', 'hea']
# ['pigem', 'positiivne']
# ['väga', 'hea']
# ['väga', 'tüütu', 'ja', 'ebameeldiv']
# ['Väga', 'hea']
# ['Väga', 'tore']
# ['väga', 'ebameeldiv']
