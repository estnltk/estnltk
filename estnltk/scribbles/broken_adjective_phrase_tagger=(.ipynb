# %% [markdown]
# # AdjectivePhraseTagger
#
# A class that tags simple adjective phrases on the **Text** object.
#
# ## Usage

# %%
from estnltk.taggers import AdjectivePhraseTagger
from estnltk import Text

# %% [markdown]
# To use **AdjectivePhraseTagger**, a **Text** object needs to be created with the layer of morphological analysis added to it:

# %%
sent = Text("Eile leitud koer oli väga energiline ja mänguhimuline.").analyse('morphology')

# %% [markdown]
# We also need to create an **AdjectivePhraseTagger** object and then tag adjective phrases as a new layer on the **Text** object:

# %%
tagger = AdjectivePhraseTagger()
tagger.tag(sent)
sent.grammar_tags
# Out:
# Layer(name=grammar_tags, spans=SL[AS[Span(Eile, {'grammar_symbol': 'ADV2'})],
# AS[Span(leitud, {'grammar_symbol': 'ADJ'})],
# AS[Span(koer oli, {'grammar_symbol': 'RANDOM_TEXT'})],
# AS[Span(väga, {'grammar_symbol': 'ADJ_M'}),
# Span(väga, {'grammar_symbol': 'ADV2'})],
# AS[Span(energiline, {'grammar_symbol': 'ADJ'})],
# AS[Span(ja, {'grammar_symbol': 'CONJ'})],
# AS[Span(mänguhimuline, {'grammar_symbol': 'ADJ'})],
# AS[Span(., {'grammar_symbol': 'RANDOM_TEXT'})]])

# %%
sent.adjective_phrases
# Out:
# Layer(name=adjective_phrases, spans=SL[ES[AS[Span(Eile, {'grammar_symbol': 'ADV2'})],
# AS[Span(leitud, {'grammar_symbol': 'ADJ'})]],
# ES[AS[Span(väga, {'grammar_symbol': 'ADJ_M'}),
# Span(väga, {'grammar_symbol': 'ADV2'})],
# AS[Span(energiline, {'grammar_symbol': 'ADJ'})],
# AS[Span(ja, {'grammar_symbol': 'CONJ'})],
# AS[Span(mänguhimuline, {'grammar_symbol': 'ADJ'})]]])

# %%
t = sent.adjective_phrases[1].text
t
# Out:
# [['väga', 'väga'], ['energiline'], ['ja'], ['mänguhimuline']]

# %%
[s[0] for s in t]
# Out:
# ['väga', 'energiline', 'ja', 'mänguhimuline']

# %%
' '.join(s[0] for s in t)
# Out:
# 'väga energiline ja mänguhimuline'

# %%
sent.text[sent.adjective_phrases[1].start: sent.adjective_phrases[1].end]
# Out:
# 'väga energiline ja mänguhimuline'

# %% [markdown]
# ### Attributes that are given with the adjective phrases:
#
# **type** is the specific type of the adjective phrase:
# * **adjective**: adjective is in its 'normal' (aka positive) form
# * **comparative**: contains a comparative adjective
# * **participle**: contains an adjective derived from a verb

# %% [markdown]
# **adverb_class** marks the intensity of the adverb in the phrase. Each class has also been assigned a weight (**adverb_weight**) noting its intensity. Currently there are 6 classes with their corresponding weights:
# * diminisher: 0.5
# * doubt: 0.7
# * affirmation: 1.5
# * strong_intensifier: 2
# * surprise: 3
# * excess: 3
#
# All the adverbs are not divided into classes, therefore some do have None as **adverb_class** and NaN as **adverb_weight**.

# %%
import csv
from collections import defaultdict

pos = {}
neg = {}

adjectives = defaultdict(lambda : defaultdict(int))

with open('hinnavaatlus.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='"')

    for idx, row in enumerate(reader):
        text = Text(row[1]).analyse('morphology')
        tagged = tagger.tag(text)
        label = row[2]
        if len(tagged.adjective_phrases) > 0:
            for phrase in tagged.adjective_phrases:
                if len(phrase.text) > 1:
                    print(phrase.text)
# Out:
# [['väga', 'väga'], ['hea']]
# [['väga', 'väga'], ['meeldivad']]
# [['äärmiselt', 'äärmiselt'], ['asjalik']]
# [['seal'], ['veedetud']]
# [['Väga', 'Väga'], ['head']]
# [['Väga', 'Väga'], ['head']]
# [['väga', 'väga'], ['jube', 'jube']]
# [['väga', 'väga'], ['personaalsel']]
# [['väga', 'väga'], ['meeldiv']]
# [['väga', 'väga'], ['vinge']]
# [['tõesti', 'tõesti'], ['tibake']]
# [['väga', 'väga'], ['hea']]
# [['sealt'], ['tellinud']]
# [['kohale'], ['toodud']]
# [['kõige', 'kõige'], ['odavam']]
# [['väga', 'väga'], ['stabiilne']]
# [['suht'], ['kallid']]
# [['väga', 'väga'], ['halb']]
# [['väga', 'väga'], ['hea']]
# [['Väga', 'Väga'], ['hea']]
# [['liiga', 'liiga'], ['kõrge']]
# [['nii', 'nii'], ['kehv']]
# [['Tõsiselt', 'Tõsiselt'], ['kehv']]
# [['siiani'], ['olnud']]
# [['nii', 'nii'], ['halb']]
# [['nii', 'nii'], ['halb']]
# [['alati'], ['astunud']]
# [['Täiesti', 'Täiesti'], ['mõttetu']]
# [['tunduvalt', 'tunduvalt'], ['kallimat']]
# [['sealt'], ['ostetud']]
# [['Kohutavalt', 'Kohutavalt'], ['kehv']]
# [['sealt'], ['ostetud']]
# [['lahti'], ['tehtud']]
# [['lahti'], ['võetud']]
# [['kõige', 'kõige'], ['viimane']]
# [['kokku'], ['pandud']]
# [['Väga', 'Väga'], ['viisakas']]
# [['Väga', 'Väga'], ['korralik']]
# [['mitte'], ['kribitud']]
# [['ära'], ['teeninud']]
# [['Väga', 'Väga'], ['hea']]
# [['sealt'], ['ostnud']]
# [['igati', 'igati'], ['vajalik']]
# [['väga', 'väga'], ['hea']]
# [['Väga', 'Väga'], ['hea']]
# [['TÄIESTI', 'TÄIESTI'], ['KORRALIKKU']]
# [['Väga', 'Väga'], ['kiire'], ['ja'], ['asjalik']]
# [['suht'], ['haige']]
# [['sealt'], ['ostnud']]
# [['Väga', 'Väga'], ['kiire']]
# [['siin'], ['olnud']]
# [['väga', 'väga'], ['korralik']]
# [['Väga', 'Väga'], ['hea']]
# [['Väga', 'Väga'], ['asjalik'], ['ja'], ['kiire']]
# [['Väga', 'Väga'], ['hea']]
# [['hoopiski', 'hoopiski'], ['vale']]
# [['rahule'], ['jäänud']]
# [['otsa'], ['saanud']]
# [['siiani'], ['olnud']]
# [['väga', 'väga'], ['head']]
# [['Igati', 'Igati'], ['positiivne']]
# [['väga', 'väga'], ['kiire']]
# [['Igati', 'Igati'], ['meeldiv']]
# [['väga', 'väga'], ['head']]
# [['tõesti', 'tõesti'], ['odavad'], ['ning'], ['kvaliteetsed']]
# [['üle'], ['pandud']]
# [['väga', 'väga'], ['soojad']]
# [['jube', 'jube'], ['odav']]
# [['rahule'], ['jäänud']]
# [['väga', 'väga'], ['hea']]
# [['Väga', 'Väga'], ['positiivne']]
# [['sisse'], ['pandud']]
# [['väga', 'väga'], ['ebastabiilse'], ['ja'], ['ettearvamatu']]
# [['päris', 'päris'], ['pikk']]
# [['palju', 'palju'], ['eksootilist']]
# [['Väga', 'Väga'], ['head']]
# [['väga', 'väga'], ['kiire'], ['ja'], ['meeldiv']]
# [['rahule'], ['jäänud']]
# [['Igati', 'Igati'], ['positiivne']]
# [['Väga', 'Väga'], ['hea']]
# [['sisse'], ['antud']]
# [['vägagi', 'vägagi'], ['kobeda']]
# [['jälle'], ['ostetud']]
# [['Väga', 'Väga'], ['hea']]
# [['Väga', 'Väga'], ['asjalik']]
# [['veel', 'veel'], ['soodsama']]
# [['sealt'], ['leidnud']]
# [['veidi', 'veidi', 'veidi'], ['positiivsema']]
# [['lahti'], ['käinud']]
# [['väga', 'väga'], ['head']]
# [['väga', 'väga'], ['ebasõbralikud']]
# [['Väga', 'Väga'], ['vilets']]
# [['seal'], ['käinud']]
# [['väga', 'väga'], ['hea']]
# [['väga', 'väga'], ['hea']]
# [['kord'], ['käidud']]
# [['väga', 'väga'], ['head']]
# [['tagasi'], ['lubatud']]
# [['sujuvalt'], ['käinud']]
# [['kinni'], ['peetud']]
# [['korralikult'], ['pakendatud']]
# [['Väga', 'Väga'], ['meeldiv']]
# [['Tõsiselt', 'Tõsiselt'], ['hea']]
# [['Väga', 'Väga'], ['hea']]
# [['kohale'], ['jõudnud']]
# [['Eriti', 'Eriti'], ['meeldiv']]
# [['kohale'], ['jõudnud']]
# [['ära'], ['hellitatud']]
# [['pisut', 'pisut', 'pisut'], ['kiirem']]
# [['pisut', 'pisut', 'pisut'], ['lühemat']]
# [['kokku'], ['leppinud']]
# [['järele'], ['tuldud']]
# [['tõesti', 'tõesti'], ['head']]
# [['täiesti', 'täiesti'], ['mõttetu']]
# [['väga', 'väga'], ['raske']]
# [['Väga', 'Väga'], ['head']]
# [['tõsiselt', 'tõsiselt'], ['kiire']]
# [['eriti', 'eriti'], ['üleolev'], ['ja'], ['ebaviisakas']]
# [['alati'], ['olnud']]
# [['igati', 'igati'], ['korralik']]
# [['väga', 'väga'], ['hea']]
# [['Väga', 'Väga'], ['positiivne']]
# [['Üllatavalt', 'Üllatavalt'], ['kiire'], ['ja'], ['meeldiv']]
# [['hästi', 'hästi'], ['pakitud']]
# [['Täitsa', 'Täitsa'], ['normaalne']]
# [['seal'], ['ostnud']]
# [['väga', 'väga'], ['soodsa']]
# [['eespool'], ['nimetatud']]
# [['kahekorra'], ['väänanud']]
# [['Igati', 'Igati'], ['positiivne']]
# [['hästi', 'hästi'], ['pakitud']]
# [['veidi', 'veidi', 'veidi'], ['spetsiifilisemat']]
# [['Meeldivalt', 'Meeldivalt'], ['kiire']]
# [['kohale'], ['jõudnud']]
# [['väga', 'väga'], ['hea']]
# [['väga', 'väga'], ['meeldiv']]
# [['Kõige', 'Kõige'], ['odavamad']]
# [['suhteliselt', 'suhteliselt'], ['olematu']]
# [['väga', 'väga'], ['vastutulelikud']]
# [['Väga', 'Väga'], ['mõistlik']]
# [['väga', 'väga'], ['viisaka']]
# [['igati', 'igati'], ['positiivne']]
# [['värskelt'], ['müüdud']]
# [['igati', 'igati'], ['positiivse']]
# [['Valesti'], ['ostetud']]
# [['Väga', 'Väga'], ['kiire']]
# [['jube', 'jube'], ['kallis']]
# [['Väga', 'Väga'], ['kiire']]
# [['kõige', 'kõige'], ['soodsam']]
# [['Väga', 'Väga'], ['meeldiv']]
# [['tõesti', 'tõesti'], ['lihtne']]
# [['Väga', 'Väga'], ['nõme']]
# [['väga', 'väga'], ['hea']]
# [['hästi', 'hästi'], ['jälgitav']]
# [['väga', 'väga'], ['professionaalne']]
# [['Väga', 'Väga'], ['ebaviisakas']]
# [['varem'], ['ostnud']]
# [['väga', 'väga'], ['lihtne']]
# [['kohale'], ['jõudnud']]
# [['igati', 'igati'], ['meeldiv']]
# [['Natuke', 'Natuke', 'Natuke'], ['nõme']]
# [['kuigi', 'kuigi'], ['tellitud']]
# [['väga', 'väga'], ['kliendisõbralik']]
# [['väga', 'väga'], ['väikse']]
# [['tunduvalt', 'tunduvalt'], ['odavam']]
# [['üsna', 'üsna'], ['häid']]
# [['kõige', 'kõige'], ['sootsamad']]
# [['Väga', 'Väga'], ['kiire'], ['ja'], ['konkreetne']]
# [['varem'], ['mainitud']]
# [['väga', 'väga'], ['mustaks']]
# [['rahule'], ['jäänud']]
# [['eriti', 'eriti'], ['viimane']]
# [['Ilusasti'], ['pakendatud']]
# [['juba'], ['ostnud']]
# [['kiirelt'], ['lahendatud']]
# [['sinna'], ['helistanud']]
# [['Väga', 'Väga'], ['positiivne']]
# [['ülimalt', 'ülimalt'], ['vajalik']]
# [['kinni'], ['jäänud']]
# [['läbi'], ['põlenud']]
# [['Kui', 'Kui'], ['makstud']]
# [['Väga', 'Väga'], ['ebausaldusväärne']]
# [['hiljem'], ['saabunud']]
# [['Väga', 'Väga'], ['negatiivne']]
# [['igati', 'igati'], ['tellitav']]
# [['täiesti', 'täiesti'], ['lõppenuks']]
# [['natuke', 'natuke', 'natuke'], ['kallim']]
# [['natuke', 'natuke', 'natuke'], ['lünklik']]
# [['väga', 'väga'], ['raske']]
# [['väga', 'väga'], ['segaseks']]
# [['igati', 'igati'], ['positiivne']]
# [['Väga', 'Väga'], ['kiire']]
# [['Päris', 'Päris'], ['lai']]
# [['enne'], ['vananenud']]
# [['sealt'], ['tellinud']]
# [['oluliselt', 'oluliselt'], ['odavam']]
# [['veel', 'veel'], ['olnud']]
# [['Väga', 'Väga'], ['meeldiv'], ['ja'], ['ülikiire']]
# [['eelpool'], ['mainitud']]
# [['nats'], ['segane']]
# [['veel', 'veel'], ['odavama']]
# [['väga', 'väga'], ['hea']]
# [['palju', 'palju'], ['oodavam']]
# [['väga', 'väga'], ['suur']]
# [['Kui', 'Kui'], ['lubatud']]
# [['Uskumatult', 'Uskumatult'], ['sitt']]
# [['valesti'], ['seotud']]
# [['veel', 'veel'], ['jõudnud']]
# [['välja'], ['pandud']]
# [['Väga', 'Väga'], ['kahtlane']]
# [['liiga', 'liiga'], ['pikk']]
# [['Väga', 'Väga'], ['asjalik']]
# [['kõige', 'kõige'], ['odavam']]
# [['kõige', 'kõige'], ['tugevam']]
# [['igati', 'igati'], ['vastutulelik']]
# [['ümber'], ['vahetatud']]
# [['valesti'], ['paigaldatud']]
# [['Meeldivalt', 'Meeldivalt'], ['kiire']]
# [['ülimalt', 'ülimalt'], ['soodne']]
# [['märkimisväärselt', 'märkimisväärselt'], ['soodsam']]
# [['väga', 'väga'], ['head']]
# [['Jõle', 'Jõle'], ['huvitav']]
# [['väga', 'väga'], ['hea']]
# [['Sealt'], ['ostetud']]
# [['veidi', 'veidi', 'veidi'], ['kõrgem']]
# [['väga', 'väga'], ['hea']]
# [['väga', 'väga'], ['head']]
# [['siit'], ['tellinud']]
# [['pisut', 'pisut', 'pisut'], ['närvis']]
# [['igati', 'igati'], ['meeldiv'], ['ja'], ['abivalmis']]
# [['väga', 'väga'], ['head']]
# [['sealt'], ['tellinud']]
# [['Väga', 'Väga'], ['negatiivsed']]
# [['sealt'], ['tellinud']]
# [['alles'], ['avastanud']]
# [['täitsa', 'täitsa'], ['vastupidine']]
# [['suht'], ['uue']]
# [['väga', 'väga'], ['head']]
# [['väga', 'väga'], ['head']]
# [['väga', 'väga'], ['soodne']]
# [['väga', 'väga'], ['hea']]
# [['veel', 'veel'], ['tulnud']]
# [['mujalt'], ['tellinud']]
# [['palju', 'palju'], ['tõusnud']]
# [['edaspidi'], ['välistatud']]
# [['kõige', 'kõige'], ['soodsam']]
# [['Väga', 'Väga'], ['kiire'], ['ja'], ['sõbralik']]
# [['suhteliselt', 'suhteliselt'], ['hea']]
# [['igati', 'igati'], ['hea']]
# [['Väga', 'Väga'], ['positiivne']]
# [['Äärmiselt', 'Äärmiselt'], ['kiire']]
# [['väga', 'väga'], ['kiire']]
# [['igatahes'], ['saanud']]
# [['väga', 'väga'], ['astutulelik']]
# [['Ülimalt', 'Ülimalt'], ['meeldiv']]
# [['väga', 'väga'], ['vastutulelikud']]
# [['täiesti', 'täiesti'], ['korralik']]
# [['päris', 'päris'], ['tuntav']]
# [['natuke', 'natuke', 'natuke'], ['põhjalikumaid']]
# [['Igati', 'Igati'], ['asjalik']]
# [['igati', 'igati'], ['positiivne']]
# [['väga', 'väga'], ['hea']]
# [['kuskil'], ['märgitud']]
# [['tagasi'], ['laekunud']]
# [['nii', 'nii'], ['vaikne']]
# [['oluliselt', 'oluliselt'], ['madalam']]
# [['Väga', 'Väga'], ['hea'], ['ja'], ['kiire']]
# [['sedavõrd', 'sedavõrd', 'sedavõrd'], ['kiiret']]
# [['korralikult'], ['pakitud']]
# [['kohal'], ['käinud']]
# [['ära'], ['toonud']]
# [['väga', 'väga'], ['kiire']]
# [['kõige', 'kõige'], ['odavam']]
# [['kõige', 'kõige'], ['soodsam']]
# [['väga', 'väga'], ['meeldiv']]
# [['kõige', 'kõige'], ['parem']]
# [['kõige', 'kõige'], ['odavama']]
# [['väga', 'väga'], ['negatiivne']]
# [['ammu'], ['tehtud']]
# [['väga', 'väga'], ['kiire']]
# [['väga', 'väga'], ['kiire']]
# [['eriti', 'eriti'], ['head']]
# [['märksa', 'märksa'], ['nõrgema']]
# [['tuimalt'], ['tellitud']]
# [['mitte'], ['muudetud']]
# [['nii', 'nii'], ['dokumentaalsed']]
# [['väga', 'väga'], ['positiivne']]
# [['varemgi'], ['käinud']]
# [['Väga', 'Väga'], ['täpne']]
# [['väga', 'väga'], ['hea']]
# [['nii', 'nii'], ['vana']]
# [['igati', 'igati'], ['korrektne']]
# [['Väga', 'Väga'], ['meeldiv']]
# [['Hästi', 'Hästi'], ['positiivse']]
# [['Väga', 'Väga'], ['head']]
# [['tunduvalt', 'tunduvalt'], ['madalamat']]
# [['eriti', 'eriti'], ['kahtlane']]
# [['väga', 'väga'], ['halb']]
# [['väga', 'väga'], ['kiire']]
# [['väga', 'väga'], ['hea']]
# [['pigem', 'pigem'], ['positiivne']]
# [['läbi'], ['antud']]
# [['väga', 'väga'], ['hea']]
# [['korrektselt'], ['vormistatud']]
# [['Kahjuks'], ['antud']]
# [['väga', 'väga'], ['tüütu'], ['ja'], ['ebameeldiv']]
# [['Väga', 'Väga'], ['hea']]
# [['Väga', 'Väga'], ['tore']]
# [['Kahjuks'], ['tellitud']]
# [['väga', 'väga'], ['ebameeldiv']]
