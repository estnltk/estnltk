# %% [markdown]
# ### Make sure that estnltk package is accessible

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
print(sys.path)
# Out:
# ['', 'C:\\Users\\Birgit\\Anaconda3\\envs\\estnltk\\python35.zip', 'C:\\Users\\Birgit\\Anaconda3\\envs\\estnltk\\DLLs', 'C:\\Users\\Birgit\\Anaconda3\\envs\\estnltk\\lib', 'C:\\Users\\Birgit\\Anaconda3\\envs\\estnltk', 'C:\\Users\\Birgit\\Anaconda3\\envs\\estnltk\\lib\\site-packages', 'C:\\Users\\Birgit\\Anaconda3\\envs\\estnltk\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\Birgit\\.ipython']

# %% [markdown]
# This line is correct only in my environment modify accordingly

# %%
sys.path.append("~/Documents/estnltk")
sys.path.append("~/Documents/estnltk/estnltk")

# %% [markdown]
# You might have to install ```conllu``` package. Magic lines are
# ```conda install -n estnltk -c conda-forge conll``` if you development environment is ```estnltk```

# %%
import estnltk

# %%
from estnltk.converters.conll_importer import conll_to_text
from estnltk.converters.conll_importer import add_layer_from_conll

# %% [markdown]
# Lets read in short files as reading long files takes a lot of time and does not add anything. Note that we read in two syntax layers and syncronise them.

# %%
textmalt = conll_to_text(file='data/test_parsed_short.conll', syntax_layer='malt')
textgold = conll_to_text(file='data/test_gold_short.conll', syntax_layer='gold')

# %%
textmalt
# Out:
# Text(text='Selles võib olla koguni 95 protsenti õhku ja ainult 5 protsenti vett . Poole tunni pärast on varbad külmast kanged . Jaamas saab need sooja plekkahju vastas üles soojendada . Kati klõbistab natuke taskuarvutiga ja kannab lõpuks lumetabelisse järgmised andmed : Suurim paksus 28 cm Väikseim paksus 16 cm Keskmine paksus 23 cm Paksus koos lumealuse jääkoorikuga 23,3 cm Lume keskmine tihedus ( lumekihi massi ja ruumala vaheline suhe ) 0,16 g ühe cm kohta')

# %%
textgold.gold
# Out:
# Layer(name='gold', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc', 'parent_span', 'children'), spans=SL[Span(start=0, end=6, text='Selles'),
# Span(start=7, end=11, text='võib'),
# Span(start=12, end=16, text='olla'),
# Span(start=17, end=23, text='koguni'),
# Span(start=24, end=26, text='95'),
# Span(start=27, end=36, text='protsenti'),
# Span(start=37, end=41, text='õhku'),
# Span(start=42, end=44, text='ja'),
# Span(start=45, end=51, text='ainult'),
# Span(start=52, end=53, text='5'),
# Span(start=54, end=63, text='protsenti'),
# Span(start=64, end=68, text='vett'),
# Span(start=69, end=70, text='.'),
# Span(start=71, end=76, text='Poole'),
# Span(start=77, end=82, text='tunni'),
# Span(start=83, end=89, text='pärast'),
# Span(start=90, end=92, text='on'),
# Span(start=93, end=99, text='varbad'),
# Span(start=100, end=107, text='külmast'),
# Span(start=108, end=114, text='kanged'),
# Span(start=115, end=116, text='.'),
# Span(start=117, end=123, text='Jaamas'),
# Span(start=124, end=128, text='saab'),
# Span(start=129, end=133, text='need'),
# Span(start=134, end=139, text='sooja'),
# Span(start=140, end=149, text='plekkahju'),
# Span(start=150, end=156, text='vastas'),
# Span(start=157, end=161, text='üles'),
# Span(start=162, end=172, text='soojendada'),
# Span(start=173, end=174, text='.'),
# Span(start=175, end=179, text='Kati'),
# Span(start=180, end=189, text='klõbistab'),
# Span(start=190, end=196, text='natuke'),
# Span(start=197, end=210, text='taskuarvutiga'),
# Span(start=211, end=213, text='ja'),
# Span(start=214, end=220, text='kannab'),
# Span(start=221, end=227, text='lõpuks'),
# Span(start=228, end=241, text='lumetabelisse'),
# Span(start=242, end=251, text='järgmised'),
# Span(start=252, end=258, text='andmed'),
# Span(start=259, end=260, text=':'),
# Span(start=261, end=267, text='Suurim'),
# Span(start=268, end=274, text='paksus'),
# Span(start=275, end=277, text='28'),
# Span(start=278, end=280, text='cm'),
# Span(start=281, end=289, text='Väikseim'),
# Span(start=290, end=296, text='paksus'),
# Span(start=297, end=299, text='16'),
# Span(start=300, end=302, text='cm'),
# Span(start=303, end=311, text='Keskmine'),
# Span(start=312, end=318, text='paksus'),
# Span(start=319, end=321, text='23'),
# Span(start=322, end=324, text='cm'),
# Span(start=325, end=331, text='Paksus'),
# Span(start=332, end=336, text='koos'),
# Span(start=337, end=346, text='lumealuse'),
# Span(start=347, end=359, text='jääkoorikuga'),
# Span(start=360, end=364, text='23,3'),
# Span(start=365, end=367, text='cm'),
# Span(start=368, end=372, text='Lume'),
# Span(start=373, end=381, text='keskmine'),
# Span(start=382, end=389, text='tihedus'),
# Span(start=390, end=391, text='('),
# Span(start=392, end=400, text='lumekihi'),
# Span(start=401, end=406, text='massi'),
# Span(start=407, end=409, text='ja'),
# Span(start=410, end=417, text='ruumala'),
# Span(start=418, end=426, text='vaheline'),
# Span(start=427, end=431, text='suhe'),
# Span(start=432, end=433, text=')'),
# Span(start=434, end=438, text='0,16'),
# Span(start=439, end=440, text='g'),
# Span(start=441, end=444, text='ühe'),
# Span(start=445, end=447, text='cm'),
# Span(start=448, end=453, text='kohta')])

# %%
textmalt.malt
# Out:
# Layer(name='malt', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc', 'parent_span', 'children'), spans=SL[Span(start=0, end=6, text='Selles'),
# Span(start=7, end=11, text='võib'),
# Span(start=12, end=16, text='olla'),
# Span(start=17, end=23, text='koguni'),
# Span(start=24, end=26, text='95'),
# Span(start=27, end=36, text='protsenti'),
# Span(start=37, end=41, text='õhku'),
# Span(start=42, end=44, text='ja'),
# Span(start=45, end=51, text='ainult'),
# Span(start=52, end=53, text='5'),
# Span(start=54, end=63, text='protsenti'),
# Span(start=64, end=68, text='vett'),
# Span(start=69, end=70, text='.'),
# Span(start=71, end=76, text='Poole'),
# Span(start=77, end=82, text='tunni'),
# Span(start=83, end=89, text='pärast'),
# Span(start=90, end=92, text='on'),
# Span(start=93, end=99, text='varbad'),
# Span(start=100, end=107, text='külmast'),
# Span(start=108, end=114, text='kanged'),
# Span(start=115, end=116, text='.'),
# Span(start=117, end=123, text='Jaamas'),
# Span(start=124, end=128, text='saab'),
# Span(start=129, end=133, text='need'),
# Span(start=134, end=139, text='sooja'),
# Span(start=140, end=149, text='plekkahju'),
# Span(start=150, end=156, text='vastas'),
# Span(start=157, end=161, text='üles'),
# Span(start=162, end=172, text='soojendada'),
# Span(start=173, end=174, text='.'),
# Span(start=175, end=179, text='Kati'),
# Span(start=180, end=189, text='klõbistab'),
# Span(start=190, end=196, text='natuke'),
# Span(start=197, end=210, text='taskuarvutiga'),
# Span(start=211, end=213, text='ja'),
# Span(start=214, end=220, text='kannab'),
# Span(start=221, end=227, text='lõpuks'),
# Span(start=228, end=241, text='lumetabelisse'),
# Span(start=242, end=251, text='järgmised'),
# Span(start=252, end=258, text='andmed'),
# Span(start=259, end=260, text=':'),
# Span(start=261, end=267, text='Suurim'),
# Span(start=268, end=274, text='paksus'),
# Span(start=275, end=277, text='28'),
# Span(start=278, end=280, text='cm'),
# Span(start=281, end=289, text='Väikseim'),
# Span(start=290, end=296, text='paksus'),
# Span(start=297, end=299, text='16'),
# Span(start=300, end=302, text='cm'),
# Span(start=303, end=311, text='Keskmine'),
# Span(start=312, end=318, text='paksus'),
# Span(start=319, end=321, text='23'),
# Span(start=322, end=324, text='cm'),
# Span(start=325, end=331, text='Paksus'),
# Span(start=332, end=336, text='koos'),
# Span(start=337, end=346, text='lumealuse'),
# Span(start=347, end=359, text='jääkoorikuga'),
# Span(start=360, end=364, text='23,3'),
# Span(start=365, end=367, text='cm'),
# Span(start=368, end=372, text='Lume'),
# Span(start=373, end=381, text='keskmine'),
# Span(start=382, end=389, text='tihedus'),
# Span(start=390, end=391, text='('),
# Span(start=392, end=400, text='lumekihi'),
# Span(start=401, end=406, text='massi'),
# Span(start=407, end=409, text='ja'),
# Span(start=410, end=417, text='ruumala'),
# Span(start=418, end=426, text='vaheline'),
# Span(start=427, end=431, text='suhe'),
# Span(start=432, end=433, text=')'),
# Span(start=434, end=438, text='0,16'),
# Span(start=439, end=440, text='g'),
# Span(start=441, end=444, text='ühe'),
# Span(start=445, end=447, text='cm'),
# Span(start=448, end=453, text='kohta')])

# %% [markdown]
# ## Development
#
# Nüüd on sul olemas text objekt millel on kaks süntaksikihti. Tee järgmist
# * Visualiseeri ühte süntaksikihti gold
# * Visualiseeri ühte süntaksikihti gold nii, et oleks näha teise süntaksihikt malt
# * Visualiseeri ühte süntaksikihti gold nii, et oleks näha teine süntaksikiht malt ja muuta saks vaid neid kohti kus kihid erinevad.

# %%
from IPython.display import display_html

# %%
def css():
        with open("syntax_visualiser_css.css") as css_file:
            contents = css_file.read()
            output = ''.join(["<style>\n", contents, "</style>"])
        return output

# %%
def event_handler_code():
        with open("syntax_visualiser_js.js") as js_file:
            contents = js_file.read()
            output = ''.join(["<script>\n", contents, "</script>"])
            #output = ''.join(["<script>\n var text_id=", str(self._text_id),"\n", contents, "</script>"])
        return output

# %%
def table_column(layers, attribute, deprel, index = None):
    cellid = 0
    sentence = 0
    word = 0
    if index is not None:
        table_elements = ["<td><table><tr><th>", attribute, str(index), "</th></tr>"]
    else:
        table_elements = ["<td><table><tr><th>", attribute, "</th></tr>"]
    if attribute == "feats":
        for element in getattr(layers, attribute):
            table_elements.extend(["<tr><td id = \"", str(attribute), str(index), ";", str(cellid), "\">"])
            cellid +=1
            if element is not None:
                for key in element:
                    table_elements.extend([str(key), " "])
            else:
                table_elements.append(str(element))
            table_elements.append("</td></tr>")
    elif attribute == "deprel":
        for element in getattr(layers, attribute):
            table_elements.extend(["<tr><td id = \"", str(attribute), str(index), ";", str(cellid), "\">"])
            cellid += 1
            table_elements.extend(["<select id = \"deprel", str(index), ";", str(cellid), "><option value=\"", str(cellid), ";0>", str(element), "</option>"])
            for deprel_element in deprel:
                if element != deprel_element:
                    table_elements.extend(["<option value=", str(cellid), ";", deprel_element, ">", str(deprel_element), "</option>"])
            table_elements.extend(["</select>", "</td></tr>"])
    elif attribute == "head":
        for element in getattr(layers, attribute):
            if word == len(textmalt.sentences[sentence]):
                word = 0
                sentence += 1
            table_elements.extend(["<tr><td id = \"", str(attribute), str(index), ";", str(cellid), "\">"])
            cellid += 1
            #table_elements.extend(["<select id = \"head", str(index), ""\"><option>", str(element), "</option>"])
            table_elements.extend(["<select id=\"head", str(index), ";", str(cellid)," onchange=\"get_select_value();\"><option value=\"", str(cellid), ";0\">", str(element), "</option>"])
            #table_elements.extend(["<select id=\"head", str(cellid),"\"><option value=\"0\">", str(element), "</option>"])
            for i in range(len(textmalt.sentences[sentence])):
                table_elements.extend(["<option value=", str(cellid), ";", str(i + 1), ">", str(i + 1), ": ", str(textmalt.sentences[sentence].text[i]), "</option>"])
            word += 1
            table_elements.append("</select></td></tr>")
    else:
        for element in getattr(layers, attribute):
            table_elements.extend(["<tr><td id = \"", str(attribute), str(index), ";", str(cellid), "\">", str(element), "</td></tr>"])
            cellid += 1
    table_elements.append("</table></td>")
    return table_elements

# %%
def table(layer, attributes, deprel):
    table_elements = [css(), "<table><tr>"]
    for attribute in attributes:
        table_elements.extend(table_column(layer, attribute, deprel))
    table_elements.append("</tr></table>")
    return "".join(table_elements)

# %%
attributes = ["text", "id", "lemma", "upostag", "xpostag", "feats", "head", "deprel", "deps", "misc"]
deprel = ["@ADVL", "@FCV", "ROOT", "@SUBJ"] #test deprel list
display_html(table(textgold.gold, attributes, deprel), raw = True)
# Out:
# <style>
# select {
#     margin: -10px;
# }
#
# td, th {
#     font-size: 0.9vw;
# }
#
# </style><table><tr><td><table><tr><th>text</th></tr><tr><td id = "textNone0">Selles</td></tr><tr><td id = "textNone1">võib</td></tr><tr><td id = "textNone2">olla</td></tr><tr><td id = "textNone3">koguni</td></tr><tr><td id = "textNone4">95</td></tr><tr><td id = "textNone5">protsenti</td></tr><tr><td id = "textNone6">õhku</td></tr><tr><td id = "textNone7">ja</td></tr><tr><td id = "textNone8">ainult</td></tr><tr><td id = "textNone9">5</td></tr><tr><td id = "textNone10">protsenti</td></tr><tr><td id = "textNone11">vett</td></tr><tr><td id = "textNone12">.</td></tr><tr><td id = "textNone13">Poole</td></tr><tr><td id = "textNone14">tunni</td></tr><tr><td id = "textNone15">pärast</td></tr><tr><td id = "textNone16">on</td></tr><tr><td id = "textNone17">varbad</td></tr><tr><td id = "textNone18">külmast</td></tr><tr><td id = "textNone19">kanged</td></tr><tr><td id = "textNone20">.</td></tr><tr><td id = "textNone21">Jaamas</td></tr><tr><td id = "textNone22">saab</td></tr><tr><td id = "textNone23">need</td></tr><tr><td id = "textNone24">sooja</td></tr><tr><td id = "textNone25">plekkahju</td></tr><tr><td id = "textNone26">vastas</td></tr><tr><td id = "textNone27">üles</td></tr><tr><td id = "textNone28">soojendada</td></tr><tr><td id = "textNone29">.</td></tr><tr><td id = "textNone30">Kati</td></tr><tr><td id = "textNone31">klõbistab</td></tr><tr><td id = "textNone32">natuke</td></tr><tr><td id = "textNone33">taskuarvutiga</td></tr><tr><td id = "textNone34">ja</td></tr><tr><td id = "textNone35">kannab</td></tr><tr><td id = "textNone36">lõpuks</td></tr><tr><td id = "textNone37">lumetabelisse</td></tr><tr><td id = "textNone38">järgmised</td></tr><tr><td id = "textNone39">andmed</td></tr><tr><td id = "textNone40">:</td></tr><tr><td id = "textNone41">Suurim</td></tr><tr><td id = "textNone42">paksus</td></tr><tr><td id = "textNone43">28</td></tr><tr><td id = "textNone44">cm</td></tr><tr><td id = "textNone45">Väikseim</td></tr><tr><td id = "textNone46">paksus</td></tr><tr><td id = "textNone47">16</td></tr><tr><td id = "textNone48">cm</td></tr><tr><td id = "textNone49">Keskmine</td></tr><tr><td id = "textNone50">paksus</td></tr><tr><td id = "textNone51">23</td></tr><tr><td id = "textNone52">cm</td></tr><tr><td id = "textNone53">Paksus</td></tr><tr><td id = "textNone54">koos</td></tr><tr><td id = "textNone55">lumealuse</td></tr><tr><td id = "textNone56">jääkoorikuga</td></tr><tr><td id = "textNone57">23,3</td></tr><tr><td id = "textNone58">cm</td></tr><tr><td id = "textNone59">Lume</td></tr><tr><td id = "textNone60">keskmine</td></tr><tr><td id = "textNone61">tihedus</td></tr><tr><td id = "textNone62">(</td></tr><tr><td id = "textNone63">lumekihi</td></tr><tr><td id = "textNone64">massi</td></tr><tr><td id = "textNone65">ja</td></tr><tr><td id = "textNone66">ruumala</td></tr><tr><td id = "textNone67">vaheline</td></tr><tr><td id = "textNone68">suhe</td></tr><tr><td id = "textNone69">)</td></tr><tr><td id = "textNone70">0,16</td></tr><tr><td id = "textNone71">g</td></tr><tr><td id = "textNone72">ühe</td></tr><tr><td id = "textNone73">cm</td></tr><tr><td id = "textNone74">kohta</td></tr></table></td><td><table><tr><th>id</th></tr><tr><td id = "idNone0">1</td></tr><tr><td id = "idNone1">2</td></tr><tr><td id = "idNone2">3</td></tr><tr><td id = "idNone3">4</td></tr><tr><td id = "idNone4">5</td></tr><tr><td id = "idNone5">6</td></tr><tr><td id = "idNone6">7</td></tr><tr><td id = "idNone7">8</td></tr><tr><td id = "idNone8">9</td></tr><tr><td id = "idNone9">10</td></tr><tr><td id = "idNone10">11</td></tr><tr><td id = "idNone11">12</td></tr><tr><td id = "idNone12">13</td></tr><tr><td id = "idNone13">1</td></tr><tr><td id = "idNone14">2</td></tr><tr><td id = "idNone15">3</td></tr><tr><td id = "idNone16">4</td></tr><tr><td id = "idNone17">5</td></tr><tr><td id = "idNone18">6</td></tr><tr><td id = "idNone19">7</td></tr><tr><td id = "idNone20">8</td></tr><tr><td id = "idNone21">1</td></tr><tr><td id = "idNone22">2</td></tr><tr><td id = "idNone23">3</td></tr>< ...

# %%
def joint_table(layers, attributes, deprel):
    table_elements = [css(), event_handler_code(), "<table><tr>"]
    for attribute in attributes:
        for i, layer in enumerate(layers):
            if attribute == "head" or attribute == "deprel":
                table_elements.extend(table_column(layer, attribute, deprel, i + 1))
            elif i == 0:
                table_elements.extend(table_column(layer, attribute, deprel))
    table_elements.append("</tr></table><button type=\"button\">save</button>")
    return "".join(table_elements)

# %%
display_html(joint_table([textgold.gold, textmalt.malt], attributes, deprel), raw = True)
# Out:
# <style>
# select {
#     margin: -10px;
# }
#
# td, th {
#     font-size: 0.9vw;
# }
#
# button {
#     margin-left: 877px;
# }</style><script>
# function get_select_value(element) {
#     let selectedValueId = document.getElementById(element).value;
#     //let selectedValue = selectedValueId.options[selectedValueId.selectedIndex].text;
#     //let selectedValue = selectedValueId.target.options[selectedValueId.target.selectedIndex].text;
#     //console.log(selectedValueId.options);
#     console.log(selectedValueId);
#     //return selectedValue;
# }
#
# function selecting_value(event, column) {
#     //let attributes = JSON.parse();
#     if (event.keyCode == '13'|| event.which == '13') {
#         let value = get_select_value(column);
#         console.log(value);
#     }
# }
#
# let start;
# document.addEventListener('click', function (e) {
#     Jupyter.keyboard_manager.disable();
#     if (start != undefined) {
#         start.style.backgroundColor = null;
#         start.style.color = null;
#     }
#     let startid = e.target.id;
#     start = document.getElementById(startid);
#     start.focus();
#     start.style.backgroundColor = 'pink';
#     start.style.color = 'white';
#     document.onkeydown = checkKey;
# }, false);
#
# function move(sibling) {
#     if (sibling != null) {
#         start.focus();
#         start.style.backgroundColor = '';
#         start.style.color = '';
#         sibling.focus();
#         sibling.style.backgroundColor = 'pink';
#         sibling.style.color = 'white';
#         start = sibling;
#     }
# }
#
# function checkKey(e) {
#     e = e || window.event;
#     if (e.keyCode == '38') {
#         // up arrow
#         e.preventDefault();
#         let idx = start.cellIndex;
#         let nextrow = start.parentElement.previousElementSibling;
#         if (nextrow != null) {
#             let sibling = nextrow.cells[idx];
#             move(sibling);
#         }
#     } else if (e.keyCode == '40') {
#         // down arrow
#         e.preventDefault();
#         let idx = start.cellIndex;
#         let nextrow = start.parentElement.nextElementSibling;
#         if (nextrow != null) {
#             let sibling = nextrow.cells[idx];
#             move(sibling);
#         }
#     } else if (e.keyCode == '37') {
#         // left arrow
#         e.preventDefault();
#         let index = Array.from(start.parentElement.parentElement.children).indexOf(start.parentElement);
#         //console.log(start);
#         //console.log(start.parentElement.parentElement.children);
#         //console.log(index);
#         let sibling = start.parentElement.parentElement.parentElement.parentElement.previousElementSibling.firstElementChild.firstElementChild.children.item(index).firstElementChild;
#         move(sibling);
#     } else if (e.keyCode == '39') {
#         // right arrow
#         e.preventDefault();
#         let index = Array.from(start.parentElement.parentElement.children).indexOf(start.parentElement);
#         let sibling = start.parentElement.parentElement.parentElement.parentElement.nextElementSibling.firstElementChild.firstElementChild.children.item(index).firstElementChild;
#         move(sibling);
#     } else if (e.keyCode == '32') {
#         // Space key for opening dropdown
#         let sibling = start.firstElementChild;
#         move(sibling);
#     } else if (e.keyCode == '16') {
#         //Shift for going back (for leaving dropdown)
#         console.log(start);
#         let sibling = start.parentElement;
#         move(sibling);
#         e.preventDefault();
#         //e.preventDefault();
#     } else if (e.keyCode == '13') {
#         // Enter key for dropdown choices
#         console.log(start.tagName);
#         console.log(start.id);
#         //console.log(start.options[start.selectedIndex]);
#         //console.log(start.id.innerHTML);
#         //let optionid = start.id;
#         let sibling = start.firstElementChild;
#         get_select_value(start.id);
#         move(sibling);
#         //console.log(optionid.options[optionid.selectedIndex].text);
#         //e.preventDefault();
#         //start.blur();
#         //let index = Array.from(start.parentElement.parentElement.children).indexOf(start.parentElement);
#         //let sibling = start.parentElement.children.item(index);
#         //let sibling = start.closest('td');
#         //move(sibling);
#     }
# }
#
# function export_data() {
#     //TODO
# }
# </script><table><tr><td><table><tr><th>text</th></tr><tr><td id = "textNone;0">Selles</td></tr><tr><td id = "textNone;1">võib</td></tr><tr><td id = "textNone;2">olla</td></tr><tr><td id = "textNone;3">koguni</td></tr><tr><td id = "textNone;4">95</td></tr><tr><td id = "textNone;5">protsenti</td></tr><tr><td id = "textNone;6">õhku</td></tr><tr><td id = "textNone;7">ja</td></tr><tr><td id = "textNone;8">ainult</td></tr><tr><td id = "textNone;9">5</td></tr><tr><td id = "textNone;10">protsenti</td></tr><tr><td id = "textNone;11">vett</td></tr><tr><td id = "textNone;12">.</td></tr><tr><td id = "textNone;13">Poole</td></tr><tr><td id = "textNone;14">tunni</td></tr><tr><td id = "textNone;15">pärast</td></tr><tr><td id = "textNone;16">on</td></tr><tr><td id = "textNone;17">varbad</td></tr><tr><td id = "textNone;18">külmast</td></tr><tr><td id = "textNone;19">kanged</td></tr><tr><td id = "textNone;20">.</td></tr><tr><td id = "textNone;21">Jaamas</td></tr><tr><td id = "textNone;22">saab</td></tr><tr><td id = "textNone;23">need</td></tr><tr><td id = "textNone;24">sooja</td></tr><tr><td id = "textNone;25">plekkahju</td></tr><tr><td id = "textNone;26">vastas</td></tr><tr><td id = "textNone;27">üles</td></tr><tr><td id = "textNone;28">soojendada</td></tr><tr><td id = "textNone;29">.</td></tr><tr><td id = "textNone;30">Kati</td></tr><tr><td id = "textNone;31">klõbistab</td></tr><tr><td id = "textNone;32">natuke</td></tr><tr><td id = "textNone;33">taskuarvutiga</td></tr><tr><td id = "textNone;34">ja</td></tr><tr><td id = "textNone;35">kannab</td></tr><tr><td id = "textNone;36">lõpuks</td></tr><tr><td id = "textNone;37">lumetabelisse</td></tr><tr><td id = "textNone;38">järgmised</td></tr><tr><td id = "textNone;39">andmed</td></tr><tr><td id = "textNone;40">:</td></tr><tr><td id = "textNone;41">Suurim</td></tr><tr><td id = "textNone;42">paksus</td></tr><tr><td id = "textNone;43">28</td></tr><tr><td id = "textNone;44">cm</td></tr><tr><td id = "textNone;45">Väikseim</td></tr><tr><td id = "textNone;46">paksus</td></tr><tr><td id = "textNone;47">16</td></tr><tr><td id = "textNone;48">cm</td></tr><tr><td id = "textNone;49">Keskmine</td></tr><tr><td id = "textNone;50">paksus</td></tr><tr><td id = "textNone;51">23</td></tr><tr><td id = "textNone;52">cm</td></tr><tr><td id = "textNone;53">Paksus</td></tr><tr><td id = "textNone;54">koos</td></tr><tr><td id = "textNone;55">lumealuse</td></tr><tr><td id = "textNone;56">jääkoorikuga</td></tr><tr><td id = "textNone;57">23,3</td></tr><tr><td id = "textNone;58">cm</td></tr><tr><td id = "textNone;59">Lume</td></tr><tr><td id = "textNone;60">keskmine</td></tr><tr><td id = "textNone;61">tihedus</td></tr><tr><td id = "textNone;62">(</td></tr><tr><td id = "textNone;63">lumekihi</td></tr><tr><td id = "textNone;64">massi</td></tr><tr><td id = "textNone;65">ja</td></tr><tr><td id = "textNone;66">ruumala</td></tr><tr><td id = "textNone;67">vaheline</td></tr><tr><td id = "textNone;68">suhe</td></tr><tr><td id = "textNone;69">)</td></tr><tr><td id = "textNone;70">0,16</td></tr><tr><td id = "textNone;71">g</td></tr><tr><td id = "textNone;72">ühe</td></tr><tr><td id = "textNone;73">cm</td></tr><tr><td id = "textNone;74">kohta</td></tr></table></td><td><table><tr><th>id</th></tr><tr><td id = "idNone;0">1</td></tr><tr><td id = "idNone;1">2</td></tr><tr><td id = "idNone;2">3</td></tr><tr><td id = "idNone;3">4</td></tr><tr><td id = "idNone;4">5</td></tr><tr><td id = "idNone;5">6</td></tr><tr><td id = "idNone;6">7</td></tr><tr><td id = "idNone;7">8</td></tr><tr><td id = "idNone;8">9</td></tr><tr><td id = "idNone;9">10</td></tr><tr><td id = "idNone;10">11</td></tr><tr><td id = "idNone;11">12</td></tr><tr><td id = "idNone;12">13</td></tr><tr><td id = "idNone;13">1</td></tr><tr><td id = "idNone;14">2</td></tr><tr><td

# %%
import json
from estnltk.converters import layer_to_json

# %%
#gold_json = layer_to_json(textgold.gold, textgold)
#malt_json = layer_to_json(textmalt.malt, textmalt)

# %%
def json_object(rows, deprel):
    d = {}
    d["rows"] = rows
    d["deprel"] = deprel
    return json.dumps(d)

# %%
json_object(attributes, deprel)
# Out:
# '{"rows": ["text", "id", "lemma", "upostag", "xpostag", "feats", "head", "deprel", "deps", "misc"], "deprel": ["@ADVL", "@FCV", "ROOT", "@SUBJ"]}'
